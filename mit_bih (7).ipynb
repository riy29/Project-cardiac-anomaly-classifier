# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/mit_bih/
# Out:
# /content/drive/MyDrive/mit_bih

# %%
# !ls -l
# Out:
# total 4
# drwx------ 2 root root 4096 Nov  6 06:00 mit-bih-arrhythmia-database-1.0.0

# %%
# !pip install wfdb
# Out:
# Requirement already satisfied: wfdb in /usr/local/lib/python3.12/dist-packages (4.3.0)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.12/dist-packages (from wfdb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2025.3.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.12/dist-packages (from wfdb) (3.10.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2.0.2)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2.3.3)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2.32.4)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (1.16.3)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (2025.10.5)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.10.0->wfdb) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp>=3.10.11->wfdb) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.17.0)

# %%
# !ls -l
# Out:
# total 4
# drwx------ 2 root root 4096 Nov  6 06:00 mit-bih-arrhythmia-database-1.0.0

# %%
import wfdb

# %%
record_name = 'mit-bih-arrhythmia-database-1.0.0/100'

# %%
record = wfdb.rdrecord(record_name)
annotation = wfdb.rdann(record_name, 'atr')
print(record.sig_name)
print(record.fs )
print( record.sig_len)
print(record.p_signal.shape)
print(record.p_signal[:5])
print(annotation.symbol[:10])
print(annotation.sample[:10])
# Out:
# ['MLII', 'V5']
# 360
# 650000
# (650000, 2)
# [[-0.145 -0.065]
#  [-0.145 -0.065]
#  [-0.145 -0.065]
#  [-0.145 -0.065]
#  [-0.145 -0.065]]
# ['+', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'A', 'N']
# [  18   77  370  662  946 1231 1515 1809 2044 2402]

# %%
import matplotlib.pyplot as plt
import numpy as np

seconds_to_plot = 10
channel_to_plot = 1

fs = record.fs

num_samples = seconds_to_plot * fs

signal = record.p_signal[:num_samples, channel_to_plot]

time_axis = np.arange(num_samples) / fs

ann_indices_in_range = np.where(annotation.sample < num_samples)[0]
ann_samples_in_range = annotation.sample[ann_indices_in_range]
ann_symbols_in_range = np.array(annotation.symbol)[ann_indices_in_range]

ann_y_values = signal[ann_samples_in_range]

plt.figure(figsize=(20, 6))

plt.plot(time_axis, signal, label=f'Channel: {record.sig_name[channel_to_plot]}')

plt.plot(ann_samples_in_range / fs, ann_y_values, 'ro', label='Beat Annotation')

for i, symbol in enumerate(ann_symbols_in_range):
    plt.text(ann_samples_in_range[i] / fs, ann_y_values[i] + 0.05, symbol, fontsize=12, color='red')

plt.title(f"ECG Signal - Record '{record_name}' - First {seconds_to_plot} Seconds", fontsize=16)
plt.xlabel("Time (seconds)", fontsize=12)
plt.ylabel("Voltage (mV)", fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np

ecg_signals=record.p_signal

type(ecg_signals)
# Out:
# numpy.ndarray

# %%
print(ecg_signals[5:])
# Out:
# [[-0.145 -0.065]
#  [-0.145 -0.065]
#  [-0.145 -0.065]
#  ...
#  [-0.675 -0.365]
#  [-0.765 -0.335]
#  [-1.28   0.   ]]

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.preprocessing import StandardScaler

raw_signals = record.p_signal
print(type(raw_signals))
print(f"Original shape (samples, channels): {raw_signals.shape}")
# Out:
# <class 'numpy.ndarray'>
# Original shape (samples, channels): (650000, 2)

# %%
raw_signals = record.p_signal

mlii_raw = raw_signals[:, 0]
v5_raw = raw_signals[:, 1]

summed_signal_raw = mlii_raw + v5_raw

print( mlii_raw.shape)
print(summed_signal_raw.shape)

print(f"  Original Mean: {np.mean(summed_signal_raw)}")
print(f"  Original Std Dev: {np.std(summed_signal_raw)}")

summed_signal_reshaped = summed_signal_raw.reshape(-1, 1)

scaler_summed = StandardScaler()
scaled_summed_signal = scaler_summed.fit_transform(summed_signal_reshaped)

print(f"\n--- 'AFTER' Scaling Summed Signal ---")
print(f"  Scaled Mean: {np.mean(scaled_summed_signal)}")
print(f"  Scaled Std Dev: {np.std(scaled_summed_signal)}")

print(scaled_summed_signal[:5])
# Out:
# (650000,)
# (650000,)
#   Original Mean: -0.4973334076923078
#   Original Std Dev: 0.3062989011772449
#
# --- 'AFTER' Scaling Summed Signal ---
#   Scaled Mean: 4.561465735045764e-16
#   Scaled Std Dev: 0.9999999999999998
# [[0.93808174]
#  [0.93808174]
#  [0.93808174]
#  [0.93808174]
#  [0.93808174]]

# %%
import wfdb.processing

fs = record.fs

xqrs = wfdb.processing.XQRS(sig=summed_signal_raw, fs=fs)
xqrs.detect()

detected_peaks = xqrs.qrs_inds
print("\n--- XQRS Detection (Experiment) ---")
print(annotation.sample[:10])

print(detected_peaks[:10])
# Out:
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
#
# --- XQRS Detection (Experiment) ---
# [  18   77  370  662  946 1231 1515 1809 2044 2402]
# [  75  369  661  945 1230 1513 1808 2043 2401 2704]

# %%
import wfdb.processing

fs = record.fs

xqrs = wfdb.processing.XQRS(sig=mlii_raw, fs=fs)
xqrs.detect()

detected_peaks = xqrs.qrs_inds
print("\n--- XQRS Detection (Experiment) ---")
print(annotation.sample[:10])

print(detected_peaks[:10])
# Out:
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
#
# --- XQRS Detection (Experiment) ---
# [  18   77  370  662  946 1231 1515 1809 2044 2402]
# [  76  370  662  946 1231 1515 1809 2044 2402 2705]

# %%
import numpy as np
import wfdb
import wfdb.processing


print("Running XQRS peak detection...")
fs = record.fs
xqrs = wfdb.processing.XQRS(sig=summed_signal_raw, fs=fs)
xqrs.detect()

detected_peaks = xqrs.qrs_inds
print(f"Found {len(detected_peaks)} peaks using XQRS.")


final_signal = scaled_summed_signal.flatten()

true_peaks = annotation.sample
true_labels = annotation.symbol

valid_beat_labels = ['N', 'L', 'R', 'B', 'A', 'a', 'J', 'S', 'V', 'r', 'F', 'e', 'j', 'n', 'E', '/', 'f', 'Q', '?']

# --- Configuration ---
window_size = 180
win_half_left = window_size // 2  # 90
win_half_right = window_size // 2 # 90
tolerance = int(0.1 * fs) # 100ms tolerance (e.g., 36 samples)

heartbeats = []
labels = []

print(window_size)

for xqrs_peak in detected_peaks:

    start = xqrs_peak - win_half_left
    end = xqrs_peak + win_half_right

    if start < 0 or end >= len(final_signal):
        continue

    distances = np.abs(true_peaks - xqrs_peak)
    closest_true_index = np.argmin(distances)
    if distances[closest_true_index] <= tolerance:
        label = true_labels[closest_true_index]

        if label in valid_beat_labels:
            segment = final_signal[start:end]
            heartbeats.append(segment)
            labels.append(label)

# --- Final Conversion ---
X_data = np.array(heartbeats)
y_data = np.array(labels)

print("\n--- Preprocessing Complete ---")
print(f"Shape of X_data (beats, features): {X_data.shape}")
print(f"Shape of y_data (labels,): {y_data.shape}")
print(f"Total valid beats found and segmented: {len(y_data)}")

print(y_data[:5])
# Out:
# Running XQRS peak detection...
# Learning initial signal parameters...
# Found 8 beats during learning. Initializing using learned parameters
# Running QRS detection...
# QRS detection complete.
# Found 2273 peaks using XQRS.
# 180
#
# --- Preprocessing Complete ---
# Shape of X_data (beats, features): (2271, 180)
# Shape of y_data (labels,): (2271,)
# Total valid beats found and segmented: 2271
# ['N' 'N' 'N' 'N' 'N']

# %%
import numpy as np
import wfdb
import wfdb.processing
from sklearn.preprocessing import StandardScaler
import os
from glob import glob
from tqdm import tqdm # For a helpful progress bar


data_dir = 'mit-bih-arrhythmia-database-1.0.0'

header_files = glob(os.path.join(data_dir, '*.hea'))
record_names = [os.path.basename(f).replace('.hea', '') for f in header_files]
record_names = [r for r in record_names if r.isdigit()]
record_names.sort()

print(f"Found {len(record_names)} records. Starting processing...")

all_X_data = []
all_y_data = []

# --- 3. Define Parameters ---
valid_beat_labels = ['N', 'L', 'R', 'B', 'A', 'a', 'J', 'S', 'V', 'r', 'F', 'e', 'j', 'n', 'E', '/', 'f', 'Q', '?']
window_size = 180
win_half_left = window_size // 2
win_half_right = window_size // 2

for record_name in tqdm(record_names):
    record_path = os.path.join(data_dir, record_name)

    try:
        # --- A: Load Data ---
        record = wfdb.rdrecord(record_path)
        annotation = wfdb.rdann(record_path, 'atr')
        fs = record.fs

        # --- B: Create Summed Signal (RAW) ---
        mlii_raw = record.p_signal[:, 0]
        v5_raw = record.p_signal[:, 1]
        summed_signal_raw = mlii_raw + v5_raw

        # --- C: Scale the Summed Signal ---
        # We re-fit the scaler for each record.
        summed_signal_reshaped = summed_signal_raw.reshape(-1, 1)
        scaler_summed = StandardScaler()
        scaled_summed_signal = scaler_summed.fit_transform(summed_signal_reshaped)
        final_signal = scaled_summed_signal.flatten() # 1D scaled signal

        # --- D: Run XQRS on RAW Signal ---
        xqrs = wfdb.processing.XQRS(sig=summed_signal_raw, fs=fs)
        # Pass verbose=False to stop it from printing "Learning..." 2273 times
        xqrs.detect(verbose=False)
        detected_peaks = xqrs.qrs_inds

        true_peaks = annotation.sample
        true_labels = annotation.symbol
        tolerance = int(0.1 * fs) # 100ms tolerance

        heartbeats = []
        labels = []

        for xqrs_peak in detected_peaks:
            start = xqrs_peak - win_half_left
            end = xqrs_peak + win_half_right

            if start < 0 or end >= len(final_signal):
                continue # Skip beats too close to the edge

            # Find the closest "true" label
            distances = np.abs(true_peaks - xqrs_peak)
            closest_true_index = np.argmin(distances)

            if distances[closest_true_index] <= tolerance:
                label = true_labels[closest_true_index]
                if label in valid_beat_labels:
                    segment = final_signal[start:end]
                    heartbeats.append(segment)
                    labels.append(label)

        # --- F: Append this file's data to global lists ---
        if len(heartbeats) > 0:
            all_X_data.append(np.array(heartbeats))
            all_y_data.append(np.array(labels))

    except Exception as e:
        print(f"\nError processing record {record_name}: {e}")

print("\n Processing Complete")

X_final_dataset = np.concatenate(all_X_data, axis=0)
y_final_dataset = np.concatenate(all_y_data, axis=0)

print(f"Final X_data shape  {X_final_dataset.shape}")
print(f"Final y_data shape {y_final_dataset.shape}")

# --- You can now save these or use them directly ---
np.save('/content/drive/MyDrive/mit_bih/X_data_summed.npy', X_final_dataset)
np.save('/content/drive/MyDrive/mit_bih/y_data_summed.npy', y_final_dataset)
# Out:
# Found 48 records. Starting processing...
# 100%|██████████| 48/48 [03:46<00:00,  4.73s/it]
#  Processing Complete
# Final X_data shape  (108008, 180)
# Final y_data shape (108008,)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight

# N: Normal ('N', 'L', 'R', 'e', 'j')
# S: Supraventricular ('A', 'a', 'J', 'S')
# V: Ventricular ('V', 'E')
# F: Fusion ('F')
# Q: Unknown ('Q', '?', '/', 'f')

label_mapping = {
    'N': 'N', 'L': 'N', 'R': 'N', 'e': 'N', 'j': 'N',
    'A': 'S', 'a': 'S', 'J': 'S', 'S': 'S',
    'V': 'V', 'E': 'V',
    'F': 'F',
    'Q': 'Q', '?': 'Q', '/': 'Q', 'f': 'Q',
    'B': 'N'

}

y_labels = y_final_dataset.copy()
y_categories = pd.Series(y_labels).map(label_mapping)


print("'Table 1' (Class Counts")
initial_counts = y_categories.value_counts()
print(initial_counts)
print(f"\nTotal beats (before dropping): {len(y_categories)}")
print(f"Beats not mapped (NaN): {y_categories.isna().sum()}")


# We create a filter 'mask' to select only the data we want
mask = y_categories.isin(['N', 'S', 'V', 'F'])

# Applying the mask to BOTH X and y
X_filtered = X_final_dataset[mask]
y_filtered = y_categories[mask]

print(f"Total heartbeats for training: {len(y_filtered)}")



print("\nSplitting ...")
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X_filtered,
    y_filtered,
    test_size=0.25,
    stratify=y_filtered,
    random_state=42
)

print("Splitting Train/Val ")
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val,
    y_train_val,
    test_size=0.20,
    stratify=y_train_val,
    random_state=42
)

print("\n Final Data Shapes ---")
print(f" {X_train.shape}, {y_train.shape}")
print(f" {X_val.shape}, {y_val.shape}")
print(f"   {X_test.shape}, {y_test.shape}")


print(y_train.value_counts())


classes = np.unique(y_train)

weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=y_train
)

# Create a dictionary for easy use (e.g., in Keras)
class_weight_dict = dict(zip(classes, weights))

print(f"Classes: {classes}")
print(f"Weights: {weights}")
print(class_weight_dict)
# Out:
# 'Table 1' (Class Counts
# N    90283
# Q     8024
# V     6222
# S     2701
# F      778
# Name: count, dtype: int64
#
# Total beats (before dropping): 108008
# Beats not mapped (NaN): 0
# Total heartbeats for training: 99984
#
# Splitting ...
# Splitting Train/Val
#
#  Final Data Shapes ---
#  (59990, 180), (59990,)
#  (14998, 180), (14998,)
#    (24996, 180), (24996,)
# N    54169
# V     3734
# S     1621
# F      466
# Name: count, dtype: int64
# Classes: ['F' 'N' 'S' 'V']
# Weights: [32.18347639  0.276865    9.25200494  4.01647027]
# {'F': np.float64(32.183476394849784), 'N': np.float64(0.2768649965847625), 'S': np.float64(9.25200493522517), 'V': np.float64(4.016470273165506)}

# %%
import numpy as np
import os

save_dir = '/content/drive/MyDrive/mit_bih/'

os.makedirs(save_dir, exist_ok=True)

print(f"Saving files to: {save_dir}\n")

try:
    # Save Training data
    np.save(os.path.join(save_dir, 'X_train.npy'), X_train)
    np.save(os.path.join(save_dir, 'y_train.npy'), y_train)
    print("Saved X_train.npy and y_train.npy")

    # Save Validation data
    np.save(os.path.join(save_dir, 'X_val.npy'), X_val)
    np.save(os.path.join(save_dir, 'y_val.npy'), y_val)
    print("Saved X_val.npy and y_val.npy")

    # Save Testing data
    np.save(os.path.join(save_dir, 'X_test.npy'), X_test)
    np.save(os.path.join(save_dir, 'y_test.npy'), y_test)
    print("Saved X_test.npy and y_test.npy")

    print("\n saved successfully.")

except Exception as e:
    print(f"error  {e}")
# Out:
# Saving files to: /content/drive/MyDrive/mit_bih/
#
# Saved X_train.npy and y_train.npy
# Saved X_val.npy and y_val.npy
# Saved X_test.npy and y_test.npy
#
#  saved successfully.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv1D, MaxPooling1D, Dropout, BatchNormalization,
    Flatten, Dense
)

from tensorflow.keras.optimizers.legacy import Adam
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report


label_encoder = LabelEncoder()

y_train_int = label_encoder.fit_transform(y_train)
y_val_int = label_encoder.transform(y_val)
y_test_int = label_encoder.transform(y_test)

print(f"Original labels: {y_train[:5]}")
print(f"Encoded labels: {y_train_int[:5]}")
print(f"Classes: {label_encoder.classes_}")



class_weight_dict_int = {}
for i, cls in enumerate(label_encoder.classes_):
    class_weight_dict_int[i] = class_weight_dict[cls]

print(class_weight_dict_int)



X_train_cnn = np.expand_dims(X_train, axis=-1)
X_val_cnn = np.expand_dims(X_val, axis=-1)
X_test_cnn = np.expand_dims(X_test, axis=-1)

print(f"Old X_train  {X_train.shape}")
print(f"New X_train  {X_train_cnn.shape}")
# Out:
# Original labels: 49479    N
# 13775    N
# 12518    N
# 68140    N
# 76487    N
# dtype: object
# Encoded labels: [1 1 1 1 1]
# Classes: ['F' 'N' 'S' 'V']
# {0: np.float64(32.183476394849784), 1: np.float64(0.2768649965847625), 2: np.float64(9.25200493522517), 3: np.float64(4.016470273165506)}
# Old X_train  (59990, 180)
# New X_train  (59990, 180, 1)

# %%
import joblib
np.save(os.path.join(save_dir, 'class_weights.npy'), class_weight_dict_int)
print("Saved class_weights.npy")

    # 2. Save the Label Encoder
joblib.dump(label_encoder, os.path.join(save_dir, 'label_encoder.joblib'))
print("Saved label_encoder.joblib")
# Out:
# Saved class_weights.npy
# Saved label_encoder.joblib

# %%
filters = 64
kernel = 3
blocks = 2
input_shape = (X_train_cnn.shape[1], X_train_cnn.shape[2]) # (180, 1)

model = Sequential()

for i in range(blocks):
    print(f"Adding Block {i+1}")

    #  Conv1D (filter, (kernel,), 'relu') ---
    if i == 0:
        model.add(Conv1D(
            filters=filters,
            kernel_size=kernel,
            activation='relu',
            input_shape=input_shape
        ))
    else:
        model.add(Conv1D(
            filters=filters,
            kernel_size=kernel,
            activation='relu'
        ))

    # --- Line 4: Conv1D (filter, (kernel,), 'relu') ---
    model.add(Conv1D(
        filters=filters,
        kernel_size=kernel,
        activation='relu'
    ))

    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.2))
    model.add(BatchNormalization())


model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))


model.add(Dense(4, activation='softmax'))

model.summary()
# Out:
# Adding Block 1
# Adding Block 2
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 178, 64)        │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 176, 64)        │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 88, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 88, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 88, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 86, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 84, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 42, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 42, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 42, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2688)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,376,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,416,644 (5.40 MB)
#  Trainable params: 1,416,388 (5.40 MB)
#  Non-trainable params: 256 (1.00 KB)

# %%
import numpy as np
import os
import tensorflow as tf
from sklearn.metrics import classification_report
from tensorflow.keras.optimizers import Adam
print("\n--- Compiling Model (Phase 1) ---")

optimizer = Adam(learning_rate=0.001)
model.compile(
    loss='sparse_categorical_crossentropy', # For integer labels
    optimizer=optimizer,
    metrics=['accuracy']
)

print("Model compiled successfully.")

print("\n--- Training Model (Phase 2) ---")

epochs = 50

history = model.fit(
    X_train_cnn,                  # input_data
    y_train_int,
    batch_size=512,               # batch_size
    epochs=epochs,                # epochs

    validation_data=(X_val_cnn, y_val_int),

    class_weight=class_weight_dict_int # cls_weight
)

print("Model training complete.")

save_dir = '/content/drive/MyDrive/mit_bih/'
model_name = 'my_summed_signal_model.keras'
model_save_path = os.path.join(save_dir, model_name)

print(f"\nSaving model to: {model_save_path}")
try:
    model.save(model_save_path)
    print(" Model saved successfully.")
except Exception as e:
    print(f"\n{e}")
# --------------------------------

print("\n--- Evaluating Model ")

test_loss, test_accuracy = model.evaluate(X_test_cnn, y_test_int, verbose=0)
print(f"\nTest Accuracy: {test_accuracy * 100:.2f}%")
print(f"Test Loss: {test_loss:.4f}")

predictions_prob = model.predict(X_test_cnn)

predictions_class = np.argmax(predictions_prob, axis=1)

print("\n--- Classification Report (Test Data) ---")
print(classification_report(
    y_test_int,
    predictions_class,
    target_names=label_encoder.classes_ # Map back to 'N', 'S', 'V', 'F'
))
# Out:
# --- Compiling Model (Phase 1) ---
# Model compiled successfully.
#
# --- Training Model (Phase 2) ---
# Epoch 1/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 80s 645ms/step - accuracy: 0.5418 - loss: 1.2107 - val_accuracy: 0.8909 - val_loss: 0.7116
# Epoch 2/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 76s 644ms/step - accuracy: 0.7589 - loss: 0.4851 - val_accuracy: 0.6127 - val_loss: 0.8437
# Epoch 3/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 80s 672ms/step - accuracy: 0.8153 - loss: 0.3753 - val_accuracy: 0.5393 - val_loss: 1.0151
# Epoch 4/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 73s 615ms/step - accuracy: 0.8537 - loss: 0.2963 - val_accuracy: 0.8246 - val_loss: 0.4872
# Epoch 5/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 72s 610ms/step - accuracy: 0.8866 - loss: 0.2337 - val_accuracy: 0.8716 - val_loss: 0.3721
# Epoch 6/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 83s 616ms/step - accuracy: 0.8422 - loss: 0.2784 - val_accuracy: 0.9197 - val_loss: 0.2504
# Epoch 7/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 75s 632ms/step - accuracy: 0.8974 - loss: 0.2174 - val_accuracy: 0.9042 - val_loss: 0.2869
# Epoch 8/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 73s 616ms/step - accuracy: 0.9202 - loss: 0.1594 - val_accuracy: 0.8708 - val_loss: 0.3723
# Epoch 9/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 623ms/step - accuracy: 0.9193 - loss: 0.1412 - val_accuracy: 0.9219 - val_loss: 0.2485
# Epoch 10/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 621ms/step - accuracy: 0.9284 - loss: 0.1266 - val_accuracy: 0.9299 - val_loss: 0.2440
# Epoch 11/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 73s 621ms/step - accuracy: 0.9396 - loss: 0.1157 - val_accuracy: 0.9542 - val_loss: 0.1409
# Epoch 12/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 623ms/step - accuracy: 0.9456 - loss: 0.1096 - val_accuracy: 0.9480 - val_loss: 0.1749
# Epoch 13/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 74s 621ms/step - accuracy: 0.9510 - loss: 0.0886 - val_accuracy: 0.9613 - val_loss: 0.1347
# Epoch 14/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 624ms/step - accuracy: 0.9513 - loss: 0.1005 - val_accuracy: 0.9424 - val_loss: 0.1881
# Epoch 15/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 80s 609ms/step - accuracy: 0.9324 - loss: 0.1351 - val_accuracy: 0.9573 - val_loss: 0.1517
# Epoch 16/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 72s 610ms/step - accuracy: 0.9517 - loss: 0.1016 - val_accuracy: 0.9451 - val_loss: 0.1875
# Epoch 17/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 608ms/step - accuracy: 0.9453 - loss: 0.0972 - val_accuracy: 0.9388 - val_loss: 0.1974
# Epoch 18/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 608ms/step - accuracy: 0.9495 - loss: 0.0910 - val_accuracy: 0.9551 - val_loss: 0.1497
# Epoch 19/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 73s 620ms/step - accuracy: 0.9600 - loss: 0.0833 - val_accuracy: 0.9503 - val_loss: 0.1753
# Epoch 20/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 71s 605ms/step - accuracy: 0.9576 - loss: 0.0696 - val_accuracy: 0.9660 - val_loss: 0.1242
# Epoch 21/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 84s 620ms/step - accuracy: 0.9666 - loss: 0.0680 - val_accuracy: 0.9708 - val_loss: 0.1173
# Epoch 22/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 72s 608ms/step - accuracy: 0.9745 - loss: 0.0466 - val_accuracy: 0.9601 - val_loss: 0.1343
# Epoch 23/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 605ms/step - accuracy: 0.9705 - loss: 0.0523 - val_accuracy: 0.9687 - val_loss: 0.1120
# Epoch 24/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 71s 603ms/step - accuracy: 0.9742 - loss: 0.0425 - val_accuracy: 0.9617 - val_loss: 0.1382
# Epoch 25/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 604ms/step - accuracy: 0.9702 - loss: 0.0499 - val_accuracy: 0.9699 - val_loss: 0.1201
# Epoch 26/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 71s 605ms/step - accuracy: 0.9778 - loss: 0.0370 - val_accuracy: 0.9523 - val_loss: 0.1653
# Epoch 27/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 607ms/step - accuracy: 0.9649 - loss: 0.0579 - val_accuracy: 0.9701 - val_loss: 0.1226
# Epoch 28/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 84s 624ms/step - accuracy: 0.9790 - loss: 0.0349 - val_accuracy: 0.9735 - val_loss: 0.1100
# Epoch 29/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 80s 612ms/step - accuracy: 0.9792 - loss: 0.0360 - val_accuracy: 0.9683 - val_loss: 0.1191
# Epoch 30/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 615ms/step - accuracy: 0.9800 - loss: 0.0370 - val_accuracy: 0.9671 - val_loss: 0.1311
# Epoch 31/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 612ms/step - accuracy: 0.9762 - loss: 0.0437 - val_accuracy: 0.9753 - val_loss: 0.1071
# Epoch 32/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 615ms/step - accuracy: 0.9711 - loss: 0.0529 - val_accuracy: 0.9531 - val_loss: 0.1919
# Epoch 33/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 612ms/step - accuracy: 0.9623 - loss: 0.0809 - val_accuracy: 0.9575 - val_loss: 0.1557
# Epoch 34/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 611ms/step - accuracy: 0.9729 - loss: 0.0603 - val_accuracy: 0.9621 - val_loss: 0.1476
# Epoch 35/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 73s 616ms/step - accuracy: 0.9685 - loss: 0.0601 - val_accuracy: 0.9547 - val_loss: 0.1696
# Epoch 36/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 72s 612ms/step - accuracy: 0.9727 - loss: 0.0525 - val_accuracy: 0.9729 - val_loss: 0.1158
# Epoch 37/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 72s 613ms/step - accuracy: 0.9803 - loss: 0.0393 - val_accuracy: 0.9727 - val_loss: 0.1097
# Epoch 38/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 74s 630ms/step - accuracy: 0.9800 - loss: 0.0341 - val_accuracy: 0.9608 - val_loss: 0.1538
# Epoch 39/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 74s 628ms/step - accuracy: 0.9308 - loss: 0.1618 - val_accuracy: 0.9535 - val_loss: 0.1679
# Epoch 40/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 80s 611ms/step - accuracy: 0.9726 - loss: 0.0618 - val_accuracy: 0.9747 - val_loss: 0.1030
# Epoch 41/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 81s 607ms/step - accuracy: 0.9800 - loss: 0.0400 - val_accuracy: 0.9698 - val_loss: 0.1261
# Epoch 42/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 73s 619ms/step - accuracy: 0.9740 - loss: 0.0538 - val_accuracy: 0.9650 - val_loss: 0.1484
# Epoch 43/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 623ms/step - accuracy: 0.9767 - loss: 0.0536 - val_accuracy: 0.9723 - val_loss: 0.1111
# Epoch 44/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 80s 605ms/step - accuracy: 0.9798 - loss: 0.0509 - val_accuracy: 0.9739 - val_loss: 0.1096
# Epoch 45/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 84s 618ms/step - accuracy: 0.9833 - loss: 0.0332 - val_accuracy: 0.9759 - val_loss: 0.1052
# Epoch 46/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 80s 603ms/step - accuracy: 0.9846 - loss: 0.0283 - val_accuracy: 0.9753 - val_loss: 0.1115
# Epoch 47/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 82s 608ms/step - accuracy: 0.9872 - loss: 0.0281 - val_accuracy: 0.9785 - val_loss: 0.1040
# Epoch 48/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 73s 616ms/step - accuracy: 0.9891 - loss: 0.0194 - val_accuracy: 0.9781 - val_loss: 0.1071
# Epoch 49/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 80s 604ms/step - accuracy: 0.9833 - loss: 0.0259 - val_accuracy: 0.9755 - val_loss: 0.1117
# Epoch 50/50
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 71s 603ms/step - accuracy: 0.9865 - loss: 0.0230 - val_accuracy: 0.9771 - val_loss: 0.1030
# Model training complete.
#
# Saving model to: /content/drive/MyDrive/mit_bih/my_summed_signal_model.keras
#  Model saved successfully.
#
# --- Evaluating Model
#
# Test Accuracy: 97.78%
# Test Loss: 0.0993
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step
#
# --- Classification Report (Test Data) ---
#               precision    recall  f1-score   support
#
#            F       0.55      0.75      0.64       195
#            N       0.99      0.98      0.99     22571
#            S       0.75      0.87      0.81       675
#            V       0.95      0.96      0.95      1555
#
#     accuracy                           0.98     24996
#    macro avg       0.81      0.89      0.85     24996
# weighted avg       0.98      0.98      0.98     24996

# %%
# Out:
# Collecting streamlit
#   Downloading streamlit-1.51.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.3.0)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow<22,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.45)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.10.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.51.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 31.4 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 60.0 MB/s eta 0:00:00
# Installing collected packages: pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.51.0

# %%
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import scipy.signal as sp
import os

def add_baseline_wander(sig, fs=360):
    t = np.arange(len(sig)) / fs
    drift = 0.1 * np.sin(2*np.pi*0.3*t) + 0.2 * np.sin(2*np.pi*0.1*t)
    return sig + drift

def add_powerline(sig, fs=360):
    t = np.arange(len(sig)) / fs
    noise = 0.05 * np.sin(2*np.pi*50*t)
    return sig + noise

def add_gaussian(sig):
    return sig + np.random.normal(0, 0.05, sig.shape)

def add_emg(sig):
    emg = np.random.normal(0, 0.1, sig.shape)
    emg = sp.lfilter([1], [1, -0.99], emg)
    return sig + emg

data_dir = '/content/drive/MyDrive/mit_bih/'
CLEAN_DATA_PATH = os.path.join(data_dir, 'X_train.npy')
NOISY_DATA_PATH = os.path.join(data_dir, 'X_train_augmented_all_noise.npy')

X_train_clean = np.load(CLEAN_DATA_PATH)

X_train_noisy = []
for beat in X_train_clean:
    noisy_beat = beat.copy()
    noisy_beat = add_baseline_wander(noisy_beat)
    noisy_beat = add_powerline(noisy_beat)
    noisy_beat = add_gaussian(noisy_beat)
    noisy_beat = add_emg(noisy_beat)
    X_train_noisy.append(noisy_beat)

X_train_noisy = np.array(X_train_noisy)

X_train_noisy_cnn = np.expand_dims(X_train_noisy, axis=-1)

np.save(NOISY_DATA_PATH, X_train_noisy_cnn)

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- Ensure these files are in the same folder as this script ---
CLEAN_DATA_PATH = 'X_train.npy'
NOISY_DATA_PATH = 'X_train_augmented_all_noise.npy'

# Load the data
X_clean = np.load(CLEAN_DATA_PATH)
X_noisy_cnn = np.load(NOISY_DATA_PATH)

# Prepare noisy data for plotting (remove the final single dimension)
X_noisy = np.squeeze(X_noisy_cnn)

# Select a few samples for visualization
num_samples = 3
indices = np.arange(num_samples)

fig, axes = plt.subplots(num_samples, 1, figsize=(15, 5 * num_samples))
fig.suptitle('Comparison of Clean vs. Augmented Noisy ECG Heartbeats', fontsize=16)

time_vector = np.arange(X_clean.shape[1])

for i, idx in enumerate(indices):
    ax = axes[i]

    # Plot Clean Signal
    ax.plot(time_vector, X_clean[idx, :], label='Clean Signal', color='blue', linewidth=2)

    # Plot Noisy Signal (Overlaid)
    ax.plot(time_vector, X_noisy[idx, :], label='Noisy Augmented Signal', color='red', alpha=0.6, linewidth=1.5)

    ax.set_title(f"Heartbeat Sample {idx+1}")
    ax.set_xlabel("Sample Index (Time)")
    ax.set_ylabel("Normalized Amplitude")
    ax.legend()
    ax.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
import joblib
import os

# --- 1. Define File Paths ---
data_dir = '/content/drive/MyDrive/mit_bih/'
MODEL_PATH = os.path.join(data_dir, 'my_summed_signal_model.keras')
X_NOISY_PATH = os.path.join(data_dir, 'X_train_augmented_all_noise.npy')
Y_TRAIN_PATH = os.path.join(data_dir, 'y_train.npy')
WEIGHTS_PATH = os.path.join(data_dir, 'class_weights.npy')
ENCODER_PATH = os.path.join(data_dir, 'label_encoder.joblib')

# --- 2. Load Data and Auxiliary Files ---
# Load the newly augmented noisy data
X_train_noisy_cnn = np.load(X_NOISY_PATH)
y_train = np.load(Y_TRAIN_PATH, allow_pickle=True)

# Load helper files
class_weight_dict_int = np.load(WEIGHTS_PATH, allow_pickle=True).item()
label_encoder = joblib.load(ENCODER_PATH)

# --- 3. Encode Labels for Training ---
y_train_int = label_encoder.transform(y_train)

# --- 4. Load Pre-trained Model ---
model = load_model(MODEL_PATH)

# --- 5. Fine-Tuning Configuration ---
# Set a very low learning rate for fine-tuning
new_learning_rate = 1e-5
model.trainable = True

optimizer_ft = Adam(learning_rate=new_learning_rate)

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=optimizer_ft,
    metrics=['accuracy']
)

# --- 6. Fine-Tune the Model ---
# Train for a small number of epochs (e.g., 10) on the noisy data
print("Starting fine-tuning on noisy data...")
history_ft = model.fit(
    X_train_noisy_cnn,
    y_train_int,
    batch_size=512,
    epochs=10,
    validation_split=0.1,
    class_weight=class_weight_dict_int,
    verbose=1
)

# --- 7. Save the Fine-Tuned Model ---
model_ft_name = 'my_fine_tuned_noisy_model.keras'
model_ft_save_path = os.path.join(data_dir, model_ft_name)
model.save(model_ft_save_path)

print(f"\nFine-tuning complete. New model saved to: {model_ft_save_path}")
# Out:
# Starting fine-tuning on noisy data...
# Epoch 1/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 69s 616ms/step - accuracy: 0.8747 - loss: 1.2764 - val_accuracy: 0.9032 - val_loss: 0.3835
# Epoch 2/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 82s 618ms/step - accuracy: 0.8592 - loss: 1.0904 - val_accuracy: 0.8906 - val_loss: 0.4336
# Epoch 3/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 83s 627ms/step - accuracy: 0.8503 - loss: 0.9259 - val_accuracy: 0.8803 - val_loss: 0.4667
# Epoch 4/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 64s 608ms/step - accuracy: 0.8399 - loss: 0.8036 - val_accuracy: 0.8726 - val_loss: 0.4870
# Epoch 5/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 82s 608ms/step - accuracy: 0.8338 - loss: 0.8041 - val_accuracy: 0.8658 - val_loss: 0.5084
# Epoch 6/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 64s 602ms/step - accuracy: 0.8262 - loss: 0.7244 - val_accuracy: 0.8645 - val_loss: 0.5162
# Epoch 7/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 65s 611ms/step - accuracy: 0.8198 - loss: 0.6453 - val_accuracy: 0.8618 - val_loss: 0.5194
# Epoch 8/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 63s 593ms/step - accuracy: 0.8147 - loss: 0.6487 - val_accuracy: 0.8571 - val_loss: 0.5217
# Epoch 9/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 65s 615ms/step - accuracy: 0.8172 - loss: 0.6823 - val_accuracy: 0.8571 - val_loss: 0.5241
# Epoch 10/10
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 65s 611ms/step - accuracy: 0.8118 - loss: 0.5749 - val_accuracy: 0.8580 - val_loss: 0.5197
#
# Fine-tuning complete. New model saved to: /content/drive/MyDrive/mit_bih/my_fine_tuned_noisy_model.keras

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
import joblib
import os

# --- Define File Paths ---
# NOTE: Please ensure all these files exist in this exact path or adjust the directory.
data_dir = '/content/drive/MyDrive/mit_bih/'
MODEL_PATH = os.path.join(data_dir, 'my_fine_tuned_noisy_model.keras')
X_TEST_PATH = os.path.join(data_dir, 'X_test.npy')
Y_TEST_PATH = os.path.join(data_dir, 'y_test.npy')
ENCODER_PATH = os.path.join(data_dir, 'label_encoder.joblib')

# Load the fine-tuned model and test data
try:
    model_ft = load_model(MODEL_PATH)
    X_test = np.load(X_TEST_PATH)
    y_test = np.load(Y_TEST_PATH, allow_pickle=True)
    label_encoder = joblib.load(ENCODER_PATH)
except FileNotFoundError as e:
    print(f"Error loading required files: {e}. Please ensure all files are in the specified path.")
    # Exit if files aren't found
    raise

# Prepare Test Data
X_test_cnn = np.expand_dims(X_test, axis=-1)
y_test_int = label_encoder.transform(y_test)
target_names = label_encoder.classes_

# Evaluate Fine-Tuned Model
print("Evaluating fine-tuned model on the clean test set...")
predictions_prob = model_ft.predict(X_test_cnn)
predictions_class = np.argmax(predictions_prob, axis=1)

print("\n--- Classification Report (Fine-Tuned Model) ---")
print(classification_report(
    y_test_int,
    predictions_class,
    target_names=target_names
))

test_loss, test_accuracy = model_ft.evaluate(X_test_cnn, y_test_int, verbose=0)
print(f"\nOverall Test Accuracy (Fine-Tuned): {test_accuracy * 100:.2f}%")
# Out:
# Evaluating fine-tuned model on the clean test set...
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step
#
# --- Classification Report (Fine-Tuned Model) ---
#               precision    recall  f1-score   support
#
#            F       0.11      0.90      0.20       195
#            N       1.00      0.90      0.95     22571
#            S       0.50      0.91      0.64       675
#            V       0.88      0.96      0.92      1555
#
#     accuracy                           0.91     24996
#    macro avg       0.62      0.92      0.68     24996
# weighted avg       0.97      0.91      0.93     24996
#
#
# Overall Test Accuracy (Fine-Tuned): 90.78%

# %%
import numpy as np
import scipy.signal as sp
import os

# --- Noise Functions (Copied from Augmentation Step) ---
def add_baseline_wander(sig, fs=360):
    t = np.arange(len(sig)) / fs
    drift = 0.1 * np.sin(2*np.pi*0.3*t) + 0.2 * np.sin(2*np.pi*0.1*t)
    return sig + drift

def add_powerline(sig, fs=360):
    t = np.arange(len(sig)) / fs
    noise = 0.05 * np.sin(2*np.pi*50*t)
    return sig + noise

def add_gaussian(sig):
    return sig + np.random.normal(0, 0.05, sig.shape)

def add_emg(sig):
    emg = np.random.normal(0, 0.1, sig.shape)
    emg = sp.lfilter([1], [1, -0.99], emg)
    return sig + emg

# --- File Paths ---
data_dir = '/content/drive/MyDrive/mit_bih/'
X_TEST_PATH = os.path.join(data_dir, 'X_test.npy')
X_TEST_NOISY_PATH = os.path.join(data_dir, 'X_test_noisy.npy')

# Load clean test data
X_test_clean = np.load(X_TEST_PATH)

# Apply all noise types to create the noisy test set
X_test_noisy = []
for beat in X_test_clean:
    noisy_beat = beat.copy()
    noisy_beat = add_baseline_wander(noisy_beat)
    noisy_beat = add_powerline(noisy_beat)
    noisy_beat = add_gaussian(noisy_beat)
    noisy_beat = add_emg(noisy_beat)
    X_test_noisy.append(noisy_beat)

X_test_noisy = np.array(X_test_noisy)

# Reshape for CNN input (samples, 180, 1)
X_test_noisy_cnn = np.expand_dims(X_test_noisy, axis=-1)

# Save the new noisy test data
np.save(X_TEST_NOISY_PATH, X_test_noisy_cnn)

print(f"Noisy test set generated and saved to: {X_TEST_NOISY_PATH}")
# Out:
# Noisy test set generated and saved to: /content/drive/MyDrive/mit_bih/X_test_noisy.npy

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
import joblib
import os

# --- File Paths ---
data_dir = '/content/drive/MyDrive/mit_bih/'
# Load BOTH models:
MODEL_ORIGINAL_PATH = os.path.join(data_dir, 'my_summed_signal_model.keras') # Original clean model
MODEL_FT_PATH = os.path.join(data_dir, 'my_fine_tuned_noisy_model.keras')  # Fine-tuned model

# Load data/helpers:
X_TEST_NOISY_PATH = os.path.join(data_dir, 'X_test_noisy.npy')
Y_TEST_PATH = os.path.join(data_dir, 'y_test.npy')
ENCODER_PATH = os.path.join(data_dir, 'label_encoder.joblib')

# Load models, data, and helpers
model_original = load_model(MODEL_ORIGINAL_PATH)
model_ft = load_model(MODEL_FT_PATH)
X_test_noisy_cnn = np.load(X_TEST_NOISY_PATH)
y_test = np.load(Y_TEST_PATH, allow_pickle=True)
label_encoder = joblib.load(ENCODER_PATH)

y_test_int = label_encoder.transform(y_test)
target_names = label_encoder.classes_

def evaluate_model(model, X_data, y_true_int, name):
    """Predicts, evaluates, and prints report for a given model."""
    print(f"\n===== EVALUATING: {name} =====")
    predictions_prob = model.predict(X_data, verbose=0)
    predictions_class = np.argmax(predictions_prob, axis=1)

    loss, accuracy = model.evaluate(X_data, y_true_int, verbose=0)

    print(f"Overall Accuracy: {accuracy * 100:.2f}%")
    print("\n--- Classification Report ---")
    print(classification_report(
        y_true_int,
        predictions_class,
        target_names=target_names
    ))
    return accuracy

# Run the comparative evaluation
print("Starting comparative evaluation on the NOISY TEST SET...")
accuracy_original = evaluate_model(model_original, X_test_noisy_cnn, y_test_int, "Original Model (Clean Trained)")
accuracy_ft = evaluate_model(model_ft, X_test_noisy_cnn, y_test_int, "Fine-Tuned Model (Noisy Augmented)")

print("\n--- Summary ---")
if accuracy_ft > accuracy_original:
    print("✅ SUCCESS! Fine-tuning improved robustness against noise.")
else:
    print("❌ FAILURE. Fine-tuning did not improve robustness. The noise was too extreme.")
# Out:
# Starting comparative evaluation on the NOISY TEST SET...
#
# ===== EVALUATING: Original Model (Clean Trained) =====
# Overall Accuracy: 90.77%
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            F       0.27      0.19      0.22       195
#            N       0.97      0.92      0.95     22571
#            S       0.37      0.68      0.48       675
#            V       0.60      0.85      0.70      1555
#
#     accuracy                           0.91     24996
#    macro avg       0.55      0.66      0.59     24996
# weighted avg       0.93      0.91      0.92     24996
#
#
# ===== EVALUATING: Fine-Tuned Model (Noisy Augmented) =====
# Overall Accuracy: 84.63%
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            F       0.09      0.64      0.16       195
#            N       0.99      0.85      0.91     22571
#            S       0.26      0.79      0.40       675
#            V       0.62      0.91      0.74      1555
#
#     accuracy                           0.85     24996
#    macro avg       0.49      0.80      0.55     24996
# weighted avg       0.94      0.85      0.88     24996
#
#
# --- Summary ---
# ❌ FAILURE. Fine-tuning did not improve robustness. The noise was too extreme.

# %%
import numpy as np
import scipy.signal as sp
import os

# --- Reduced Noise Parameters (Approx. 75% reduction from previous attempt) ---
# This significantly lowers the intensity to prevent over-degradation
GAUSSIAN_STD_NEW = 0.0125
PLI_AMPLITUDE_NEW = 0.0125
BW_AMPLITUDE_1_NEW = 0.025
BW_AMPLITUDE_2_NEW = 0.050

def add_baseline_wander_reduced(sig, fs=360):
    t = np.arange(len(sig)) / fs
    drift = BW_AMPLITUDE_1_NEW * np.sin(2*np.pi*0.3*t) + BW_AMPLITUDE_2_NEW * np.sin(2*np.pi*0.1*t)
    return sig + drift

def add_powerline_reduced(sig, fs=360):
    t = np.arange(len(sig)) / fs
    noise = PLI_AMPLITUDE_NEW * np.sin(2*np.pi*50*t)
    return sig + noise

def add_gaussian_reduced(sig):
    return sig + np.random.normal(0, GAUSSIAN_STD_NEW, sig.shape)

def add_emg_reduced(sig):
    # EMG amplitude also reduced
    emg = np.random.normal(0, GAUSSIAN_STD_NEW * 2, sig.shape)
    emg = sp.lfilter([1], [1, -0.99], emg)
    return sig + emg

# --- File Paths ---
data_dir = '/content/drive/MyDrive/mit_bih/'
CLEAN_DATA_PATH = os.path.join(data_dir, 'X_train.npy')
Y_TRAIN_PATH = os.path.join(data_dir, 'y_train.npy')
X_TRAIN_MIXED_PATH = os.path.join(data_dir, 'X_train_mixed_reduced_noise.npy')
Y_TRAIN_MIXED_PATH = os.path.join(data_dir, 'y_train_mixed_reduced_noise.npy')

# Load clean training data and labels
X_train_clean = np.load(CLEAN_DATA_PATH)
y_train_clean = np.load(Y_TRAIN_PATH, allow_pickle=True)

# Generate a second, equal-sized noisy dataset (using reduced noise)
X_train_reduced_noisy = []
for beat in X_train_clean:
    # Sequentially apply all four reduced noise types
    noisy_beat = beat.copy()
    noisy_beat = add_baseline_wander_reduced(noisy_beat)
    noisy_beat = add_powerline_reduced(noisy_beat)
    noisy_beat = add_gaussian_reduced(noisy_beat)
    noisy_beat = add_emg_reduced(noisy_beat)
    X_train_reduced_noisy.append(noisy_beat)

X_train_reduced_noisy = np.array(X_train_reduced_noisy)

# --- Combine Data (50% Clean, 50% Noisy) ---
X_train_mixed = np.concatenate([X_train_clean, X_train_reduced_noisy], axis=0)
y_train_mixed = np.concatenate([y_train_clean, y_train_clean], axis=0)

# Reshape for CNN input: (samples, 180, 1)
X_train_mixed_cnn = np.expand_dims(X_train_mixed, axis=-1)

# Save the new mixed training data and labels
np.save(X_TRAIN_MIXED_PATH, X_train_mixed_cnn)
np.save(Y_TRAIN_MIXED_PATH, y_train_mixed)

print(f"Mixed (50% Clean / 50% Low-Noise) dataset created and saved. New total size: {X_train_mixed_cnn.shape}")
# Out:
# Mixed (50% Clean / 50% Low-Noise) dataset created and saved. New total size: (119980, 180, 1)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
import joblib
import os

# --- File Paths ---
data_dir = '/content/drive/MyDrive/mit_bih/'
MODEL_PATH = os.path.join(data_dir, 'my_summed_signal_model.keras')
X_MIXED_PATH = os.path.join(data_dir, 'X_train_mixed_reduced_noise.npy')
Y_MIXED_PATH = os.path.join(data_dir, 'y_train_mixed_reduced_noise.npy')
ENCODER_PATH = os.path.join(data_dir, 'label_encoder.joblib')

# --- Load Data and Auxiliary Files ---
X_train_mixed_cnn = np.load(X_MIXED_PATH)
y_train_mixed = np.load(Y_MIXED_PATH, allow_pickle=True)
label_encoder = joblib.load(ENCODER_PATH)

# --- Prepare Labels and Weights ---
y_train_mixed_int = label_encoder.transform(y_train_mixed)
classes = np.unique(y_train_mixed)

# Re-calculate class weights based on the new, doubled dataset
weights = compute_class_weight(
    class_weight='balanced',
    classes=classes,
    y=y_train_mixed
)
class_weight_dict_int = dict(zip(label_encoder.transform(classes), weights))


# --- Load Model and Configure Fine-Tuning ---
model = load_model(MODEL_PATH)
new_learning_rate = 1e-5
model.trainable = True

optimizer_ft = Adam(learning_rate=new_learning_rate)

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=optimizer_ft,
    metrics=['accuracy']
)

# --- Fine-Tune the Model (v2) ---
print("Starting Fine-Tuning V2 on Mixed (50% Clean / 50% Low-Noise) Data...")
model.fit(
    X_train_mixed_cnn,
    y_train_mixed_int,
    batch_size=512,
    epochs=10,
    validation_split=0.1,
    class_weight=class_weight_dict_int,
    verbose=1
)

# --- Save the Fine-Tuned Model v2 ---
model_ft_v2_name = 'my_fine_tuned_v2_mixed_low_noise_model.keras'
model_ft_v2_save_path = os.path.join(data_dir, model_ft_v2_name)
model.save(model_ft_v2_save_path)

print(f"\nFine-Tuning V2 complete. New model saved to: {model_ft_v2_save_path}")
# Out:
# Starting Fine-Tuning V2 on Mixed (50% Clean / 50% Low-Noise) Data...
# Epoch 1/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 138s 609ms/step - accuracy: 0.9866 - loss: 0.0368 - val_accuracy: 0.9911 - val_loss: 0.0310
# Epoch 2/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 128s 609ms/step - accuracy: 0.9861 - loss: 0.0334 - val_accuracy: 0.9906 - val_loss: 0.0317
# Epoch 3/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 140s 598ms/step - accuracy: 0.9861 - loss: 0.0288 - val_accuracy: 0.9905 - val_loss: 0.0314
# Epoch 4/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 128s 605ms/step - accuracy: 0.9863 - loss: 0.0275 - val_accuracy: 0.9907 - val_loss: 0.0313
# Epoch 5/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 137s 580ms/step - accuracy: 0.9871 - loss: 0.0233 - val_accuracy: 0.9908 - val_loss: 0.0303
# Epoch 6/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 144s 590ms/step - accuracy: 0.9863 - loss: 0.0233 - val_accuracy: 0.9910 - val_loss: 0.0289
# Epoch 7/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 128s 608ms/step - accuracy: 0.9873 - loss: 0.0253 - val_accuracy: 0.9913 - val_loss: 0.0280
# Epoch 8/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 142s 609ms/step - accuracy: 0.9882 - loss: 0.0234 - val_accuracy: 0.9913 - val_loss: 0.0287
# Epoch 9/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 140s 602ms/step - accuracy: 0.9876 - loss: 0.0245 - val_accuracy: 0.9916 - val_loss: 0.0280
# Epoch 10/10
# 211/211 ━━━━━━━━━━━━━━━━━━━━ 129s 611ms/step - accuracy: 0.9880 - loss: 0.0198 - val_accuracy: 0.9922 - val_loss: 0.0268
#
# Fine-Tuning V2 complete. New model saved to: /content/drive/MyDrive/mit_bih/my_fine_tuned_v2_mixed_low_noise_model.keras

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report
import joblib
import os

# --- Define File Paths ---
data_dir = '/content/drive/MyDrive/mit_bih/'
# Model 1: Trained on PURELY CLEAN data
MODEL_ORIGINAL_PATH = os.path.join(data_dir, 'my_summed_signal_model.keras')
# Model 2: Trained on CLEAN then Fine-Tuned on HEAVY NOISE
MODEL_HEAVY_NOISY_FT_PATH = os.path.join(data_dir, 'my_fine_tuned_noisy_model.keras')
# Model 3: Trained on PURELY HEAVY NOISE
MODEL_PURE_NOISE_PATH = os.path.join(data_dir, 'model_B_noisy.keras')
# Model 4: Fine-Tuned on 50/50 Mixed, Low-Noise Data (The new model)
MODEL_MIXED_FT_PATH = os.path.join(data_dir, 'my_fine_tuned_v2_mixed_low_noise_model.keras')

# Data/Helpers
X_TEST_NOISY_PATH = os.path.join(data_dir, 'X_test_noisy.npy')
Y_TEST_PATH = os.path.join(data_dir, 'y_test.npy')
ENCODER_PATH = os.path.join(data_dir, 'label_encoder.joblib')

# Load data and helpers only once
X_test_noisy_cnn = np.load(X_TEST_NOISY_PATH)
y_test = np.load(Y_TEST_PATH, allow_pickle=True)
label_encoder = joblib.load(ENCODER_PATH)

y_test_int = label_encoder.transform(y_test)
target_names = label_encoder.classes_

# List of models to evaluate
models_to_evaluate = [
    {"name": "1. Original (Clean Trained)", "path": MODEL_ORIGINAL_PATH},
    {"name": "2. Fine-Tuned (Clean + Heavy Noise FT)", "path": MODEL_HEAVY_NOISY_FT_PATH},
    {"name": "3. Purely Noisy Trained", "path": MODEL_PURE_NOISE_PATH},
    {"name": "4. Fine-Tuned (50/50 Mixed, V2)", "path": MODEL_MIXED_FT_PATH},
]

def evaluate_model(model_path, X_data, y_true_int, name, target_names):
    """Loads a model, predicts, evaluates, and prints report."""
    try:
        model = load_model(model_path)
    except Exception as e:
        print(f"Skipping {name}: Error loading model from {model_path}. {e}")
        return None, None, None

    print(f"\n===== EVALUATING: {name} =====")
    predictions_prob = model.predict(X_data, verbose=0)
    predictions_class = np.argmax(predictions_prob, axis=1)

    loss, accuracy = model.evaluate(X_data, y_true_int, verbose=0)

    report = classification_report(
        y_true_int,
        predictions_class,
        target_names=target_names,
        output_dict=True
    )

    print(f"Overall Accuracy: {accuracy * 100:.2f}%")
    print("\n--- Classification Report (F1-Scores) ---")

    f1_scores = {cls: report[cls]['f1-score'] for cls in target_names}
    for cls, f1 in f1_scores.items():
        print(f"  {cls}: {f1:.4f}")

    return accuracy, report['macro avg']['f1-score'], f1_scores


# --- Run Evaluation on NOISY TEST SET ---
results = []
print("Starting UNIFIED Comparative Evaluation on the NOISY TEST SET...")

for model_info in models_to_evaluate:
    accuracy, macro_f1, f1_scores = evaluate_model(
        model_info["path"],
        X_test_noisy_cnn,
        y_test_int,
        model_info["name"],
        target_names
    )
    if accuracy is not None:
        results.append({
            "Model": model_info["name"],
            "Accuracy": accuracy,
            "Macro F1": macro_f1,
            "F1 Scores": f1_scores
        })

# --- Final Comparison Table ---
print("\n" + "="*50)
print("       FINAL ROBUSTNESS COMPARISON (NOISY TEST SET)")
print("="*50)

header = ["Model", "Accuracy", "Macro F1", "N F1", "S F1", "V F1", "F F1"]
print(f"{header[0]:<30}{header[1]:<10}{header[2]:<10}{header[3]:<8}{header[4]:<8}{header[5]:<8}{header[6]:<8}")
print("-" * 80)

for res in results:
    f1s = res["F1 Scores"]
    print(f"{res['Model']:<30}{res['Accuracy'] * 100:<10.2f}{res['Macro F1']:<10.4f}{f1s['N']:<8.4f}{f1s['S']:<8.4f}{f1s['V']:<8.4f}{f1s['F']:<8.4f}")
# Out:
# Starting UNIFIED Comparative Evaluation on the NOISY TEST SET...
#
# ===== EVALUATING: 1. Original (Clean Trained) =====
# Overall Accuracy: 90.77%
#
# --- Classification Report (F1-Scores) ---
#   F: 0.2222
#   N: 0.9490
#   S: 0.4828
#   V: 0.7018
#
# ===== EVALUATING: 2. Fine-Tuned (Clean + Heavy Noise FT) =====
# Overall Accuracy: 84.63%
#
# --- Classification Report (F1-Scores) ---
#   F: 0.1607
#   N: 0.9108
#   S: 0.3953
#   V: 0.7361
#
# ===== EVALUATING: 3. Purely Noisy Trained =====
# Overall Accuracy: 91.57%
#
# --- Classification Report (F1-Scores) ---
#   F: 0.2636
#   N: 0.9544
#   S: 0.4212
#   V: 0.7065
#
# ===== EVALUATING: 4. Fine-Tuned (50/50 Mixed, V2) =====
# Overall Accuracy: 91.07%
#
# --- Classification Report (F1-Scores) ---
#   F: 0.2722
#   N: 0.9506
#   S: 0.4617
#   V: 0.7242
#
# ==================================================
#        FINAL ROBUSTNESS COMPARISON (NOISY TEST SET)
# ==================================================
# Model                         Accuracy  Macro F1  N F1    S F1    V F1    F F1
# --------------------------------------------------------------------------------
# 1. Original (Clean Trained)   90.77     0.5890    0.9490  0.4828  0.7018  0.2222
# 2. Fine-Tuned (Clean + Heavy Noise FT)84.63     0.5507    0.9108  0.3953  0.7361  0.1607
# 3. Purely Noisy Trained       91.57     0.5864    0.9544  0.4212  0.7065  0.2636
# 4. Fine-Tuned (50/50 Mixed, V2)91.07     0.6022    0.9506  0.4617  0.7242  0.2722

# %%
# !cd /content/drive/MyDrive/mit_bih/ && wget -r -N -c -np https://physionet.org/files/nstdb/1.0.0/
# Out:
# --2025-11-16 03:28:02--  https://physionet.org/files/nstdb/1.0.0/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/index.html’
#
# physionet.org/files     [ <=>                ]   7.79K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-16 03:28:02 (812 MB/s) - ‘physionet.org/files/nstdb/1.0.0/index.html’ saved [7982]
#
# Loading robots.txt; please ignore errors.
# --2025-11-16 03:28:02--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22 [text/plain]
# Saving to: ‘physionet.org/robots.txt’
#
# physionet.org/robot 100%[===================>]      22  --.-KB/s    in 0s
#
# 2025-11-16 03:28:02 (3.25 MB/s) - ‘physionet.org/robots.txt’ saved [22/22]
#
# --2025-11-16 03:28:02--  https://physionet.org/files/nstdb/1.0.0/old/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/index.html’
#
# physionet.org/files     [ <=>                ]   3.70K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-11-16 03:28:02 (337 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/index.html’ saved [3786]
#
# --2025-11-16 03:28:02--  https://physionet.org/files/nstdb/1.0.0/118e00.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4622 (4.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e00.atr’
#
# physionet.org/files 100%[===================>]   4.51K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:02 (330 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e00.atr’ saved [4622/4622]
#
# --2025-11-16 03:28:02--  https://physionet.org/files/nstdb/1.0.0/118e00.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e00.dat’
#
# physionet.org/files 100%[===================>]   2.48M  9.01MB/s    in 0.3s
#
# 2025-11-16 03:28:03 (9.01 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e00.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:03--  https://physionet.org/files/nstdb/1.0.0/118e00.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 173 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e00.hea’
#
# physionet.org/files 100%[===================>]     173  --.-KB/s    in 0s
#
# 2025-11-16 03:28:03 (28.8 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e00.hea’ saved [173/173]
#
# --2025-11-16 03:28:03--  https://physionet.org/files/nstdb/1.0.0/118e00.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e00.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2025-11-16 03:28:03 (12.2 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e00.xws’ saved [91/91]
#
# --2025-11-16 03:28:03--  https://physionet.org/files/nstdb/1.0.0/118e06.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4622 (4.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e06.atr’
#
# physionet.org/files 100%[===================>]   4.51K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:03 (530 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e06.atr’ saved [4622/4622]
#
# --2025-11-16 03:28:03--  https://physionet.org/files/nstdb/1.0.0/118e06.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e06.dat’
#
# physionet.org/files 100%[===================>]   1.86M  10.4MB/s    in 0.2s
#
# 2025-11-16 03:28:03 (10.4 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e06.dat’ saved [1950000/1950000]
#
# --2025-11-16 03:28:03--  https://physionet.org/files/nstdb/1.0.0/118e06.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 175 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e06.hea’
#
# physionet.org/files 100%[===================>]     175  --.-KB/s    in 0s
#
# 2025-11-16 03:28:03 (27.1 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e06.hea’ saved [175/175]
#
# --2025-11-16 03:28:03--  https://physionet.org/files/nstdb/1.0.0/118e06.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e06.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2025-11-16 03:28:03 (14.3 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e06.xws’ saved [91/91]
#
# --2025-11-16 03:28:03--  https://physionet.org/files/nstdb/1.0.0/118e12.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4622 (4.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e12.atr’
#
# physionet.org/files 100%[===================>]   4.51K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:03 (565 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e12.atr’ saved [4622/4622]
#
# --2025-11-16 03:28:03--  https://physionet.org/files/nstdb/1.0.0/118e12.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e12.dat’
#
# physionet.org/files 100%[===================>]   1.86M  6.34MB/s    in 0.3s
#
# 2025-11-16 03:28:04 (6.34 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e12.dat’ saved [1950000/1950000]
#
# --2025-11-16 03:28:04--  https://physionet.org/files/nstdb/1.0.0/118e12.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 177 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e12.hea’
#
# physionet.org/files 100%[===================>]     177  --.-KB/s    in 0s
#
# 2025-11-16 03:28:04 (26.3 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e12.hea’ saved [177/177]
#
# --2025-11-16 03:28:04--  https://physionet.org/files/nstdb/1.0.0/118e12.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e12.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2025-11-16 03:28:04 (16.3 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e12.xws’ saved [91/91]
#
# --2025-11-16 03:28:04--  https://physionet.org/files/nstdb/1.0.0/118e18.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4622 (4.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e18.atr’
#
# physionet.org/files 100%[===================>]   4.51K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:04 (607 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e18.atr’ saved [4622/4622]
#
# --2025-11-16 03:28:04--  https://physionet.org/files/nstdb/1.0.0/118e18.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e18.dat’
#
# physionet.org/files 100%[===================>]   1.86M  4.92MB/s    in 0.4s
#
# 2025-11-16 03:28:04 (4.92 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e18.dat’ saved [1950000/1950000]
#
# --2025-11-16 03:28:04--  https://physionet.org/files/nstdb/1.0.0/118e18.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 175 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e18.hea’
#
# physionet.org/files 100%[===================>]     175  --.-KB/s    in 0s
#
# 2025-11-16 03:28:04 (23.3 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e18.hea’ saved [175/175]
#
# --2025-11-16 03:28:04--  https://physionet.org/files/nstdb/1.0.0/118e18.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e18.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2025-11-16 03:28:04 (14.9 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e18.xws’ saved [91/91]
#
# --2025-11-16 03:28:04--  https://physionet.org/files/nstdb/1.0.0/118e24.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4622 (4.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e24.atr’
#
# physionet.org/files 100%[===================>]   4.51K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:04 (631 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e24.atr’ saved [4622/4622]
#
# --2025-11-16 03:28:04--  https://physionet.org/files/nstdb/1.0.0/118e24.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e24.dat’
#
# physionet.org/files 100%[===================>]   1.86M  3.10MB/s    in 0.6s
#
# 2025-11-16 03:28:05 (3.10 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e24.dat’ saved [1950000/1950000]
#
# --2025-11-16 03:28:05--  https://physionet.org/files/nstdb/1.0.0/118e24.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 176 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e24.hea’
#
# physionet.org/files 100%[===================>]     176  --.-KB/s    in 0s
#
# 2025-11-16 03:28:05 (34.6 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e24.hea’ saved [176/176]
#
# --2025-11-16 03:28:05--  https://physionet.org/files/nstdb/1.0.0/118e24.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e24.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2025-11-16 03:28:05 (13.6 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e24.xws’ saved [91/91]
#
# --2025-11-16 03:28:05--  https://physionet.org/files/nstdb/1.0.0/118e_6.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4622 (4.5K) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e_6.atr’
#
# physionet.org/files 100%[===================>]   4.51K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:05 (640 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e_6.atr’ saved [4622/4622]
#
# --2025-11-16 03:28:05--  https://physionet.org/files/nstdb/1.0.0/118e_6.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e_6.dat’
#
# physionet.org/files 100%[===================>]   2.48M  2.84MB/s    in 0.9s
#
# 2025-11-16 03:28:06 (2.84 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e_6.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:06--  https://physionet.org/files/nstdb/1.0.0/118e_6.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 172 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e_6.hea’
#
# physionet.org/files 100%[===================>]     172  --.-KB/s    in 0s
#
# 2025-11-16 03:28:06 (29.8 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e_6.hea’ saved [172/172]
#
# --2025-11-16 03:28:06--  https://physionet.org/files/nstdb/1.0.0/118e_6.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/118e_6.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2025-11-16 03:28:06 (16.3 MB/s) - ‘physionet.org/files/nstdb/1.0.0/118e_6.xws’ saved [91/91]
#
# --2025-11-16 03:28:06--  https://physionet.org/files/nstdb/1.0.0/119e00.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4812 (4.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e00.atr’
#
# physionet.org/files 100%[===================>]   4.70K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:06 (906 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e00.atr’ saved [4812/4812]
#
# --2025-11-16 03:28:06--  https://physionet.org/files/nstdb/1.0.0/119e00.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e00.dat’
#
# physionet.org/files 100%[===================>]   2.48M  2.18MB/s    in 1.1s
#
# 2025-11-16 03:28:07 (2.18 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e00.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:08--  https://physionet.org/files/nstdb/1.0.0/119e00.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 170 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e00.hea’
#
# physionet.org/files 100%[===================>]     170  --.-KB/s    in 0s
#
# 2025-11-16 03:28:08 (34.5 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e00.hea’ saved [170/170]
#
# --2025-11-16 03:28:08--  https://physionet.org/files/nstdb/1.0.0/119e00.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e00.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2025-11-16 03:28:08 (18.5 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e00.xws’ saved [91/91]
#
# --2025-11-16 03:28:08--  https://physionet.org/files/nstdb/1.0.0/119e06.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4812 (4.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e06.atr’
#
# physionet.org/files 100%[===================>]   4.70K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:08 (706 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e06.atr’ saved [4812/4812]
#
# --2025-11-16 03:28:08--  https://physionet.org/files/nstdb/1.0.0/119e06.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e06.dat’
#
# physionet.org/files 100%[===================>]   1.86M  3.15MB/s    in 0.6s
#
# 2025-11-16 03:28:08 (3.15 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e06.dat’ saved [1950000/1950000]
#
# --2025-11-16 03:28:08--  https://physionet.org/files/nstdb/1.0.0/119e06.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 175 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e06.hea’
#
# physionet.org/files 100%[===================>]     175  --.-KB/s    in 0s
#
# 2025-11-16 03:28:08 (33.1 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e06.hea’ saved [175/175]
#
# --2025-11-16 03:28:08--  https://physionet.org/files/nstdb/1.0.0/119e06.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e06.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2025-11-16 03:28:08 (17.8 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e06.xws’ saved [91/91]
#
# --2025-11-16 03:28:08--  https://physionet.org/files/nstdb/1.0.0/119e12.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4812 (4.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e12.atr’
#
# physionet.org/files 100%[===================>]   4.70K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:08 (861 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e12.atr’ saved [4812/4812]
#
# --2025-11-16 03:28:08--  https://physionet.org/files/nstdb/1.0.0/119e12.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e12.dat’
#
# physionet.org/files 100%[===================>]   1.86M  4.79MB/s    in 0.4s
#
# 2025-11-16 03:28:09 (4.79 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e12.dat’ saved [1950000/1950000]
#
# --2025-11-16 03:28:09--  https://physionet.org/files/nstdb/1.0.0/119e12.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 174 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e12.hea’
#
# physionet.org/files 100%[===================>]     174  --.-KB/s    in 0s
#
# 2025-11-16 03:28:09 (31.2 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e12.hea’ saved [174/174]
#
# --2025-11-16 03:28:09--  https://physionet.org/files/nstdb/1.0.0/119e12.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e12.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2025-11-16 03:28:09 (17.9 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e12.xws’ saved [91/91]
#
# --2025-11-16 03:28:09--  https://physionet.org/files/nstdb/1.0.0/119e18.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4812 (4.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e18.atr’
#
# physionet.org/files 100%[===================>]   4.70K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:09 (1.00 GB/s) - ‘physionet.org/files/nstdb/1.0.0/119e18.atr’ saved [4812/4812]
#
# --2025-11-16 03:28:09--  https://physionet.org/files/nstdb/1.0.0/119e18.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e18.dat’
#
# physionet.org/files 100%[===================>]   1.86M  3.11MB/s    in 0.6s
#
# 2025-11-16 03:28:10 (3.11 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e18.dat’ saved [1950000/1950000]
#
# --2025-11-16 03:28:10--  https://physionet.org/files/nstdb/1.0.0/119e18.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 175 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e18.hea’
#
# physionet.org/files 100%[===================>]     175  --.-KB/s    in 0s
#
# 2025-11-16 03:28:10 (9.19 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e18.hea’ saved [175/175]
#
# --2025-11-16 03:28:10--  https://physionet.org/files/nstdb/1.0.0/119e18.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e18.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2025-11-16 03:28:10 (18.9 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e18.xws’ saved [91/91]
#
# --2025-11-16 03:28:10--  https://physionet.org/files/nstdb/1.0.0/119e24.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4812 (4.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e24.atr’
#
# physionet.org/files 100%[===================>]   4.70K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:10 (827 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e24.atr’ saved [4812/4812]
#
# --2025-11-16 03:28:10--  https://physionet.org/files/nstdb/1.0.0/119e24.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e24.dat’
#
# physionet.org/files 100%[===================>]   1.86M  2.80MB/s    in 0.7s
#
# 2025-11-16 03:28:11 (2.80 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e24.dat’ saved [1950000/1950000]
#
# --2025-11-16 03:28:11--  https://physionet.org/files/nstdb/1.0.0/119e24.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 175 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e24.hea’
#
# physionet.org/files 100%[===================>]     175  --.-KB/s    in 0s
#
# 2025-11-16 03:28:11 (28.5 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e24.hea’ saved [175/175]
#
# --2025-11-16 03:28:11--  https://physionet.org/files/nstdb/1.0.0/119e24.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e24.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2025-11-16 03:28:11 (18.4 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e24.xws’ saved [91/91]
#
# --2025-11-16 03:28:11--  https://physionet.org/files/nstdb/1.0.0/119e_6.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4812 (4.7K) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e_6.atr’
#
# physionet.org/files 100%[===================>]   4.70K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:11 (772 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e_6.atr’ saved [4812/4812]
#
# --2025-11-16 03:28:11--  https://physionet.org/files/nstdb/1.0.0/119e_6.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e_6.dat’
#
# physionet.org/files 100%[===================>]   2.48M  3.51MB/s    in 0.7s
#
# 2025-11-16 03:28:11 (3.51 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e_6.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:11--  https://physionet.org/files/nstdb/1.0.0/119e_6.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 171 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e_6.hea’
#
# physionet.org/files 100%[===================>]     171  --.-KB/s    in 0s
#
# 2025-11-16 03:28:12 (39.4 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e_6.hea’ saved [171/171]
#
# --2025-11-16 03:28:12--  https://physionet.org/files/nstdb/1.0.0/119e_6.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/119e_6.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2025-11-16 03:28:12 (14.0 MB/s) - ‘physionet.org/files/nstdb/1.0.0/119e_6.xws’ saved [91/91]
#
# --2025-11-16 03:28:12--  https://physionet.org/files/nstdb/1.0.0/ANNOTATORS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 59 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/ANNOTATORS’
#
# physionet.org/files 100%[===================>]      59  --.-KB/s    in 0s
#
# 2025-11-16 03:28:12 (11.3 MB/s) - ‘physionet.org/files/nstdb/1.0.0/ANNOTATORS’ saved [59/59]
#
# --2025-11-16 03:28:12--  https://physionet.org/files/nstdb/1.0.0/RECORDS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 93 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/RECORDS’
#
# physionet.org/files 100%[===================>]      93  --.-KB/s    in 0s
#
# 2025-11-16 03:28:12 (19.9 MB/s) - ‘physionet.org/files/nstdb/1.0.0/RECORDS’ saved [93/93]
#
# --2025-11-16 03:28:12--  https://physionet.org/files/nstdb/1.0.0/SHA256SUMS.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7439 (7.3K) [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/SHA256SUMS.txt’
#
# physionet.org/files 100%[===================>]   7.26K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:12 (1.37 GB/s) - ‘physionet.org/files/nstdb/1.0.0/SHA256SUMS.txt’ saved [7439/7439]
#
# --2025-11-16 03:28:12--  https://physionet.org/files/nstdb/1.0.0/bw.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/bw.dat’
#
# physionet.org/files 100%[===================>]   1.86M  1.86MB/s    in 1.0s
#
# 2025-11-16 03:28:13 (1.86 MB/s) - ‘physionet.org/files/nstdb/1.0.0/bw.dat’ saved [1950000/1950000]
#
# --2025-11-16 03:28:13--  https://physionet.org/files/nstdb/1.0.0/bw.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 93 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/bw.hea’
#
# physionet.org/files 100%[===================>]      93  --.-KB/s    in 0s
#
# 2025-11-16 03:28:13 (28.0 MB/s) - ‘physionet.org/files/nstdb/1.0.0/bw.hea’ saved [93/93]
#
# --2025-11-16 03:28:13--  https://physionet.org/files/nstdb/1.0.0/bw.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 117 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/bw.hea-’
#
# physionet.org/files 100%[===================>]     117  --.-KB/s    in 0s
#
# 2025-11-16 03:28:13 (24.4 MB/s) - ‘physionet.org/files/nstdb/1.0.0/bw.hea-’ saved [117/117]
#
# --2025-11-16 03:28:13--  https://physionet.org/files/nstdb/1.0.0/bw.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 80 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/bw.xws’
#
# physionet.org/files 100%[===================>]      80  --.-KB/s    in 0s
#
# 2025-11-16 03:28:13 (21.5 MB/s) - ‘physionet.org/files/nstdb/1.0.0/bw.xws’ saved [80/80]
#
# --2025-11-16 03:28:13--  https://physionet.org/files/nstdb/1.0.0/em.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/em.dat’
#
# physionet.org/files 100%[===================>]   1.86M  2.90MB/s    in 0.6s
#
# 2025-11-16 03:28:14 (2.90 MB/s) - ‘physionet.org/files/nstdb/1.0.0/em.dat’ saved [1950000/1950000]
#
# --2025-11-16 03:28:14--  https://physionet.org/files/nstdb/1.0.0/em.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 92 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/em.hea’
#
# physionet.org/files 100%[===================>]      92  --.-KB/s    in 0s
#
# 2025-11-16 03:28:14 (25.3 MB/s) - ‘physionet.org/files/nstdb/1.0.0/em.hea’ saved [92/92]
#
# --2025-11-16 03:28:14--  https://physionet.org/files/nstdb/1.0.0/em.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 116 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/em.hea-’
#
# physionet.org/files 100%[===================>]     116  --.-KB/s    in 0s
#
# 2025-11-16 03:28:14 (27.1 MB/s) - ‘physionet.org/files/nstdb/1.0.0/em.hea-’ saved [116/116]
#
# --2025-11-16 03:28:14--  https://physionet.org/files/nstdb/1.0.0/em.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 80 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/em.xws’
#
# physionet.org/files 100%[===================>]      80  --.-KB/s    in 0s
#
# 2025-11-16 03:28:14 (11.8 MB/s) - ‘physionet.org/files/nstdb/1.0.0/em.xws’ saved [80/80]
#
# --2025-11-16 03:28:14--  https://physionet.org/files/nstdb/1.0.0/ma.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/ma.dat’
#
# physionet.org/files 100%[===================>]   1.86M  2.49MB/s    in 0.7s
#
# 2025-11-16 03:28:15 (2.49 MB/s) - ‘physionet.org/files/nstdb/1.0.0/ma.dat’ saved [1950000/1950000]
#
# --2025-11-16 03:28:15--  https://physionet.org/files/nstdb/1.0.0/ma.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/ma.hea’
#
# physionet.org/files 100%[===================>]      90  --.-KB/s    in 0s
#
# 2025-11-16 03:28:15 (12.8 MB/s) - ‘physionet.org/files/nstdb/1.0.0/ma.hea’ saved [90/90]
#
# --2025-11-16 03:28:15--  https://physionet.org/files/nstdb/1.0.0/ma.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 114 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/ma.hea-’
#
# physionet.org/files 100%[===================>]     114  --.-KB/s    in 0s
#
# 2025-11-16 03:28:15 (14.1 MB/s) - ‘physionet.org/files/nstdb/1.0.0/ma.hea-’ saved [114/114]
#
# --2025-11-16 03:28:15--  https://physionet.org/files/nstdb/1.0.0/ma.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 80 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/ma.xws’
#
# physionet.org/files 100%[===================>]      80  --.-KB/s    in 0s
#
# 2025-11-16 03:28:15 (8.47 MB/s) - ‘physionet.org/files/nstdb/1.0.0/ma.xws’ saved [80/80]
#
# --2025-11-16 03:28:15--  https://physionet.org/files/nstdb/1.0.0/nstdb.doc
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1922 (1.9K) [application/msword]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/nstdb.doc’
#
# physionet.org/files 100%[===================>]   1.88K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:15 (222 MB/s) - ‘physionet.org/files/nstdb/1.0.0/nstdb.doc’ saved [1922/1922]
#
# --2025-11-16 03:28:15--  https://physionet.org/files/nstdb/1.0.0/nstdb.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1922 (1.9K) [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/nstdb.txt’
#
# physionet.org/files 100%[===================>]   1.88K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:15 (244 MB/s) - ‘physionet.org/files/nstdb/1.0.0/nstdb.txt’ saved [1922/1922]
#
# --2025-11-16 03:28:15--  https://physionet.org/files/nstdb/1.0.0/nstdbgen
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 730 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/nstdbgen’
#
# physionet.org/files 100%[===================>]     730  --.-KB/s    in 0s
#
# 2025-11-16 03:28:15 (96.9 MB/s) - ‘physionet.org/files/nstdb/1.0.0/nstdbgen’ saved [730/730]
#
# --2025-11-16 03:28:15--  https://physionet.org/files/nstdb/1.0.0/nstdbgen-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1211 (1.2K) [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/nstdbgen-’
#
# physionet.org/files 100%[===================>]   1.18K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:15 (199 MB/s) - ‘physionet.org/files/nstdb/1.0.0/nstdbgen-’ saved [1211/1211]
#
# --2025-11-16 03:28:15--  https://physionet.org/files/nstdb/1.0.0/old/118_02.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/118_02.dat’
#
# physionet.org/files 100%[===================>]   2.48M  1.89MB/s    in 1.3s
#
# 2025-11-16 03:28:17 (1.89 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/118_02.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:17--  https://physionet.org/files/nstdb/1.0.0/old/118_02.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 144 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/118_02.hea’
#
# physionet.org/files 100%[===================>]     144  --.-KB/s    in 0s
#
# 2025-11-16 03:28:17 (35.0 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/118_02.hea’ saved [144/144]
#
# --2025-11-16 03:28:17--  https://physionet.org/files/nstdb/1.0.0/old/118_04.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/118_04.dat’
#
# physionet.org/files 100%[===================>]   2.48M  3.28MB/s    in 0.8s
#
# 2025-11-16 03:28:17 (3.28 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/118_04.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:17--  https://physionet.org/files/nstdb/1.0.0/old/118_04.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 144 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/118_04.hea’
#
# physionet.org/files 100%[===================>]     144  --.-KB/s    in 0s
#
# 2025-11-16 03:28:17 (27.5 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/118_04.hea’ saved [144/144]
#
# --2025-11-16 03:28:17--  https://physionet.org/files/nstdb/1.0.0/old/118_06.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/118_06.dat’
#
# physionet.org/files 100%[===================>]   2.48M  3.32MB/s    in 0.7s
#
# 2025-11-16 03:28:18 (3.32 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/118_06.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:18--  https://physionet.org/files/nstdb/1.0.0/old/118_06.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 143 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/118_06.hea’
#
# physionet.org/files 100%[===================>]     143  --.-KB/s    in 0s
#
# 2025-11-16 03:28:18 (28.9 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/118_06.hea’ saved [143/143]
#
# --2025-11-16 03:28:18--  https://physionet.org/files/nstdb/1.0.0/old/118_08.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/118_08.dat’
#
# physionet.org/files 100%[===================>]   2.48M  4.18MB/s    in 0.6s
#
# 2025-11-16 03:28:19 (4.18 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/118_08.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:19--  https://physionet.org/files/nstdb/1.0.0/old/118_08.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 144 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/118_08.hea’
#
# physionet.org/files 100%[===================>]     144  --.-KB/s    in 0s
#
# 2025-11-16 03:28:19 (25.2 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/118_08.hea’ saved [144/144]
#
# --2025-11-16 03:28:19--  https://physionet.org/files/nstdb/1.0.0/old/118_10.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/118_10.dat’
#
# physionet.org/files 100%[===================>]   2.48M  3.77MB/s    in 0.7s
#
# 2025-11-16 03:28:20 (3.77 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/118_10.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:20--  https://physionet.org/files/nstdb/1.0.0/old/118_10.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 143 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/118_10.hea’
#
# physionet.org/files 100%[===================>]     143  --.-KB/s    in 0s
#
# 2025-11-16 03:28:20 (24.9 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/118_10.hea’ saved [143/143]
#
# --2025-11-16 03:28:20--  https://physionet.org/files/nstdb/1.0.0/old/118_12.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/118_12.dat’
#
# physionet.org/files 100%[===================>]   2.48M  3.48MB/s    in 0.7s
#
# 2025-11-16 03:28:21 (3.48 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/118_12.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:21--  https://physionet.org/files/nstdb/1.0.0/old/118_12.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 142 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/118_12.hea’
#
# physionet.org/files 100%[===================>]     142  --.-KB/s    in 0s
#
# 2025-11-16 03:28:21 (21.9 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/118_12.hea’ saved [142/142]
#
# --2025-11-16 03:28:21--  https://physionet.org/files/nstdb/1.0.0/old/119_02.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/119_02.dat’
#
# physionet.org/files 100%[===================>]   2.48M  3.69MB/s    in 0.7s
#
# 2025-11-16 03:28:21 (3.69 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/119_02.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:21--  https://physionet.org/files/nstdb/1.0.0/old/119_02.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 142 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/119_02.hea’
#
# physionet.org/files 100%[===================>]     142  --.-KB/s    in 0s
#
# 2025-11-16 03:28:21 (23.7 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/119_02.hea’ saved [142/142]
#
# --2025-11-16 03:28:21--  https://physionet.org/files/nstdb/1.0.0/old/119_04.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/119_04.dat’
#
# physionet.org/files 100%[===================>]   2.48M  5.45MB/s    in 0.5s
#
# 2025-11-16 03:28:22 (5.45 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/119_04.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:22--  https://physionet.org/files/nstdb/1.0.0/old/119_04.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 142 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/119_04.hea’
#
# physionet.org/files 100%[===================>]     142  --.-KB/s    in 0s
#
# 2025-11-16 03:28:22 (29.4 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/119_04.hea’ saved [142/142]
#
# --2025-11-16 03:28:22--  https://physionet.org/files/nstdb/1.0.0/old/119_06.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/119_06.dat’
#
# physionet.org/files 100%[===================>]   2.48M  3.62MB/s    in 0.7s
#
# 2025-11-16 03:28:23 (3.62 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/119_06.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:23--  https://physionet.org/files/nstdb/1.0.0/old/119_06.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 142 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/119_06.hea’
#
# physionet.org/files 100%[===================>]     142  --.-KB/s    in 0s
#
# 2025-11-16 03:28:23 (32.8 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/119_06.hea’ saved [142/142]
#
# --2025-11-16 03:28:23--  https://physionet.org/files/nstdb/1.0.0/old/119_08.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/119_08.dat’
#
# physionet.org/files 100%[===================>]   2.48M  2.79MB/s    in 0.9s
#
# 2025-11-16 03:28:24 (2.79 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/119_08.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:24--  https://physionet.org/files/nstdb/1.0.0/old/119_08.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 144 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/119_08.hea’
#
# physionet.org/files 100%[===================>]     144  --.-KB/s    in 0s
#
# 2025-11-16 03:28:24 (37.2 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/119_08.hea’ saved [144/144]
#
# --2025-11-16 03:28:24--  https://physionet.org/files/nstdb/1.0.0/old/119_10.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/119_10.dat’
#
# physionet.org/files 100%[===================>]   2.48M  3.08MB/s    in 0.8s
#
# 2025-11-16 03:28:25 (3.08 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/119_10.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:25--  https://physionet.org/files/nstdb/1.0.0/old/119_10.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 143 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/119_10.hea’
#
# physionet.org/files 100%[===================>]     143  --.-KB/s    in 0s
#
# 2025-11-16 03:28:25 (27.5 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/119_10.hea’ saved [143/143]
#
# --2025-11-16 03:28:25--  https://physionet.org/files/nstdb/1.0.0/old/119_12.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/119_12.dat’
#
# physionet.org/files 100%[===================>]   2.48M  3.02MB/s    in 0.8s
#
# 2025-11-16 03:28:26 (3.02 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/119_12.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:26--  https://physionet.org/files/nstdb/1.0.0/old/119_12.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 143 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/119_12.hea’
#
# physionet.org/files 100%[===================>]     143  --.-KB/s    in 0s
#
# 2025-11-16 03:28:26 (35.8 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/119_12.hea’ saved [143/143]
#
# --2025-11-16 03:28:26--  https://physionet.org/files/nstdb/1.0.0/old/oldbw.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/oldbw.dat’
#
# physionet.org/files 100%[===================>]   2.48M  2.75MB/s    in 0.9s
#
# 2025-11-16 03:28:27 (2.75 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/oldbw.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:27--  https://physionet.org/files/nstdb/1.0.0/old/oldbw.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 123 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/oldbw.hea’
#
# physionet.org/files 100%[===================>]     123  --.-KB/s    in 0s
#
# 2025-11-16 03:28:27 (24.7 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/oldbw.hea’ saved [123/123]
#
# --2025-11-16 03:28:27--  https://physionet.org/files/nstdb/1.0.0/old/oldem.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/oldem.dat’
#
# physionet.org/files 100%[===================>]   2.48M  2.87MB/s    in 0.9s
#
# 2025-11-16 03:28:28 (2.87 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/oldem.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:28--  https://physionet.org/files/nstdb/1.0.0/old/oldem.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 122 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/oldem.hea’
#
# physionet.org/files 100%[===================>]     122  --.-KB/s    in 0s
#
# 2025-11-16 03:28:28 (21.2 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/oldem.hea’ saved [122/122]
#
# --2025-11-16 03:28:28--  https://physionet.org/files/nstdb/1.0.0/old/oldma.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2600000 (2.5M) [application/octet-stream]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/oldma.dat’
#
# physionet.org/files 100%[===================>]   2.48M  2.50MB/s    in 1.0s
#
# 2025-11-16 03:28:29 (2.50 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/oldma.dat’ saved [2600000/2600000]
#
# --2025-11-16 03:28:29--  https://physionet.org/files/nstdb/1.0.0/old/oldma.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 125 [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/oldma.hea’
#
# physionet.org/files 100%[===================>]     125  --.-KB/s    in 0s
#
# 2025-11-16 03:28:29 (25.1 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/oldma.hea’ saved [125/125]
#
# --2025-11-16 03:28:29--  https://physionet.org/files/nstdb/1.0.0/old/oldnstdb.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1581 (1.5K) [text/plain]
# Saving to: ‘physionet.org/files/nstdb/1.0.0/old/oldnstdb.txt’
#
# physionet.org/files 100%[===================>]   1.54K  --.-KB/s    in 0s
#
# 2025-11-16 03:28:29 (399 MB/s) - ‘physionet.org/files/nstdb/1.0.0/old/oldnstdb.txt’ saved [1581/1581]
#
# FINISHED --2025-11-16 03:28:29--
# Total wall clock time: 27s
# Downloaded: 101 files, 68M in 21s (3.23 MB/s)

# %%
# Original path placeholder
NSTDB_DIR = os.path.join(data_dir, 'nstdb/')

# Change to the actual downloaded path
# This assumes the wget command completed successfully:
NSTDB_DIR = os.path.join(data_dir, 'physionet.org/files/nstdb/1.0.0/')

# %%
# !pip install wfdb
# Out:
# Collecting wfdb
#   Downloading wfdb-4.3.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.12/dist-packages (from wfdb) (3.13.2)
# Requirement already satisfied: fsspec>=2023.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2025.3.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.12/dist-packages (from wfdb) (3.10.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2.0.2)
# Collecting pandas>=2.2.3 (from wfdb)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2.32.4)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (1.16.3)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (2025.10.5)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.10.0->wfdb) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp>=3.10.11->wfdb) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.17.0)
# Downloading wfdb-4.3.0-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 13.9 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 51.3 MB/s eta 0:00:00
# Installing collected packages: pandas, wfdb
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# Successfully installed pandas-2.3.3 wfdb-4.3.0

# %%
import numpy as np
import wfdb
import os
import random

# --- Configuration ---
data_dir = '/content/drive/MyDrive/mit_bih/'
CLEAN_TEST_PATH = os.path.join(data_dir, 'X_test.npy')
FS = 360  # MIT-BIH Sample Frequency
SEGMENT_LEN = 180
TARGET_SNR_DB = 10.0

# The path where wget placed the noise files
NSTDB_DIR = os.path.join(data_dir, 'physionet.org/files/nstdb/1.0.0/')
NOISE_RECORD_NAME = 'em' # Electrode Motion noise
NOISE_TEST_PATH = os.path.join(data_dir, 'X_test_nstdb_10db_noise.npy')

def generate_real_noise_test_set():
    # Load clean test data
    X_clean = np.load(CLEAN_TEST_PATH)

    # Load NSTDB Noise Record (Electrode Motion)
    noise_record_path = os.path.join(NSTDB_DIR, NOISE_RECORD_NAME)
    noise_record = wfdb.rdrecord(noise_record_path)
    noise_signal = noise_record.p_signal[:, 0]

    X_noisy_nstdb = []

    # Calculate desired ratio
    desired_ratio = 10**(TARGET_SNR_DB / 20)

    for clean_beat in X_clean:
        clean_energy = np.linalg.norm(clean_beat)

        # Randomly select a 180-sample segment of noise
        start_index = random.randint(0, len(noise_signal) - SEGMENT_LEN)
        noise_segment = noise_signal[start_index : start_index + SEGMENT_LEN]
        noise_energy = np.linalg.norm(noise_segment)

        # Calculate the scaling factor (alpha) to achieve the target SNR
        if noise_energy == 0:
            alpha = 0
        else:
            alpha = (clean_energy / noise_energy) / desired_ratio

        # Mix and add to list
        scaled_noise_segment = alpha * noise_segment
        noisy_beat = clean_beat + scaled_noise_segment

        X_noisy_nstdb.append(noisy_beat)

    X_noisy_nstdb = np.array(X_noisy_nstdb)
    X_noisy_nstdb_cnn = np.expand_dims(X_noisy_nstdb, axis=-1)

    np.save(NOISE_TEST_PATH, X_noisy_nstdb_cnn)
    return X_noisy_nstdb_cnn

# Execute and get the new test data
X_test_nstdb_cnn = generate_real_noise_test_set()
print(f"Generated {len(X_test_nstdb_cnn)} real-noise test beats at 10 dB SNR.")
# Out:
# Generated 24996 real-noise test beats at 10 dB SNR.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import classification_report
import joblib
import os

# --- Model Paths ---
data_dir = '/content/drive/MyDrive/mit_bih/'
MODEL_ORIGINAL_PATH = os.path.join(data_dir, 'my_summed_signal_model.keras')
MODEL_HEAVY_NOISY_FT_PATH = os.path.join(data_dir, 'my_fine_tuned_noisy_model.keras')
MODEL_PURE_NOISE_PATH = os.path.join(data_dir, 'model_B_noisy.keras')
MODEL_MIXED_FT_PATH = os.path.join(data_dir, 'my_fine_tuned_v2_mixed_low_noise_model.keras')

# --- Data/Helpers ---
X_TEST_NSTDB_PATH = os.path.join(data_dir, 'X_test_nstdb_10db_noise.npy')
Y_TEST_PATH = os.path.join(data_dir, 'y_test.npy')
ENCODER_PATH = os.path.join(data_dir, 'label_encoder.joblib')

# Load the real-noise test data generated in the previous step
X_test_nstdb_cnn = np.load(X_TEST_NSTDB_PATH)
y_test = np.load(Y_TEST_PATH, allow_pickle=True)
label_encoder = joblib.load(ENCODER_PATH)

y_test_int = label_encoder.transform(y_test)
target_names = label_encoder.classes_

# List of models to evaluate
models_to_evaluate = [
    {"name": "1. Original (Clean Trained)", "path": MODEL_ORIGINAL_PATH},
    {"name": "2. Fine-Tuned (Clean + Heavy Noise FT)", "path": MODEL_HEAVY_NOISY_FT_PATH},
    {"name": "3. Purely Noisy Trained", "path": MODEL_PURE_NOISE_PATH},
    {"name": "4. Fine-Tuned (50/50 Mixed, V2)", "path": MODEL_MIXED_FT_PATH},
]

def evaluate_model(model_path, X_data, y_true_int, name, target_names):
    """Loads a model, predicts, evaluates, and prints report."""
    try:
        model = load_model(model_path)
    except Exception as e:
        print(f"Skipping {name}: Error loading model from {model_path}. {e}")
        return None, None, None

    print(f"\n===== EVALUATING: {name} =====")
    predictions_prob = model.predict(X_data, verbose=0)
    predictions_class = np.argmax(predictions_prob, axis=1)

    loss, accuracy = model.evaluate(X_data, y_true_int, verbose=0)

    report = classification_report(
        y_true_int,
        predictions_class,
        target_names=target_names,
        output_dict=True
    )

    print(f"Overall Accuracy: {accuracy * 100:.2f}%")
    print("\n--- Classification Report (F1-Scores) ---")

    f1_scores = {cls: report[cls]['f1-score'] for cls in target_names}
    for cls, f1 in f1_scores.items():
        print(f"  {cls}: {f1:.4f}")

    return accuracy, report['macro avg']['f1-score'], f1_scores


# --- Run Evaluation on NSTDB NOISE TEST SET ---
results = []
print("Starting FINAL Comparative Evaluation on the REAL-NOISE TEST SET (NSTDB 10dB)...")

for model_info in models_to_evaluate:
    accuracy, macro_f1, f1_scores = evaluate_model(
        model_info["path"],
        X_test_nstdb_cnn,
        y_test_int,
        model_info["name"],
        target_names
    )
    if accuracy is not None:
        results.append({
            "Model": model_info["name"],
            "Accuracy": accuracy,
            "Macro F1": macro_f1,
            "F1 Scores": f1_scores
        })

# --- Final Comparison Table ---
print("\n" + "="*50)
print("  FINAL ROBUSTNESS COMPARISON (NSTDB 10dB REAL NOISE)")
print("="*50)

header = ["Model", "Accuracy", "Macro F1", "N F1", "S F1", "V F1", "F F1"]
print(f"{header[0]:<30}{header[1]:<10}{header[2]:<10}{header[3]:<8}{header[4]:<8}{header[5]:<8}{header[6]:<8}")
print("-" * 80)

for res in results:
    f1s = res["F1 Scores"]
    print(f"{res['Model']:<30}{res['Accuracy'] * 100:<10.2f}{res['Macro F1']:<10.4f}{f1s['N']:<8.4f}{f1s['S']:<8.4f}{f1s['V']:<8.4f}{f1s['F']:<8.4f}")
# Out:
# Starting FINAL Comparative Evaluation on the REAL-NOISE TEST SET (NSTDB 10dB)...
#
# ===== EVALUATING: 1. Original (Clean Trained) =====
# Overall Accuracy: 94.92%
#
# --- Classification Report (F1-Scores) ---
#   F: 0.5607
#   N: 0.9723
#   S: 0.6253
#   V: 0.8691
#
# ===== EVALUATING: 2. Fine-Tuned (Clean + Heavy Noise FT) =====
# Overall Accuracy: 86.83%
#
# --- Classification Report (F1-Scores) ---
#   F: 0.1889
#   N: 0.9236
#   S: 0.4572
#   V: 0.8490
#
# ===== EVALUATING: 3. Purely Noisy Trained =====
# Overall Accuracy: 95.17%
#
# --- Classification Report (F1-Scores) ---
#   F: 0.3542
#   N: 0.9747
#   S: 0.5852
#   V: 0.8108
#
# ===== EVALUATING: 4. Fine-Tuned (50/50 Mixed, V2) =====
# Overall Accuracy: 95.34%
#
# --- Classification Report (F1-Scores) ---
#   F: 0.6440
#   N: 0.9747
#   S: 0.6127
#   V: 0.8921
#
# ==================================================
#   FINAL ROBUSTNESS COMPARISON (NSTDB 10dB REAL NOISE)
# ==================================================
# Model                         Accuracy  Macro F1  N F1    S F1    V F1    F F1
# --------------------------------------------------------------------------------
# 1. Original (Clean Trained)   94.92     0.7568    0.9723  0.6253  0.8691  0.5607
# 2. Fine-Tuned (Clean + Heavy Noise FT)86.83     0.6047    0.9236  0.4572  0.8490  0.1889
# 3. Purely Noisy Trained       95.17     0.6813    0.9747  0.5852  0.8108  0.3542
# 4. Fine-Tuned (50/50 Mixed, V2)95.34     0.7809    0.9747  0.6127  0.8921  0.6440

# %%
# !wget -r -N -c -np https://physionet.org/files/ptb-xl/1.0.1/ -P /content/drive/MyDrive/ptb_xl_download/
# Out:
# Streaming output truncated to the last 5000 lines.
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00502_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-11-17 09:14:13 (54.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00502_lr.hea’ saved [600/600]
#
# --2025-11-17 09:14:13--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00503_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00503_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:14 (630 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00503_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:14--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00503_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00503_lr.hea’
#
# physionet.org/files 100%[===================>]     609  --.-KB/s    in 0s
#
# 2025-11-17 09:14:14 (71.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00503_lr.hea’ saved [609/609]
#
# --2025-11-17 09:14:14--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00504_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00504_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:14 (590 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00504_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:14--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00504_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 611 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00504_lr.hea’
#
# physionet.org/files 100%[===================>]     611  --.-KB/s    in 0s
#
# 2025-11-17 09:14:14 (60.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00504_lr.hea’ saved [611/611]
#
# --2025-11-17 09:14:14--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00505_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00505_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:14 (628 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00505_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:14--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00505_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00505_lr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-11-17 09:14:14 (51.2 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00505_lr.hea’ saved [605/605]
#
# --2025-11-17 09:14:14--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00506_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00506_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:14:14 (9.32 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00506_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:14--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00506_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00506_lr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-11-17 09:14:14 (28.1 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00506_lr.hea’ saved [603/603]
#
# --2025-11-17 09:14:14--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00507_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00507_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:14:14 (11.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00507_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:14--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00507_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00507_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-11-17 09:14:14 (121 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00507_lr.hea’ saved [600/600]
#
# --2025-11-17 09:14:14--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00508_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00508_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.004s
#
# 2025-11-17 09:14:15 (5.83 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00508_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:15--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00508_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00508_lr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-11-17 09:14:15 (54.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00508_lr.hea’ saved [603/603]
#
# --2025-11-17 09:14:15--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00509_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00509_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.003s
#
# 2025-11-17 09:14:15 (7.43 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00509_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:15--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00509_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 613 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00509_lr.hea’
#
# physionet.org/files 100%[===================>]     613  --.-KB/s    in 0s
#
# 2025-11-17 09:14:15 (51.8 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00509_lr.hea’ saved [613/613]
#
# --2025-11-17 09:14:15--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00510_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00510_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.003s
#
# 2025-11-17 09:14:15 (8.64 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00510_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:15--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00510_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00510_lr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-11-17 09:14:15 (94.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00510_lr.hea’ saved [602/602]
#
# --2025-11-17 09:14:15--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00511_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00511_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.02s
#
# 2025-11-17 09:14:15 (1.17 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00511_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:15--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00511_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 610 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00511_lr.hea’
#
# physionet.org/files 100%[===================>]     610  --.-KB/s    in 0s
#
# 2025-11-17 09:14:15 (72.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00511_lr.hea’ saved [610/610]
#
# --2025-11-17 09:14:15--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00512_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00512_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.003s
#
# 2025-11-17 09:14:15 (8.30 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00512_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:15--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00512_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00512_lr.hea’
#
# physionet.org/files 100%[===================>]     609  --.-KB/s    in 0s
#
# 2025-11-17 09:14:15 (50.8 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00512_lr.hea’ saved [609/609]
#
# --2025-11-17 09:14:15--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00513_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00513_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.003s
#
# 2025-11-17 09:14:15 (8.07 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00513_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:15--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00513_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00513_lr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-11-17 09:14:15 (59.1 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00513_lr.hea’ saved [606/606]
#
# --2025-11-17 09:14:15--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00514_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00514_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.01s
#
# 2025-11-17 09:14:16 (2.19 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00514_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:16--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00514_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00514_lr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-11-17 09:14:16 (55.2 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00514_lr.hea’ saved [603/603]
#
# --2025-11-17 09:14:16--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00515_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00515_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.006s
#
# 2025-11-17 09:14:16 (4.10 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00515_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:16--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00515_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00515_lr.hea’
#
# physionet.org/files 100%[===================>]     608  --.-KB/s    in 0s
#
# 2025-11-17 09:14:16 (98.9 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00515_lr.hea’ saved [608/608]
#
# --2025-11-17 09:14:16--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00516_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00516_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:14:16 (11.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00516_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:16--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00516_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 615 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00516_lr.hea’
#
# physionet.org/files 100%[===================>]     615  --.-KB/s    in 0s
#
# 2025-11-17 09:14:16 (90.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00516_lr.hea’ saved [615/615]
#
# --2025-11-17 09:14:16--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00517_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00517_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:14:16 (11.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00517_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:16--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00517_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00517_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-11-17 09:14:16 (53.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00517_lr.hea’ saved [600/600]
#
# --2025-11-17 09:14:16--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00518_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00518_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:14:16 (11.8 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00518_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:16--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00518_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00518_lr.hea’
#
# physionet.org/files 100%[===================>]     604  --.-KB/s    in 0s
#
# 2025-11-17 09:14:16 (77.9 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00518_lr.hea’ saved [604/604]
#
# --2025-11-17 09:14:16--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00519_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00519_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:14:16 (10.9 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00519_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:16--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00519_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 595 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00519_lr.hea’
#
# physionet.org/files 100%[===================>]     595  --.-KB/s    in 0s
#
# 2025-11-17 09:14:17 (67.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00519_lr.hea’ saved [595/595]
#
# --2025-11-17 09:14:17--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00520_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00520_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:17 (598 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00520_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:17--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00520_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 610 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00520_lr.hea’
#
# physionet.org/files 100%[===================>]     610  --.-KB/s    in 0s
#
# 2025-11-17 09:14:17 (90.1 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00520_lr.hea’ saved [610/610]
#
# --2025-11-17 09:14:17--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00521_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00521_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:17 (578 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00521_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:17--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00521_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00521_lr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-11-17 09:14:17 (130 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00521_lr.hea’ saved [603/603]
#
# --2025-11-17 09:14:17--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00522_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00522_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:17 (638 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00522_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:17--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00522_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00522_lr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-11-17 09:14:17 (87.2 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00522_lr.hea’ saved [605/605]
#
# --2025-11-17 09:14:17--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00523_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00523_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:17 (599 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00523_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:17--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00523_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00523_lr.hea’
#
# physionet.org/files 100%[===================>]     604  --.-KB/s    in 0s
#
# 2025-11-17 09:14:18 (155 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00523_lr.hea’ saved [604/604]
#
# --2025-11-17 09:14:18--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00524_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00524_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:18 (594 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00524_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:18--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00524_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00524_lr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-11-17 09:14:18 (123 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00524_lr.hea’ saved [606/606]
#
# --2025-11-17 09:14:18--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00525_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00525_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:14:18 (12.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00525_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:18--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00525_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 612 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00525_lr.hea’
#
# physionet.org/files 100%[===================>]     612  --.-KB/s    in 0s
#
# 2025-11-17 09:14:18 (118 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00525_lr.hea’ saved [612/612]
#
# --2025-11-17 09:14:18--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00526_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00526_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.001s
#
# 2025-11-17 09:14:19 (18.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00526_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:19--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00526_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00526_lr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-11-17 09:14:19 (76.1 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00526_lr.hea’ saved [602/602]
#
# --2025-11-17 09:14:19--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00527_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00527_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:19 (561 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00527_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:19--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00527_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 617 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00527_lr.hea’
#
# physionet.org/files 100%[===================>]     617  --.-KB/s    in 0s
#
# 2025-11-17 09:14:19 (82.2 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00527_lr.hea’ saved [617/617]
#
# --2025-11-17 09:14:19--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00528_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00528_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:19 (588 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00528_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:19--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00528_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00528_lr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-11-17 09:14:19 (111 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00528_lr.hea’ saved [605/605]
#
# --2025-11-17 09:14:19--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00529_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00529_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:19 (590 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00529_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:19--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00529_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00529_lr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-11-17 09:14:19 (78.8 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00529_lr.hea’ saved [603/603]
#
# --2025-11-17 09:14:19--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00530_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00530_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:19 (642 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00530_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:19--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00530_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 601 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00530_lr.hea’
#
# physionet.org/files 100%[===================>]     601  --.-KB/s    in 0s
#
# 2025-11-17 09:14:19 (113 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00530_lr.hea’ saved [601/601]
#
# --2025-11-17 09:14:19--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00531_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00531_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:20 (632 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00531_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:20--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00531_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00531_lr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-11-17 09:14:20 (83.8 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00531_lr.hea’ saved [602/602]
#
# --2025-11-17 09:14:20--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00532_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00532_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.03s
#
# 2025-11-17 09:14:20 (764 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00532_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:20--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00532_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 592 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00532_lr.hea’
#
# physionet.org/files 100%[===================>]     592  --.-KB/s    in 0s
#
# 2025-11-17 09:14:20 (52.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00532_lr.hea’ saved [592/592]
#
# --2025-11-17 09:14:20--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00533_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00533_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:20 (611 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00533_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:20--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00533_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00533_lr.hea’
#
# physionet.org/files 100%[===================>]     604  --.-KB/s    in 0s
#
# 2025-11-17 09:14:20 (53.0 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00533_lr.hea’ saved [604/604]
#
# --2025-11-17 09:14:20--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00534_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00534_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:20 (592 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00534_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:20--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00534_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00534_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-11-17 09:14:20 (49.6 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00534_lr.hea’ saved [600/600]
#
# --2025-11-17 09:14:20--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00535_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00535_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.08s
#
# 2025-11-17 09:14:20 (289 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00535_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:20--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00535_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00535_lr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-11-17 09:14:21 (90.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00535_lr.hea’ saved [605/605]
#
# --2025-11-17 09:14:21--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00536_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00536_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:14:21 (11.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00536_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:21--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00536_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00536_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-11-17 09:14:21 (49.2 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00536_lr.hea’ saved [600/600]
#
# --2025-11-17 09:14:21--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00537_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00537_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:21 (651 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00537_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:21--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00537_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00537_lr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-11-17 09:14:21 (61.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00537_lr.hea’ saved [603/603]
#
# --2025-11-17 09:14:21--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00538_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00538_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:21 (616 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00538_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:21--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00538_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 610 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00538_lr.hea’
#
# physionet.org/files 100%[===================>]     610  --.-KB/s    in 0s
#
# 2025-11-17 09:14:21 (51.9 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00538_lr.hea’ saved [610/610]
#
# --2025-11-17 09:14:21--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00539_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00539_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:21 (607 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00539_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:21--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00539_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 610 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00539_lr.hea’
#
# physionet.org/files 100%[===================>]     610  --.-KB/s    in 0s
#
# 2025-11-17 09:14:21 (112 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00539_lr.hea’ saved [610/610]
#
# --2025-11-17 09:14:21--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00540_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00540_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:22 (613 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00540_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:22--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00540_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00540_lr.hea’
#
# physionet.org/files 100%[===================>]     607  --.-KB/s    in 0s
#
# 2025-11-17 09:14:22 (57.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00540_lr.hea’ saved [607/607]
#
# --2025-11-17 09:14:22--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00541_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00541_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:22 (609 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00541_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:22--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00541_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 613 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00541_lr.hea’
#
# physionet.org/files 100%[===================>]     613  --.-KB/s    in 0s
#
# 2025-11-17 09:14:22 (56.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00541_lr.hea’ saved [613/613]
#
# --2025-11-17 09:14:22--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00542_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00542_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:22 (646 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00542_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:22--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00542_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 614 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00542_lr.hea’
#
# physionet.org/files 100%[===================>]     614  --.-KB/s    in 0s
#
# 2025-11-17 09:14:22 (55.2 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00542_lr.hea’ saved [614/614]
#
# --2025-11-17 09:14:22--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00543_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00543_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.04s
#
# 2025-11-17 09:14:22 (608 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00543_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:14:22--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00543_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00543_lr.hea’
#
# ...
#
# --2025-11-17 09:15:01--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00739_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00739_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:15:01 (11.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00739_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:01--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00739_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00739_lr.hea’
#
# physionet.org/files 100%[===================>]     609  --.-KB/s    in 0s
#
# 2025-11-17 09:15:01 (119 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00739_lr.hea’ saved [609/609]
#
# --2025-11-17 09:15:01--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00740_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00740_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.003s
#
# 2025-11-17 09:15:01 (6.98 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00740_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:01--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00740_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 611 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00740_lr.hea’
#
# physionet.org/files 100%[===================>]     611  --.-KB/s    in 0s
#
# 2025-11-17 09:15:01 (81.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00740_lr.hea’ saved [611/611]
#
# --2025-11-17 09:15:01--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00741_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00741_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:15:01 (11.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00741_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:01--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00741_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00741_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-11-17 09:15:01 (88.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00741_lr.hea’ saved [600/600]
#
# --2025-11-17 09:15:01--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00742_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00742_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:15:02 (12.0 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00742_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:02--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00742_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 598 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00742_lr.hea’
#
# physionet.org/files 100%[===================>]     598  --.-KB/s    in 0s
#
# 2025-11-17 09:15:02 (142 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00742_lr.hea’ saved [598/598]
#
# --2025-11-17 09:15:02--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00743_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00743_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:15:02 (12.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00743_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:02--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00743_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 597 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00743_lr.hea’
#
# physionet.org/files 100%[===================>]     597  --.-KB/s    in 0s
#
# 2025-11-17 09:15:02 (81.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00743_lr.hea’ saved [597/597]
#
# --2025-11-17 09:15:02--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00744_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00744_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:15:02 (10.6 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00744_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:02--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00744_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00744_lr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-11-17 09:15:02 (74.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00744_lr.hea’ saved [600/600]
#
# --2025-11-17 09:15:02--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00745_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00745_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:15:02 (13.0 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00745_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:02--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00745_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 599 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00745_lr.hea’
#
# physionet.org/files 100%[===================>]     599  --.-KB/s    in 0s
#
# 2025-11-17 09:15:02 (114 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00745_lr.hea’ saved [599/599]
#
# --2025-11-17 09:15:02--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00746_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00746_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:15:02 (9.81 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00746_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:02--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00746_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 599 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00746_lr.hea’
#
# physionet.org/files 100%[===================>]     599  --.-KB/s    in 0s
#
# 2025-11-17 09:15:02 (74.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00746_lr.hea’ saved [599/599]
#
# --2025-11-17 09:15:02--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00747_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00747_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.002s
#
# 2025-11-17 09:15:02 (12.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00747_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:02--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00747_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00747_lr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-11-17 09:15:03 (126 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00747_lr.hea’ saved [606/606]
#
# --2025-11-17 09:15:03--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00748_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00748_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.003s
#
# 2025-11-17 09:15:03 (7.33 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00748_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:03--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00748_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00748_lr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-11-17 09:15:03 (72.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00748_lr.hea’ saved [603/603]
#
# --2025-11-17 09:15:03--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00749_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00749_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.003s
#
# 2025-11-17 09:15:03 (7.52 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00749_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:03--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00749_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00749_lr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-11-17 09:15:03 (60.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00749_lr.hea’ saved [606/606]
#
# --2025-11-17 09:15:03--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00750_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00750_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.003s
#
# 2025-11-17 09:15:03 (7.36 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00750_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:03--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00750_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00750_lr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-11-17 09:15:03 (93.8 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00750_lr.hea’ saved [602/602]
#
# --2025-11-17 09:15:03--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00751_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00751_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.004s
#
# 2025-11-17 09:15:03 (5.84 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00751_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:03--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00751_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00751_lr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-11-17 09:15:03 (75.6 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00751_lr.hea’ saved [606/606]
#
# --2025-11-17 09:15:03--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00752_lr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 24000 (23K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00752_lr.dat’
#
# physionet.org/files 100%[===================>]  23.44K  --.-KB/s    in 0.003s
#
# 2025-11-17 09:15:03 (6.77 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00752_lr.dat’ saved [24000/24000]
#
# --2025-11-17 09:15:03--  https://physionet.org/files/ptb-xl/1.0.1/records100/00000/00752_lr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... ^C

# %%
# !pip install wfdb
# Out:
# Requirement already satisfied: wfdb in /usr/local/lib/python3.12/dist-packages (4.3.0)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.12/dist-packages (from wfdb) (3.13.2)
# Requirement already satisfied: fsspec>=2023.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2025.3.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.12/dist-packages (from wfdb) (3.10.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2.0.2)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2.3.3)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2.32.4)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (1.16.3)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (2025.10.5)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.10.0->wfdb) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp>=3.10.11->wfdb) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.17.0)

# %%
# !find /content/drive/MyDrive/ptb_xl_download/ -name '*_hr.dat' | head -n 1

# %%
# !wget -r -N -c -np https://physionet.org/files/ptb-xl/1.0.1/ -P /content/drive/MyDrive/ptb_xl_download/
# Out:
# Streaming output truncated to the last 5000 lines.
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21588_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:28:54 (878 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21588_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:54--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21588_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 611 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21588_hr.hea’
#
# physionet.org/files 100%[===================>]     611  --.-KB/s    in 0s
#
# 2025-11-17 13:28:54 (99.6 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21588_hr.hea’ saved [611/611]
#
# --2025-11-17 13:28:54--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21589_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21589_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:28:55 (915 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21589_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:55--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21589_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21589_hr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-11-17 13:28:55 (125 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21589_hr.hea’ saved [602/602]
#
# --2025-11-17 13:28:55--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21590_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21590_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.09s
#
# 2025-11-17 13:28:55 (1.24 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21590_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:55--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21590_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21590_hr.hea’
#
# physionet.org/files 100%[===================>]     604  --.-KB/s    in 0s
#
# 2025-11-17 13:28:55 (52.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21590_hr.hea’ saved [604/604]
#
# --2025-11-17 13:28:55--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21591_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21591_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:28:55 (1.18 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21591_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:55--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21591_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21591_hr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-11-17 13:28:55 (46.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21591_hr.hea’ saved [606/606]
#
# --2025-11-17 13:28:55--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21592_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21592_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:28:55 (839 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21592_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:55--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21592_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 610 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21592_hr.hea’
#
# physionet.org/files 100%[===================>]     610  --.-KB/s    in 0s
#
# 2025-11-17 13:28:56 (57.9 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21592_hr.hea’ saved [610/610]
#
# --2025-11-17 13:28:56--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21593_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21593_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:28:56 (823 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21593_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:56--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21593_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 601 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21593_hr.hea’
#
# physionet.org/files 100%[===================>]     601  --.-KB/s    in 0s
#
# 2025-11-17 13:28:56 (54.0 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21593_hr.hea’ saved [601/601]
#
# --2025-11-17 13:28:56--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21594_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21594_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   646KB/s    in 0.2s
#
# 2025-11-17 13:28:56 (646 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21594_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:56--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21594_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 613 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21594_hr.hea’
#
# physionet.org/files 100%[===================>]     613  --.-KB/s    in 0s
#
# 2025-11-17 13:28:56 (51.0 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21594_hr.hea’ saved [613/613]
#
# --2025-11-17 13:28:56--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21595_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21595_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   632KB/s    in 0.2s
#
# 2025-11-17 13:28:57 (632 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21595_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:57--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21595_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21595_hr.hea’
#
# physionet.org/files 100%[===================>]     604  --.-KB/s    in 0s
#
# 2025-11-17 13:28:57 (49.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21595_hr.hea’ saved [604/604]
#
# --2025-11-17 13:28:57--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21596_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21596_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   545KB/s    in 0.2s
#
# 2025-11-17 13:28:57 (545 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21596_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:57--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21596_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 601 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21596_hr.hea’
#
# physionet.org/files 100%[===================>]     601  --.-KB/s    in 0s
#
# 2025-11-17 13:28:57 (44.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21596_hr.hea’ saved [601/601]
#
# --2025-11-17 13:28:57--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21597_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21597_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   649KB/s    in 0.2s
#
# 2025-11-17 13:28:57 (649 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21597_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:57--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21597_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 601 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21597_hr.hea’
#
# physionet.org/files 100%[===================>]     601  --.-KB/s    in 0s
#
# 2025-11-17 13:28:57 (50.0 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21597_hr.hea’ saved [601/601]
#
# --2025-11-17 13:28:57--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21598_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21598_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   668KB/s    in 0.2s
#
# 2025-11-17 13:28:58 (668 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21598_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:58--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21598_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21598_hr.hea’
#
# physionet.org/files 100%[===================>]     607  --.-KB/s    in 0s
#
# 2025-11-17 13:28:58 (89.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21598_hr.hea’ saved [607/607]
#
# --2025-11-17 13:28:58--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21599_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21599_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:28:58 (832 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21599_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:58--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21599_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 613 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21599_hr.hea’
#
# physionet.org/files 100%[===================>]     613  --.-KB/s    in 0s
#
# 2025-11-17 13:28:58 (54.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21599_hr.hea’ saved [613/613]
#
# --2025-11-17 13:28:58--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21600_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21600_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:28:58 (790 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21600_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:58--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21600_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21600_hr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-11-17 13:28:58 (61.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21600_hr.hea’ saved [602/602]
#
# --2025-11-17 13:28:58--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21601_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21601_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   641KB/s    in 0.2s
#
# 2025-11-17 13:28:59 (641 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21601_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:59--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21601_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21601_hr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-11-17 13:28:59 (45.9 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21601_hr.hea’ saved [602/602]
#
# --2025-11-17 13:28:59--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21602_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21602_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   713KB/s    in 0.2s
#
# 2025-11-17 13:28:59 (713 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21602_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:59--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21602_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21602_hr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-11-17 13:28:59 (50.6 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21602_hr.hea’ saved [606/606]
#
# --2025-11-17 13:28:59--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21603_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21603_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:28:59 (825 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21603_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:28:59--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21603_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21603_hr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-11-17 13:28:59 (42.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21603_hr.hea’ saved [605/605]
#
# --2025-11-17 13:28:59--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21604_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21604_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   671KB/s    in 0.2s
#
# 2025-11-17 13:29:00 (671 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21604_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:00--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21604_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21604_hr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-11-17 13:29:00 (68.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21604_hr.hea’ saved [605/605]
#
# --2025-11-17 13:29:00--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21605_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21605_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   427KB/s    in 0.3s
#
# 2025-11-17 13:29:00 (427 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21605_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:00--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21605_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 611 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21605_hr.hea’
#
# physionet.org/files 100%[===================>]     611  --.-KB/s    in 0s
#
# 2025-11-17 13:29:00 (64.1 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21605_hr.hea’ saved [611/611]
#
# --2025-11-17 13:29:00--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21606_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21606_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   438KB/s    in 0.3s
#
# 2025-11-17 13:29:01 (438 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21606_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:01--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21606_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21606_hr.hea’
#
# physionet.org/files 100%[===================>]     609  --.-KB/s    in 0s
#
# 2025-11-17 13:29:01 (78.8 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21606_hr.hea’ saved [609/609]
#
# --2025-11-17 13:29:01--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21607_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21607_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   450KB/s    in 0.3s
#
# 2025-11-17 13:29:01 (450 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21607_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:01--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21607_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 613 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21607_hr.hea’
#
# physionet.org/files 100%[===================>]     613  --.-KB/s    in 0s
#
# 2025-11-17 13:29:01 (44.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21607_hr.hea’ saved [613/613]
#
# --2025-11-17 13:29:01--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21608_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21608_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   551KB/s    in 0.2s
#
# 2025-11-17 13:29:01 (551 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21608_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:01--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21608_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 612 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21608_hr.hea’
#
# physionet.org/files 100%[===================>]     612  --.-KB/s    in 0s
#
# 2025-11-17 13:29:02 (43.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21608_hr.hea’ saved [612/612]
#
# --2025-11-17 13:29:02--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21609_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21609_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   668KB/s    in 0.2s
#
# 2025-11-17 13:29:02 (668 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21609_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:02--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21609_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 610 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21609_hr.hea’
#
# physionet.org/files 100%[===================>]     610  --.-KB/s    in 0.001s
#
# 2025-11-17 13:29:02 (1.08 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21609_hr.hea’ saved [610/610]
#
# --2025-11-17 13:29:02--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21610_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21610_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   670KB/s    in 0.2s
#
# 2025-11-17 13:29:02 (670 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21610_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:02--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21610_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21610_hr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-11-17 13:29:02 (50.1 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21610_hr.hea’ saved [603/603]
#
# --2025-11-17 13:29:02--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21611_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21611_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   446KB/s    in 0.3s
#
# 2025-11-17 13:29:03 (446 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21611_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:03--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21611_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21611_hr.hea’
#
# physionet.org/files 100%[===================>]     607  --.-KB/s    in 0s
#
# 2025-11-17 13:29:03 (63.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21611_hr.hea’ saved [607/607]
#
# --2025-11-17 13:29:03--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21612_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21612_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   530KB/s    in 0.2s
#
# 2025-11-17 13:29:03 (530 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21612_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:03--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21612_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 612 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21612_hr.hea’
#
# physionet.org/files 100%[===================>]     612  --.-KB/s    in 0s
#
# 2025-11-17 13:29:03 (87.0 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21612_hr.hea’ saved [612/612]
#
# --2025-11-17 13:29:03--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21613_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21613_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   537KB/s    in 0.2s
#
# 2025-11-17 13:29:03 (537 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21613_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:03--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21613_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21613_hr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-11-17 13:29:04 (76.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21613_hr.hea’ saved [606/606]
#
# --2025-11-17 13:29:04--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21614_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21614_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   639KB/s    in 0.2s
#
# 2025-11-17 13:29:04 (639 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21614_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:04--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21614_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21614_hr.hea’
#
# physionet.org/files 100%[===================>]     604  --.-KB/s    in 0s
#
# 2025-11-17 13:29:04 (74.8 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21614_hr.hea’ saved [604/604]
#
# --2025-11-17 13:29:04--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21615_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21615_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   691KB/s    in 0.2s
#
# 2025-11-17 13:29:04 (691 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21615_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:04--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21615_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21615_hr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-11-17 13:29:04 (61.9 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21615_hr.hea’ saved [600/600]
#
# --2025-11-17 13:29:04--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21616_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21616_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:29:04 (847 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21616_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:04--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21616_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 611 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21616_hr.hea’
#
# physionet.org/files 100%[===================>]     611  --.-KB/s    in 0s
#
# 2025-11-17 13:29:04 (89.8 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21616_hr.hea’ saved [611/611]
#
# --2025-11-17 13:29:05--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21617_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21617_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   658KB/s    in 0.2s
#
# 2025-11-17 13:29:05 (658 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21617_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:05--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21617_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 599 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21617_hr.hea’
#
# physionet.org/files 100%[===================>]     599  --.-KB/s    in 0s
#
# 2025-11-17 13:29:05 (53.1 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21617_hr.hea’ saved [599/599]
#
# --2025-11-17 13:29:05--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21618_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21618_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   534KB/s    in 0.2s
#
# 2025-11-17 13:29:05 (534 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21618_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:05--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21618_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21618_hr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-11-17 13:29:05 (51.9 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21618_hr.hea’ saved [605/605]
#
# --2025-11-17 13:29:05--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21619_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21619_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   523KB/s    in 0.2s
#
# 2025-11-17 13:29:06 (523 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21619_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:06--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21619_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21619_hr.hea’
#
# physionet.org/files 100%[===================>]     607  --.-KB/s    in 0s
#
# 2025-11-17 13:29:06 (62.7 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21619_hr.hea’ saved [607/607]
#
# --2025-11-17 13:29:06--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21620_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21620_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   652KB/s    in 0.2s
#
# 2025-11-17 13:29:06 (652 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21620_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:06--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21620_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21620_hr.hea’
#
# physionet.org/files 100%[===================>]     604  --.-KB/s    in 0s
#
# 2025-11-17 13:29:06 (72.2 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21620_hr.hea’ saved [604/604]
#
# --2025-11-17 13:29:06--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21621_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21621_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   676KB/s    in 0.2s
#
# 2025-11-17 13:29:06 (676 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21621_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:06--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21621_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 617 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21621_hr.hea’
#
# physionet.org/files 100%[===================>]     617  --.-KB/s    in 0s
#
# 2025-11-17 13:29:06 (79.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21621_hr.hea’ saved [617/617]
#
# --2025-11-17 13:29:06--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21622_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21622_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:29:07 (856 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21622_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:07--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21622_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21622_hr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-11-17 13:29:07 (63.0 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21622_hr.hea’ saved [603/603]
#
# --2025-11-17 13:29:07--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21623_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21623_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:29:07 (890 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21623_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:07--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21623_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21623_hr.hea’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2025-11-17 13:29:07 (64.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21623_hr.hea’ saved [603/603]
#
# --2025-11-17 13:29:07--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21624_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21624_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:29:07 (915 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21624_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:07--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21624_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21624_hr.hea’
#
# physionet.org/files 100%[===================>]     607  --.-KB/s    in 0s
#
# 2025-11-17 13:29:07 (62.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21624_hr.hea’ saved [607/607]
#
# --2025-11-17 13:29:07--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21625_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21625_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   735KB/s    in 0.2s
#
# 2025-11-17 13:29:08 (735 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21625_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:08--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21625_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 602 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21625_hr.hea’
#
# physionet.org/files 100%[===================>]     602  --.-KB/s    in 0s
#
# 2025-11-17 13:29:08 (92.6 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21625_hr.hea’ saved [602/602]
#
# --2025-11-17 13:29:08--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21626_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21626_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   673KB/s    in 0.2s
#
# 2025-11-17 13:29:08 (673 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21626_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:08--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21626_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 601 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21626_hr.hea’
#
# physionet.org/files 100%[===================>]     601  --.-KB/s    in 0s
#
# 2025-11-17 13:29:08 (68.8 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21626_hr.hea’ saved [601/601]
#
# --2025-11-17 13:29:08--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21627_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21627_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:29:08 (855 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21627_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:08--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21627_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21627_hr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-11-17 13:29:08 (83.9 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21627_hr.hea’ saved [605/605]
#
# --2025-11-17 13:29:08--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21628_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21628_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:29:09 (835 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21628_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:29:09--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21628_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 599 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21628_hr.hea’
#
# physionet.org/files 100%[===================>]     599  --.-KB/s    in 0s
#
# 2025-11-17 13:29:09 (87.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21628_hr.hea’ saved [599/599]
#
# --2025-11-17 13:29:09--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21629_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# ...
#
# --2025-11-17 13:30:11--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21824_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 610 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21824_hr.hea’
#
# physionet.org/files 100%[===================>]     610  --.-KB/s    in 0s
#
# 2025-11-17 13:30:11 (18.5 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21824_hr.hea’ saved [610/610]
#
# --2025-11-17 13:30:11--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21825_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21825_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:30:12 (1.09 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21825_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:12--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21825_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21825_hr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-11-17 13:30:12 (95.1 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21825_hr.hea’ saved [605/605]
#
# --2025-11-17 13:30:12--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21826_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21826_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:30:12 (1.13 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21826_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:12--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21826_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 595 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21826_hr.hea’
#
# physionet.org/files 100%[===================>]     595  --.-KB/s    in 0s
#
# 2025-11-17 13:30:12 (23.2 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21826_hr.hea’ saved [595/595]
#
# --2025-11-17 13:30:12--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21827_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21827_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:30:12 (1013 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21827_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:12--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21827_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21827_hr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-11-17 13:30:12 (9.97 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21827_hr.hea’ saved [605/605]
#
# --2025-11-17 13:30:12--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21828_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21828_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:30:12 (917 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21828_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:12--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21828_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 596 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21828_hr.hea’
#
# physionet.org/files 100%[===================>]     596  --.-KB/s    in 0s
#
# 2025-11-17 13:30:13 (42.2 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21828_hr.hea’ saved [596/596]
#
# --2025-11-17 13:30:13--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21829_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21829_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:30:13 (930 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21829_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:13--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21829_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 606 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21829_hr.hea’
#
# physionet.org/files 100%[===================>]     606  --.-KB/s    in 0s
#
# 2025-11-17 13:30:13 (60.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21829_hr.hea’ saved [606/606]
#
# --2025-11-17 13:30:13--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21830_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21830_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   549KB/s    in 0.2s
#
# 2025-11-17 13:30:13 (549 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21830_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:13--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21830_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 610 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21830_hr.hea’
#
# physionet.org/files 100%[===================>]     610  --.-KB/s    in 0s
#
# 2025-11-17 13:30:13 (26.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21830_hr.hea’ saved [610/610]
#
# --2025-11-17 13:30:13--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21831_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21831_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   555KB/s    in 0.2s
#
# 2025-11-17 13:30:14 (555 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21831_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:14--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21831_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21831_hr.hea’
#
# physionet.org/files 100%[===================>]     608  --.-KB/s    in 0s
#
# 2025-11-17 13:30:14 (32.6 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21831_hr.hea’ saved [608/608]
#
# --2025-11-17 13:30:14--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21832_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21832_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   634KB/s    in 0.2s
#
# 2025-11-17 13:30:14 (634 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21832_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:14--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21832_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 601 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21832_hr.hea’
#
# physionet.org/files 100%[===================>]     601  --.-KB/s    in 0s
#
# 2025-11-17 13:30:14 (64.8 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21832_hr.hea’ saved [601/601]
#
# --2025-11-17 13:30:14--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21833_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21833_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K   679KB/s    in 0.2s
#
# 2025-11-17 13:30:15 (679 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21833_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:15--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21833_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 605 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21833_hr.hea’
#
# physionet.org/files 100%[===================>]     605  --.-KB/s    in 0s
#
# 2025-11-17 13:30:15 (115 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21833_hr.hea’ saved [605/605]
#
# --2025-11-17 13:30:15--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21834_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21834_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:30:15 (834 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21834_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:15--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21834_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 600 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21834_hr.hea’
#
# physionet.org/files 100%[===================>]     600  --.-KB/s    in 0s
#
# 2025-11-17 13:30:15 (53.4 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21834_hr.hea’ saved [600/600]
#
# --2025-11-17 13:30:15--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21835_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21835_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:30:15 (901 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21835_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:15--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21835_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 598 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21835_hr.hea’
#
# physionet.org/files 100%[===================>]     598  --.-KB/s    in 0s
#
# 2025-11-17 13:30:15 (29.0 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21835_hr.hea’ saved [598/598]
#
# --2025-11-17 13:30:15--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21836_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21836_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:30:16 (871 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21836_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:16--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21836_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 607 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21836_hr.hea’
#
# physionet.org/files 100%[===================>]     607  --.-KB/s    in 0s
#
# 2025-11-17 13:30:16 (44.1 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21836_hr.hea’ saved [607/607]
#
# --2025-11-17 13:30:16--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21837_hr.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 120000 (117K) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21837_hr.dat’
#
# physionet.org/files 100%[===================>] 117.19K  --.-KB/s    in 0.1s
#
# 2025-11-17 13:30:16 (823 KB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21837_hr.dat’ saved [120000/120000]
#
# --2025-11-17 13:30:16--  https://physionet.org/files/ptb-xl/1.0.1/records500/21000/21837_hr.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 609 [text/plain]
# Saving to: ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21837_hr.hea’
#
# physionet.org/files 100%[===================>]     609  --.-KB/s    in 0s
#
# 2025-11-17 13:30:16 (70.3 MB/s) - ‘/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/21000/21837_hr.hea’ saved [609/609]
#
# FINISHED --2025-11-17 13:30:16--
# Total wall clock time: 3h 21m 54s
# Downloaded: 85892 files, 2.9G in 1h 5m 56s (781 KB/s)

# %%
# !wget https://physionet.org/files/ptb-xl/1.0.1/ptbxl_database.csv -P /content/drive/MyDrive/mit_bih/physionet.org/files/ptb-xl/1.0.1/
# Out:
# --2025-11-17 13:36:58--  https://physionet.org/files/ptb-xl/1.0.1/ptbxl_database.csv
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6602796 (6.3M) [text/plain]
# Saving to: ‘/content/drive/MyDrive/mit_bih/physionet.org/files/ptb-xl/1.0.1/ptbxl_database.csv’
#
# ptbxl_database.csv  100%[===================>]   6.30M   713KB/s    in 4.5s
#
# 2025-11-17 13:37:03 (1.39 MB/s) - ‘/content/drive/MyDrive/mit_bih/physionet.org/files/ptb-xl/1.0.1/ptbxl_database.csv’ saved [6602796/6602796]

# %%
# !wget https://physionet.org/files/ptb-xl/1.0.1/scp_statements.csv -P /content/drive/MyDrive/mit_bih/physionet.org/files/ptb-xl/1.0.1/
# Out:
# --2025-11-17 13:38:14--  https://physionet.org/files/ptb-xl/1.0.1/scp_statements.csv
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9720 (9.5K) [text/plain]
# Saving to: ‘/content/drive/MyDrive/mit_bih/physionet.org/files/ptb-xl/1.0.1/scp_statements.csv’
#
# scp_statements.csv  100%[===================>]   9.49K  --.-KB/s    in 0.005s
#
# 2025-11-17 13:38:14 (1.98 MB/s) - ‘/content/drive/MyDrive/mit_bih/physionet.org/files/ptb-xl/1.0.1/scp_statements.csv’ saved [9720/9720]

# %%
import wfdb
import numpy as np

record_path = "/content/drive/MyDrive/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records100/00000/00734_lr"

# Load record
record = wfdb.rdsamp(record_path)

signal = record[0]   # ECG data (samples × 12 leads)
metadata = record[1] # sampling frequency, etc.

# %%
print(metadata['sig_name'])
print(metadata['fs'])
# Out:
# ['I', 'II', 'III', 'AVR', 'AVL', 'AVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6']
# 100

# %%
lead_II = signal[:, 1]
lead_V5 = signal[:, 10]

combined_sum = lead_II + lead_V5

# %%
from scipy.signal import resample

def resample_to_360(sig, original_fs=100, target_fs=360):
    n = int(len(sig) * target_fs / original_fs)
    return resample(sig, n)

combined_sum = resample_to_360(combined_sum, 100, 360)

# %%
# Create windows (256 samples)
def create_windows(sig, size=256, step=256):
    return np.array([sig[i:i+size]
                     for i in range(0, len(sig)-size, step)])

windows = create_windows(combined_sum)

# %%
import torch

X = torch.tensor(windows).float().unsqueeze(1)  # shape: (batch, 1, 256)

# %%
from sklearn.metrics import classification_report, accuracy_score, f1_score
import pandas as pd
import numpy as np

# %%
def evaluate_model(name, y_true, y_pred):
    report = classification_report(y_true, y_pred, output_dict=True)

    accuracy = accuracy_score(y_true, y_pred)
    macro_f1 = f1_score(y_true, y_pred, average='macro')

    # Extract individual class F1
    f1_N = report['N']['f1-score'] if 'N' in report else 0
    f1_S = report['S']['f1-score'] if 'S' in report else 0
    f1_V = report['V']['f1-score'] if 'V' in report else 0
    f1_F = report['F']['f1-score'] if 'F' in report else 0

    return {
        "Model": name,
        "Accuracy": round(accuracy*100, 2),
        "Macro F1": round(macro_f1, 4),
        "N F1": round(f1_N, 4),
        "S F1": round(f1_S, 4),
        "V F1": round(f1_V, 4),
        "F F1": round(f1_F, 4)
    }, report

# %%
# %whos
# Out:
# Variable                       Type         Data/Info
# -----------------------------------------------------
# DATA_2017_PATH                 str          /content/drive/MyDrive/1l<...>d/physionet/training2017/
# FIXED_LENGTH                   int          5000
# LabelEncoder                   type         <class 'sklearn.preproces<...>ing._label.LabelEncoder'>
# PTB_XL_PATH                    str          /content/drive/MyDrive/mi<...>t.org/files/ptb-xl/1.0.1/
# SAMPLING_RATE                  int          500
# SAMPLING_RATE_TARGET           int          500
# SAVE_DIR                       str          /content/drive/MyDrive/mit_bih/
# StandardScaler                 type         <class 'sklearn.preproces<...>ng._data.StandardScaler'>
# X                              Tensor       tensor([[[ 0.0480,  0.057<...>535, -0.0510, -0.0479]]])
# X_data                         ndarray      0: 0 elems, type `float64`, 0 bytes
# X_data_list                    ndarray      0: 0 elems, type `float64`, 0 bytes
# Y_filtered                     DataFrame    Empty DataFrame\nColumns:<...>\n\n[0 rows x 28 columns]
# Y_meta                         DataFrame            patient_id   age <...>[21837 rows x 28 columns]
# accuracy_score                 function     <function accuracy_score at 0x7a76ce1667a0>
# aggregate_diagnostic_classes   function     <function aggregate_diagn<...>lasses at 0x7a77b0ebc860>
# ast                            module       <module 'ast' from '/usr/lib/python3.12/ast.py'>
# classification_report          function     <function classification_<...>report at 0x7a76ce167c40>
# combined_sum                   ndarray      3600: 3600 elems, type `float64`, 28800 bytes
# compute_class_weight           function     <function compute_class_weight at 0x7a77b2216de0>
# create_windows                 function     <function create_windows at 0x7a77b1898c20>
# data_dir                       str          /content/drive/MyDrive/mit_bih/
# evaluate_model                 function     <function evaluate_model at 0x7a76ce2b7ba0>
# f1_score                       function     <function f1_score at 0x7a76ce167060>
# joblib                         module       <module 'joblib' from '/u<...>ages/joblib/__init__.py'>
# lead_II                        ndarray      1000: 1000 elems, type `float64`, 8000 bytes
# lead_V5                        ndarray      1000: 1000 elems, type `float64`, 8000 bytes
# load_raw_data                  function     <function load_raw_data at 0x7a77b0ebc040>
# metadata                       dict         n=8
# np                             module       <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# original_filtered_ids          list         n=16272
# os                             module       <module 'os' (frozen)>
# pd                             module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# record                         tuple        n=2
# record_path                    str          /content/drive/MyDrive/pt<...>records100/00000/00734_lr
# reports                        dict         n=0
# resample                       function     <function resample at 0x7a77a9fd5d00>
# resample_to_360                function     <function resample_to_360 at 0x7a77b1ae2340>
# results                        list         n=0
# signal                         ndarray      1000x12: 12000 elems, type `float64`, 96000 bytes
# skipped_ids_list               list         n=16272
# torch                          module       <module 'torch' from '/us<...>kages/torch/__init__.py'>
# tqdm                           type         <class 'tqdm.auto.tqdm'>
# wfdb                           module       <module 'wfdb' from '/usr<...>ckages/wfdb/__init__.py'>
# windows                        ndarray      14x256: 3584 elems, type `float64`, 28672 bytes
# y_data                         ndarray      0: 0 elems, type `object`, 0 bytes

# %%
import numpy as np
import wfdb
import os
import joblib
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler

# ================================
#       CONFIGURATION
# ================================
DATA_DIR = '/content/drive/MyDrive/mit_bih/'

MODEL_PATH = os.path.join(DATA_DIR, 'my_summed_signal_model.keras')
ENCODER_PATH = os.path.join(DATA_DIR, 'label_encoder.joblib')

# FULL PATH TO RECORD (without .hea)
RECORD_PATH = "/content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/10000/10002_hr"

INPUT_LENGTH = 180   # MIT-BIH model input length


# ================================
#   PREPROCESSING FUNCTION
# ================================
def preprocess_single_record(record_path):
    print(f"Loading record: {record_path}")

    # ❗ FIX: load directly via full path
    record = wfdb.rdrecord(record_path)

    print(f"Record loaded successfully. Fs = {record.fs} Hz, Channels = {record.n_sig}")

    if record.n_sig < 2:
        raise ValueError("Record must have at least 2 channels.")

    ch1 = record.p_signal[:, 0]
    ch2 = record.p_signal[:, 1]

    summed = ch1 + ch2

    summed = summed.reshape(-1, 1)
    scaler = StandardScaler()
    scaled = scaler.fit_transform(summed)

    if scaled.shape[0] < INPUT_LENGTH:
        raise ValueError(f"Record has only {scaled.shape[0]} samples, need 180")

    segment = scaled[:INPUT_LENGTH, 0]
    X_input = np.expand_dims(segment, axis=(0, -1))
    return X_input


# ================================
#       LOAD MODEL & PREDICT
# ================================
try:
    print("\nLoading model and label encoder...")
    model = load_model(MODEL_PATH)
    label_encoder = joblib.load(ENCODER_PATH)
    print("Model and encoder loaded.\n")

    X_test = preprocess_single_record(RECORD_PATH)

    print("Predicting...")
    prediction_prob = model.predict(X_test, verbose=0)
    prediction_class = np.argmax(prediction_prob, axis=1)
    prediction_label = label_encoder.inverse_transform(prediction_class)

    print("\n===========================================")
    print(f"Prediction Complete for Record: {RECORD_PATH}")
    print(f"Classes: {', '.join(label_encoder.classes_)}")
    print(f"Predicted Label: {prediction_label[0]}")
    print(f"Confidence (Softmax): {prediction_prob[0].round(4)}")
    print("===========================================")

except Exception as e:
    print("\n❌ ERROR OCCURRED:")
    print(e)
# Out:
# Loading model and label encoder...
# Model and encoder loaded.
#
# Loading record: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/10000/10002_hr
# Record loaded successfully. Fs = 500 Hz, Channels = 12
# Predicting...
#
# ===========================================
# Prediction Complete for Record: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/10000/10002_hr
# Classes: F, N, S, V
# Predicted Label: N
# Confidence (Softmax): [0.     0.9775 0.     0.0225]
# ===========================================

# %%
import os
import wfdb
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model
import joblib
import csv

DATA_DIR = "/content/drive/MyDrive/mit_bih/"
MODEL_PATH = os.path.join(DATA_DIR, "my_summed_signal_model.keras")
ENCODER_PATH = os.path.join(DATA_DIR, "label_encoder.joblib")

PTB_XL_ROOT = os.path.join(
    DATA_DIR,
    "ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500"
)

INPUT_LENGTH = 180   # Your model expects 180 samples

# --------------------------------------------------------
# LOAD MODEL + ENCODER
# --------------------------------------------------------
model = load_model(MODEL_PATH)
label_encoder = joblib.load(ENCODER_PATH)
classes = list(label_encoder.classes_)

print("Loaded CNN + Encoder")
print("Classes:", classes)

# --------------------------------------------------------
# PREPROCESSING
# --------------------------------------------------------
def preprocess_record(record_path):
    """Load a PTB-XL record and return a (1,180,1) segment."""
    rec = wfdb.rdrecord(record_path)

    ch1 = rec.p_signal[:, 0]
    ch2 = rec.p_signal[:, 1]
    summed = ch1 + ch2

    summed = summed.reshape(-1, 1)
    scaled = StandardScaler().fit_transform(summed)

    if scaled.shape[0] < INPUT_LENGTH:
        return None  # too short

    segment = scaled[:INPUT_LENGTH, 0]
    return np.expand_dims(segment, axis=(0, -1))

# --------------------------------------------------------
# OUTPUT CSV
# --------------------------------------------------------
output_csv = "/content/drive/MyDrive/ptb_xl_predictions.csv"
csv_file = open(output_csv, "w", newline="")
writer = csv.writer(csv_file)
writer.writerow(["record", "predicted_class", "confidence", "probs"])

# --------------------------------------------------------
# PREDICT ON ALL /records500 FILES
# --------------------------------------------------------
print("\n--- Starting predictions on PTB-XL ---\n")

for folder in sorted(os.listdir(PTB_XL_ROOT)):

    folder_path = os.path.join(PTB_XL_ROOT, folder)
    if not os.path.isdir(folder_path):
        continue

    for f in os.listdir(folder_path):

        if f.endswith("_hr.hea") or f.endswith("_lr.hea"):
            base = f.replace(".hea", "")
            record_path = os.path.join(folder_path, base)

            print("Predicting:", record_path)

            X = preprocess_record(record_path)
            if X is None:
                print("  Skipped (too short)")
                continue

            probs = model.predict(X, verbose=0)[0]
            pred_idx = np.argmax(probs)
            pred_class = classes[pred_idx]
            confidence = float(probs[pred_idx])

            print(f" → Class: {pred_class}  (Conf: {confidence:.4f})")

            writer.writerow([record_path, pred_class, confidence, probs.tolist()])

csv_file.close()
print("\nDONE! Saved predictions to:")
print(output_csv)
# Out:
# Loaded CNN + Encoder
# Classes: ['F', 'N', 'S', 'V']
#
# --- Starting predictions on PTB-XL ---
#
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00001_hr
#  → Class: S  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00002_hr
#  → Class: V  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00003_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00004_hr
#  → Class: V  (Conf: 0.9995)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00005_hr
#  → Class: V  (Conf: 0.8340)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00006_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00007_hr
#  → Class: F  (Conf: 0.9764)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00008_hr
#  → Class: F  (Conf: 0.7330)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00009_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00010_hr
#  → Class: V  (Conf: 0.9983)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00011_hr
#  → Class: N  (Conf: 0.7330)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00012_hr
#  → Class: S  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00013_hr
#  → Class: S  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00014_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00015_hr
#  → Class: V  (Conf: 0.9982)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00016_hr
#  → Class: V  (Conf: 0.9967)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00017_hr
#  → Class: N  (Conf: 0.7693)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00018_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00019_hr
#  → Class: F  (Conf: 0.7077)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00020_hr
#  → Class: N  (Conf: 0.8617)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00021_hr
#  → Class: N  (Conf: 0.9324)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00022_hr
#  → Class: V  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00023_hr
#  → Class: V  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00024_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00025_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00026_hr
#  → Class: F  (Conf: 0.9923)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00027_hr
#  → Class: V  (Conf: 0.9995)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00028_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00029_hr
#  → Class: V  (Conf: 0.5961)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00030_hr
#  → Class: V  (Conf: 0.5655)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00031_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00032_hr
#  → Class: V  (Conf: 0.7577)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00033_hr
#  → Class: V  (Conf: 0.9919)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00034_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00035_hr
#  → Class: N  (Conf: 0.9862)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00036_hr
#  → Class: N  (Conf: 0.9991)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00037_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00038_hr
#  → Class: S  (Conf: 0.5745)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00039_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00040_hr
#  → Class: V  (Conf: 0.8275)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00041_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00042_hr
#  → Class: N  (Conf: 0.9617)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00043_hr
#  → Class: S  (Conf: 0.9997)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00044_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00045_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00046_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00047_hr
#  → Class: N  (Conf: 0.7476)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00048_hr
#  → Class: N  (Conf: 0.9981)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00049_hr
#  → Class: V  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00050_hr
#  → Class: V  (Conf: 0.9744)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00051_hr
#  → Class: V  (Conf: 0.7216)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00052_hr
#  → Class: S  (Conf: 0.9997)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00053_hr
#  → Class: V  (Conf: 0.9973)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00054_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00055_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00056_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00057_hr
#  → Class: V  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00058_hr
#  → Class: V  (Conf: 0.9948)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00059_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00060_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00061_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00062_hr
#  → Class: V  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00063_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00064_hr
#  → Class: F  (Conf: 0.9705)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00065_hr
#  → Class: V  (Conf: 0.9994)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00066_hr
#  → Class: N  (Conf: 0.9832)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00067_hr
#  → Class: S  (Conf: 0.9996)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00068_hr
#  → Class: N  (Conf: 0.9958)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00069_hr
#  → Class: S  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00070_hr
#  → Class: S  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00071_hr
#  → Class: V  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00072_hr
#  → Class: N  (Conf: 0.5915)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00073_hr
#  → Class: V  (Conf: 0.9989)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00074_hr
#  → Class: N  (Conf: 0.9488)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00075_hr
#  → Class: N  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00076_hr
#  → Class: N  (Conf: 0.5390)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00077_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00078_hr
#  → Class: S  (Conf: 0.9605)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00079_hr
#  → Class: F  (Conf: 0.5082)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00080_hr
#  → Class: N  (Conf: 0.9781)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00081_hr
#  → Class: N  (Conf: 0.9993)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00082_hr
#  → Class: V  (Conf: 0.9020)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00083_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00084_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00085_hr
#  → Class: V  (Conf: 0.9241)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00086_hr
#  → Class: N  (Conf: 0.7582)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00087_hr
#  → Class: V  (Conf: 0.9481)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00088_hr
#  → Class: N  (Conf: 0.9382)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00089_hr
#  → Class: V  (Conf: 0.9917)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00090_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00091_hr
#  → Class: N  (Conf: 0.6378)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00092_hr
#  → Class: N  (Conf: 0.8356)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00093_hr
#  → Class: V  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00094_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00095_hr
#  → Class: F  (Conf: 0.9602)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00096_hr
#  → Class: V  (Conf: 0.8553)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00097_hr
#  → Class: S  (Conf: 0.9646)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00098_hr
#  → Class: V  (Conf: 0.5237)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00099_hr
#  → Class: V  (Conf: 0.6872)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00100_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00101_hr
#  → Class: V  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00102_hr
#  → Class: N  (Conf: 0.9996)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00103_hr
#  → Class: V  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00104_hr
#  → Class: S  (Conf: 0.9996)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00105_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00106_hr
#  → Class: V  (Conf: 0.4542)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00107_hr
#  → Class: N  (Conf: 0.9589)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00108_hr
#  → Class: N  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00109_hr
#  → Class: V  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00110_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00111_hr
#  → Class: N  (Conf: 0.5573)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00112_hr
#  → Class: F  (Conf: 0.9118)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00113_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00114_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00115_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00116_hr
#  → Class: V  (Conf: 0.9088)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00117_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00118_hr
#  → Class: N  (Conf: 0.9360)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00119_hr
#  → Class: F  (Conf: 0.9119)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00120_hr
#  → Class: S  (Conf: 0.8701)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00121_hr
#  → Class: N  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00122_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00123_hr
#  → Class: N  (Conf: 0.9223)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00124_hr
#  → Class: N  (Conf: 0.9970)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00125_hr
#  → Class: S  (Conf: 0.9818)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00126_hr
#  → Class: F  (Conf: 0.9483)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00127_hr
#  → Class: S  (Conf: 0.5641)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00128_hr
#  → Class: V  (Conf: 0.7534)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00129_hr
#  → Class: F  (Conf: 0.7672)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00130_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00131_hr
#  → Class: V  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00132_hr
#  → Class: V  (Conf: 0.9777)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00133_hr
#  → Class: S  (Conf: 0.8638)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00134_hr
#  → Class: S  (Conf: 0.9984)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00135_hr
#  → Class: N  (Conf: 0.9964)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00136_hr
#  → Class: N  (Conf: 0.9487)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00137_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00138_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00139_hr
#  → Class: V  (Conf: 0.9850)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00140_hr
#  → Class: V  (Conf: 0.9965)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00141_hr
#  → Class: V  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00142_hr
#  → Class: V  (Conf: 0.9790)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00143_hr
#  → Class: N  (Conf: 0.5816)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00144_hr
#  → Class: N  (Conf: 0.5816)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00145_hr
#  → Class: V  (Conf: 0.6226)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00146_hr
#  → Class: V  (Conf: 0.9888)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00147_hr
#  → Class: V  (Conf: 0.9741)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00148_hr
#  → Class: V  (Conf: 0.9956)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00149_hr
#  → Class: S  (Conf: 0.9909)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00150_hr
#  → Class: N  (Conf: 0.8993)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00151_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00152_hr
#  → Class: N  (Conf: 0.9954)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00153_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00154_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00155_hr
#  → Class: N  (Conf: 0.8699)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00156_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00157_hr
#  → Class: N  (Conf: 0.5633)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00158_hr
#  → Class: V  (Conf: 0.9875)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00159_hr
#  → Class: V  (Conf: 0.8660)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00160_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00161_hr
#  → Class: F  (Conf: 0.9849)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00162_hr
#  → Class: F  (Conf: 0.7586)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00163_hr
#  → Class: V  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00164_hr
#  → Class: V  (Conf: 0.9981)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00165_hr
#  → Class: S  (Conf: 0.9831)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00166_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00167_hr
#  → Class: F  (Conf: 0.9151)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00168_hr
#  → Class: S  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00169_hr
#  → Class: S  (Conf: 0.5609)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00170_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00171_hr
#  → Class: F  (Conf: 0.9991)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00172_hr
#  → Class: V  (Conf: 0.9413)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00173_hr
#  → Class: S  (Conf: 0.5724)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00174_hr
#  → Class: V  (Conf: 0.9318)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00175_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00176_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00177_hr
#  → Class: N  (Conf: 0.6435)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00178_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00179_hr
#  → Class: N  (Conf: 0.9954)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00180_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00181_hr
#  → Class: N  (Conf: 0.9968)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00182_hr
#  → Class: N  (Conf: 0.9898)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00183_hr
#  → Class: N  (Conf: 0.9302)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00184_hr
#  → Class: N  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00185_hr
#  → Class: V  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00186_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00187_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00188_hr
#  → Class: V  (Conf: 0.6712)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00189_hr
#  → Class: N  (Conf: 0.8287)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00190_hr
#  → Class: V  (Conf: 0.9830)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00191_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00192_hr
#  → Class: V  (Conf: 0.9926)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00193_hr
#  → Class: V  (Conf: 0.9988)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00194_hr
#  → Class: N  (Conf: 0.9635)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00195_hr
#  → Class: V  (Conf: 0.9492)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00196_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00197_hr
#  → Class: S  (Conf: 0.5084)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00198_hr
#  → Class: V  (Conf: 0.9977)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00199_hr
#  → Class: N  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00200_hr
#  → Class: V  (Conf: 0.9014)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00201_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00202_hr
#  → Class: V  (Conf: 0.9895)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00203_hr
#  → Class: F  (Conf: 0.9263)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00204_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00205_hr
#  → Class: S  (Conf: 0.9705)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00206_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00207_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00208_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00209_hr
#  → Class: S  (Conf: 0.9914)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00210_hr
#  → Class: N  (Conf: 0.9849)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00211_hr
#  → Class: V  (Conf: 0.9989)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00212_hr
#  → Class: N  (Conf: 0.9989)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00213_hr
#  → Class: V  (Conf: 0.8379)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00214_hr
#  → Class: S  (Conf: 0.5055)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00215_hr
#  → Class: V  (Conf: 0.9937)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00216_hr
#  → Class: V  (Conf: 0.9963)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00217_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00218_hr
#  → Class: S  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00219_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00220_hr
#  → Class: V  (Conf: 0.9701)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00221_hr
#  → Class: V  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00222_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00223_hr
#  → Class: V  (Conf: 0.9981)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00224_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00225_hr
#  → Class: S  (Conf: 0.9970)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00226_hr
#  → Class: N  (Conf: 0.9137)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00227_hr
#  → Class: N  (Conf: 0.9901)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00228_hr
#  → Class: V  (Conf: 0.5112)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00229_hr
#  → Class: N  (Conf: 0.9944)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00230_hr
#  → Class: V  (Conf: 0.6832)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00231_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00232_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00233_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00234_hr
#  → Class: N  (Conf: 0.9917)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00235_hr
#  → Class: V  (Conf: 0.7099)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00236_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00237_hr
#  → Class: F  (Conf: 0.8845)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00238_hr
#  → Class: N  (Conf: 0.8973)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00239_hr
#  → Class: N  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00240_hr
#  → Class: F  (Conf: 0.8214)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00241_hr
#  → Class: N  (Conf: 0.9301)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00242_hr
#  → Class: V  (Conf: 0.7751)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00243_hr
#  → Class: N  (Conf: 0.9908)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00244_hr
#  → Class: V  (Conf: 0.9477)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00245_hr
#  → Class: N  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00246_hr
#  → Class: S  (Conf: 0.9522)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00247_hr
#  → Class: N  (Conf: 0.9994)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00248_hr
#  → Class: N  (Conf: 0.4156)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00249_hr
#  → Class: V  (Conf: 0.9992)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00250_hr
#  → Class: N  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00251_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00252_hr
#  → Class: V  (Conf: 0.5549)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00253_hr
#  → Class: N  (Conf: 0.9996)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00254_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00255_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00256_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00257_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00258_hr
#  → Class: V  (Conf: 0.9202)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00259_hr
#  → Class: S  (Conf: 0.7706)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00260_hr
#  → Class: N  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00261_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00262_hr
#  → Class: V  (Conf: 0.9807)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00263_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00264_hr
#  → Class: V  (Conf: 0.9886)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00265_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00266_hr
#  → Class: V  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00267_hr
#  → Class: N  (Conf: 0.9995)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00268_hr
#  → Class: F  (Conf: 0.5659)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00269_hr
#  → Class: V  (Conf: 0.9981)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00270_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00271_hr
#  → Class: N  (Conf: 0.8656)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00272_hr
#  → Class: N  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00273_hr
#  → Class: V  (Conf: 0.9994)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00274_hr
#  → Class: F  (Conf: 0.9991)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00275_hr
#  → Class: V  (Conf: 0.5871)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00276_hr
#  → Class: V  (Conf: 0.9879)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00277_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00278_hr
#  → Class: V  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00279_hr
#  → Class: S  (Conf: 0.9997)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00280_hr
#  → Class: V  (Conf: 0.9961)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00281_hr
#  → Class: N  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00282_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00283_hr
#  → Class: V  (Conf: 0.9321)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00284_hr
#  → Class: S  (Conf: 0.9144)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00285_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00286_hr
#  → Class: S  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00287_hr
#  → Class: V  (Conf: 0.9714)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00288_hr
#  → Class: V  (Conf: 0.9089)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00289_hr
#  → Class: F  (Conf: 0.9910)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00290_hr
#  → Class: N  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00291_hr
#  → Class: V  (Conf: 0.9635)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00292_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00293_hr
#  → Class: V  (Conf: 0.9768)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00294_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00295_hr
#  → Class: V  (Conf: 0.8756)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00296_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00297_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00298_hr
#  → Class: S  (Conf: 0.9984)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00299_hr
#  → Class: V  (Conf: 0.9942)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00300_hr
#  → Class: V  (Conf: 0.9992)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00301_hr
#  → Class: V  (Conf: 0.9602)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00302_hr
#  → Class: F  (Conf: 0.9997)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00303_hr
#  → Class: V  (Conf: 0.7692)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00304_hr
#  → Class: N  (Conf: 0.9747)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00305_hr
#  → Class: F  (Conf: 0.9173)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00306_hr
#  → Class: S  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00307_hr
#  → Class: S  (Conf: 0.5348)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00308_hr
#  → Class: N  (Conf: 0.9066)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00309_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00310_hr
#  → Class: S  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00311_hr
#  → Class: F  (Conf: 0.8705)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00312_hr
#  → Class: F  (Conf: 0.9725)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00313_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00314_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00315_hr
#  → Class: V  (Conf: 0.9993)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00316_hr
#  → Class: V  (Conf: 0.5227)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00317_hr
#  → Class: V  (Conf: 0.9481)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00318_hr
#  → Class: N  (Conf: 0.8603)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00319_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00320_hr
#  → Class: V  (Conf: 0.9251)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00321_hr
#  → Class: V  (Conf: 0.9998)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00322_hr
#  → Class: V  (Conf: 0.9239)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00323_hr
#  → Class: V  (Conf: 0.9895)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00324_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00325_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00326_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00327_hr
#  → Class: V  (Conf: 0.9309)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00328_hr
#  → Class: V  (Conf: 1.0000)
# ...
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01693_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01694_hr
#  → Class: V  (Conf: 0.9117)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01695_hr
#  → Class: F  (Conf: 0.9152)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01696_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01697_hr
#  → Class: V  (Conf: 0.9891)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01698_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01699_hr
#  → Class: N  (Conf: 0.9995)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01700_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01701_hr
#  → Class: S  (Conf: 0.9556)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01702_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01703_hr
#  → Class: N  (Conf: 0.9992)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01704_hr
#  → Class: V  (Conf: 0.9997)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01705_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01706_hr
#  → Class: N  (Conf: 0.9777)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01707_hr
#  → Class: N  (Conf: 0.8001)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01708_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01709_hr
#  → Class: V  (Conf: 0.6991)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01710_hr
#  → Class: V  (Conf: 0.9744)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01711_hr
#  → Class: S  (Conf: 0.6674)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01712_hr
#  → Class: N  (Conf: 0.9567)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01713_hr
#  → Class: V  (Conf: 0.9941)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01714_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01715_hr
#  → Class: F  (Conf: 0.8090)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01716_hr
#  → Class: N  (Conf: 0.8400)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01717_hr
#  → Class: V  (Conf: 0.9924)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01718_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01719_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01720_hr
#  → Class: S  (Conf: 0.6672)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01721_hr
#  → Class: F  (Conf: 0.7806)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01722_hr
#  → Class: N  (Conf: 0.9991)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01723_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01724_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01725_hr
#  → Class: N  (Conf: 0.9990)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01726_hr
#  → Class: F  (Conf: 0.8798)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01727_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01728_hr
#  → Class: S  (Conf: 0.5902)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01729_hr
#  → Class: V  (Conf: 0.9526)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01730_hr
#  → Class: S  (Conf: 0.5985)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01731_hr
#  → Class: V  (Conf: 0.9050)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01732_hr
#  → Class: S  (Conf: 0.3874)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01733_hr
#  → Class: V  (Conf: 0.5068)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01734_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01735_hr
#  → Class: V  (Conf: 0.9841)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01736_hr
#  → Class: F  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01737_hr
#  → Class: N  (Conf: 0.9865)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01738_hr
#  → Class: V  (Conf: 0.9747)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01739_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01740_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01741_hr
#  → Class: N  (Conf: 0.9964)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01742_hr
#  → Class: V  (Conf: 0.9779)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01743_hr
#  → Class: N  (Conf: 0.5392)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01744_hr
#  → Class: V  (Conf: 0.9862)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01745_hr
#  → Class: V  (Conf: 0.7248)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01746_hr
#  → Class: V  (Conf: 0.5403)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01747_hr
#  → Class: V  (Conf: 0.9216)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01748_hr
#  → Class: N  (Conf: 0.6361)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01749_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01750_hr
#  → Class: N  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01751_hr
#  → Class: F  (Conf: 0.8958)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01752_hr
#  → Class: V  (Conf: 0.9981)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01753_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01754_hr
#  → Class: N  (Conf: 0.9774)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01755_hr
#  → Class: V  (Conf: 0.9138)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01756_hr
#  → Class: V  (Conf: 0.9999)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01757_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01758_hr
#  → Class: V  (Conf: 0.9494)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01759_hr
#  → Class: S  (Conf: 0.8147)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01760_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01761_hr
#  → Class: N  (Conf: 0.9967)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01762_hr
#  → Class: N  (Conf: 0.8964)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01763_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01764_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01765_hr
#  → Class: F  (Conf: 0.6361)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01766_hr
#  → Class: S  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01767_hr
#  → Class: V  (Conf: 0.9779)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01768_hr
#  → Class: N  (Conf: 0.9991)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01769_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01770_hr
#  → Class: V  (Conf: 0.8610)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01771_hr
#  → Class: N  (Conf: 0.9992)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01772_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01773_hr
#  → Class: V  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01774_hr
#  → Class: N  (Conf: 1.0000)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01775_hr
#  → Class: F  (Conf: 0.9600)
# Predicting: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/01000/01776_hr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-820360184.py in <cell line: 0>()
#      80                 continue
#      81
# ---> 82             probs = model.predict(X, verbose=0)[0]
#      83             pred_idx = np.argmax(probs)
#      84             pred_class = classes[pred_idx]
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in predict(self, x, batch_size, verbose, steps, callbacks)
#     564                 callbacks.on_predict_batch_begin(step)
#     565                 data = get_data(iterator)
# --> 566                 batch_outputs = self.predict_function(data)
#     567                 outputs = append_to_outputs(batch_outputs, outputs)
#     568                 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     130   args = args if args else ()
#     131   kwargs = kwargs if kwargs else {}
# --> 132   function = trace_function(
#     133       args=args, kwargs=kwargs, tracing_options=tracing_options
#     134   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     218     )
#     219
# --> 220   current_func_context = function_context.make_function_context(
#     221       tracing_options.scope_type
#     222   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/function_context.py in make_function_context(scope_type)
#      90     in_cross_replica_context = (strategy_stack[-1].replica_context is None)  # pylint: disable=protected-access
#      91   except (AttributeError, IndexError):
# ---> 92     pass
#      93
#      94   if save_context.in_save_context():
#
# KeyboardInterrupt:

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/ptb_xl_predictions.csv')
df.head()
df.tail()
# Out:
#                                                  record predicted_class  \
# 1614  /content/drive/MyDrive/mit_bih/ptb_xl_download...               N
# 1615  /content/drive/MyDrive/mit_bih/ptb_xl_download...               V
# 1616  /content/drive/MyDrive/mit_bih/ptb_xl_download...               F
# 1617  /content/drive/MyDrive/mit_bih/ptb_xl_download...               V
# 1618  /content/drive/MyDrive/mit_bih/ptb_xl_download...               N
#
#       confidence                                              probs
# 1614    0.999986  [1.1548934551741663e-11, 0.999985933303833, 2....
# 1615    0.999960  [6.587531631296883e-10, 3.959725654567592e-05,...
# 1616    0.989768  [0.9897676110267639, 5.095416054246016e-05, 8....
# 1617    1.000000  [5.206834312668218e-13, 3.204432577372609e-16,...
# 1618    0.998056  [0.00042868807213380933, 0.998056173324585, 0....

# %%
import numpy as np
import wfdb
import os
import joblib
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler

DATA_DIR = '/content/drive/MyDrive/mit_bih/'

MODEL_PATH = os.path.join(DATA_DIR, 'my_summed_signal_model.keras')
ENCODER_PATH = os.path.join(DATA_DIR, 'label_encoder.joblib')

PTB_XL_ROOT = os.path.join(
    DATA_DIR,
    'ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500'
)

RECORD_NAME = "10000/10002_hr"

INPUT_LENGTH = 180

def preprocess_all_leads(record_name):

    # Build full file path
    full_path = os.path.join(PTB_XL_ROOT, record_name)

    print("Loading:", full_path)

    # Load directly (no pn_dir!)
    record = wfdb.rdrecord(full_path)

    if record is None:
        raise FileNotFoundError("Record could not be loaded.")

    print(f"Loaded. Fs={record.fs}, Leads={record.n_sig}")

    # Sum ALL 12 leads
    summed = np.sum(record.p_signal, axis=1)

    # Standardize
    scaled = StandardScaler().fit_transform(summed.reshape(-1, 1))

    if scaled.shape[0] < INPUT_LENGTH:
        raise ValueError("Record too short!")

    segment = scaled[:INPUT_LENGTH, 0]
    return np.expand_dims(segment, axis=(0, -1))


# Load model
model = load_model(MODEL_PATH)
label_encoder = joblib.load(ENCODER_PATH)

print("\nModel + Encoder Loaded\n")

try:
    X = preprocess_all_leads(RECORD_NAME)

    print("\nPredicting...")
    probs = model.predict(X, verbose=0)[0]

    idx = np.argmax(probs)
    pred = label_encoder.inverse_transform([idx])[0]
    conf = float(probs[idx])

    print("\n===============================")
    print(f"Record: {RECORD_NAME}")
    print("Prediction using ALL 12 LEADS summed")
    print("-------------------------------")
    print(f"Predicted Class: {pred}")
    print(f"Confidence: {conf:.4f}")
    print(f"Softmax: {np.round(probs, 4)}")
    print("===============================\n")

except Exception as e:
    print("❌ ERROR:", e)
# Out:
# Model + Encoder Loaded
#
# Loading: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/10000/10002_hr
# Loaded. Fs=500, Leads=12
#
# Predicting...
#
# ===============================
# Record: 10000/10002_hr
# Prediction using ALL 12 LEADS summed
# -------------------------------
# Predicted Class: V
# Confidence: 0.9883
# Softmax: [0.0117 0.     0.     0.9883]
# ===============================

# %%
import numpy as np
import wfdb
import os
import joblib
from tensorflow.keras.models import load_model
from sklearn.preprocessing import StandardScaler

DATA_DIR = '/content/drive/MyDrive/mit_bih/'

MODEL_PATH = os.path.join(DATA_DIR, 'my_summed_signal_model.keras')
ENCODER_PATH = os.path.join(DATA_DIR, 'label_encoder.joblib')

PTB_XL_ROOT = os.path.join(
    DATA_DIR,
    'ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500'
)

RECORD_NAME = "10000/10002_hr"

INPUT_LENGTH = 180


def preprocess_leadII_V5(record_name):

    full_path = os.path.join(PTB_XL_ROOT, record_name)
    print("Loading:", full_path)

    record = wfdb.rdrecord(full_path)

    if record is None:
        raise FileNotFoundError("Record not found")

    print(f"Loaded. Fs={record.fs}, Leads={record.n_sig}")

    # Lead mapping:
    # 1 = Lead II
    # 10 = Lead V5
    lead_II = record.p_signal[:, 1]
    lead_V5 = record.p_signal[:, 10]

    # Sum (same as your training data)
    summed = lead_II + lead_V5

    # Standardize
    scaled = StandardScaler().fit_transform(summed.reshape(-1, 1))

    if scaled.shape[0] < INPUT_LENGTH:
        raise ValueError("Not enough samples")

    segment = scaled[:INPUT_LENGTH, 0]

    return np.expand_dims(segment, axis=(0, -1))


# Load model
model = load_model(MODEL_PATH)
label_encoder = joblib.load(ENCODER_PATH)

print("\nModel + Encoder Loaded\n")

try:
    X = preprocess_leadII_V5(RECORD_NAME)

    print("\nPredicting...")
    probs = model.predict(X, verbose=0)[0]

    idx = np.argmax(probs)
    pred = label_encoder.inverse_transform([idx])[0]
    conf = float(probs[idx])

    print("\n===============================")
    print(f"Record: {RECORD_NAME}")
    print("Prediction using Lead II + V5 summed")
    print("-------------------------------")
    print(f"Predicted Class: {pred}")
    print(f"Confidence: {conf:.4f}")
    print(f"Softmax: {np.round(probs, 4)}")
    print("===============================\n")

except Exception as e:
    print("❌ ERROR:", e)
# Out:
# Model + Encoder Loaded
#
# Loading: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/10000/10002_hr
# Loaded. Fs=500, Leads=12
#
# Predicting...
#
# ===============================
# Record: 10000/10002_hr
# Prediction using Lead II + V5 summed
# -------------------------------
# Predicted Class: V
# Confidence: 0.9830
# Softmax: [1.66e-02 4.00e-04 0.00e+00 9.83e-01]
# ===============================

# %%
import os
import wfdb
import numpy as np
import csv
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model
import joblib

# ============================
# CONFIG
# ============================
DATA_DIR = '/content/drive/MyDrive/mit_bih/'
PTB_ROOT = os.path.join(DATA_DIR,
        'ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500')

MODEL_PATH = os.path.join(DATA_DIR, 'my_summed_signal_model.keras')
ENCODER_PATH = os.path.join(DATA_DIR, 'label_encoder.joblib')

OUTPUT_CSV = "/content/drive/MyDrive/ptb_xl_predictions_100.csv"

INPUT_LEN = 180  # model input requirement


# ============================
# PREPROCESSOR (Lead II + V5)
# ============================
def preprocess(record_path):
    rec = wfdb.rdrecord(record_path, pn_dir=None)
    sig = rec.p_signal

    if sig.shape[1] < 6:
        raise ValueError("Record does not contain enough leads (needs lead II & V5).")

    lead_II = sig[:, 1]
    lead_V5 = sig[:, 5]

    summed = lead_II + lead_V5

    # Standardize
    scaler = StandardScaler()
    scaled = scaler.fit_transform(summed.reshape(-1, 1)).flatten()

    if len(scaled) < INPUT_LEN:
        raise ValueError("Record smaller than 180 samples.")

    segment = scaled[:INPUT_LEN]
    return np.expand_dims(segment, axis=(0, -1))  # (1,180,1)


# ============================
# LOAD MODEL
# ============================
print("Loading model...")
model = load_model(MODEL_PATH)
encoder = joblib.load(ENCODER_PATH)
print("Model loaded. Classes:", list(encoder.classes_))


# ============================
# GET RECORD LIST
# ============================
record_paths = []

for root, dirs, files in os.walk(PTB_ROOT):
    for f in files:
        if f.endswith(".dat"):
            full = os.path.join(root, f[:-4])  # remove .dat
            record_paths.append(full)

record_paths = sorted(record_paths)[:100]  # TAKE ONLY FIRST 100 RECORDS

print(f"\nTotal records used: {len(record_paths)}")


# ============================
# PREDICT LOOP
# ============================
with open(OUTPUT_CSV, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["record", "predicted_class", "confidence", "softmax"])

    for rec in record_paths:
        try:
            print("\nProcessing:", rec)

            X = preprocess(rec)
            probs = model.predict(X, verbose=0)[0]

            cls_idx = np.argmax(probs)
            label = encoder.classes_[cls_idx]
            confidence = float(probs[cls_idx])

            print(" →", label, " (confidence:", round(confidence, 4), ")")

            writer.writerow([
                rec,
                label,
                confidence,
                probs.tolist()
            ])

        except Exception as e:
            print(" ❌ Error:", e)
            writer.writerow([rec, "ERROR", "NA", str(e)])


print("\n\n===============================")
print("Prediction File Saved At:")
print(OUTPUT_CSV)
print("===============================")
# Out:
# Loading model...
# Model loaded. Classes: ['F', 'N', 'S', 'V']
#
# Total records used: 100
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00001_hr
#  → S  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00002_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00003_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00004_hr
#  → F  (confidence: 0.9984 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00005_hr
#  → V  (confidence: 0.6322 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00006_hr
#  → F  (confidence: 0.9992 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00007_hr
#  → V  (confidence: 0.9991 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00008_hr
#  → F  (confidence: 0.9219 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00009_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00010_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00011_hr
#  → S  (confidence: 0.84 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00012_hr
#  → S  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00013_hr
#  → S  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00014_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00015_hr
#  → V  (confidence: 0.9423 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00016_hr
#  → V  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00017_hr
#  → N  (confidence: 0.9169 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00018_hr
#  → N  (confidence: 0.7262 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00019_hr
#  → V  (confidence: 0.9965 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00020_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00021_hr
#  → N  (confidence: 0.9578 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00022_hr
#  → V  (confidence: 0.9993 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00023_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00024_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00025_hr
#  → V  (confidence: 0.9291 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00026_hr
#  → V  (confidence: 0.679 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00027_hr
#  → S  (confidence: 0.9983 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00028_hr
#  → V  (confidence: 0.9679 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00029_hr
#  → V  (confidence: 0.9646 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00030_hr
#  → N  (confidence: 0.6571 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00031_hr
#  → F  (confidence: 0.8063 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00032_hr
#  → V  (confidence: 0.4763 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00033_hr
#  → S  (confidence: 0.5769 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00034_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00035_hr
#  → S  (confidence: 0.6243 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00036_hr
#  → N  (confidence: 0.7928 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00037_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00038_hr
#  → N  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00039_hr
#  → V  (confidence: 0.9961 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00040_hr
#  → S  (confidence: 0.981 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00041_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00042_hr
#  → V  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00043_hr
#  → S  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00044_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00045_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00046_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00047_hr
#  → N  (confidence: 0.9957 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00048_hr
#  → N  (confidence: 0.9551 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00049_hr
#  → S  (confidence: 0.9922 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00050_hr
#  → V  (confidence: 0.9866 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00051_hr
#  → V  (confidence: 0.9991 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00052_hr
#  → S  (confidence: 0.998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00053_hr
#  → V  (confidence: 0.9988 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00054_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00055_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00056_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00057_hr
#  → V  (confidence: 0.7565 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00058_hr
#  → V  (confidence: 0.9992 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00059_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00060_hr
#  → F  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00061_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00062_hr
#  → V  (confidence: 0.9987 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00063_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00064_hr
#  → V  (confidence: 0.9042 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00065_hr
#  → V  (confidence: 0.9766 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00066_hr
#  → V  (confidence: 0.9438 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00067_hr
#  → S  (confidence: 0.885 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00068_hr
#  → N  (confidence: 0.9993 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00069_hr
#  → S  (confidence: 0.9997 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00070_hr
#  → S  (confidence: 0.999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00071_hr
#  → N  (confidence: 0.9936 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00072_hr
#  → N  (confidence: 0.8313 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00073_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00074_hr
#  → N  (confidence: 0.9519 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00075_hr
#  → F  (confidence: 0.6637 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00076_hr
#  → F  (confidence: 0.9826 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00077_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00078_hr
#  → S  (confidence: 0.7871 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00079_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00080_hr
#  → V  (confidence: 0.6872 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00081_hr
#  → N  (confidence: 0.9583 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00082_hr
#  → N  (confidence: 0.9835 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00083_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00084_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00085_hr
#  → F  (confidence: 0.5014 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00086_hr
#  → F  (confidence: 0.7367 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00087_hr
#  → F  (confidence: 0.4256 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00088_hr
#  → F  (confidence: 0.4835 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00089_hr
#  → V  (confidence: 0.9995 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00090_hr
#  → N  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00091_hr
#  → N  (confidence: 0.9874 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00092_hr
#  → F  (confidence: 0.5929 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00093_hr
#  → N  (confidence: 0.8936 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00094_hr
#  → V  (confidence: 0.9993 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00095_hr
#  → F  (confidence: 0.9962 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00096_hr
#  → F  (confidence: 0.7536 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00097_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00098_hr
#  → V  (confidence: 0.9849 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00099_hr
#  → F  (confidence: 0.9347 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00100_hr
#  → F  (confidence: 1.0 )
#
#
# ===============================
# Prediction File Saved At:
# /content/drive/MyDrive/ptb_xl_predictions_100.csv
# ===============================

# %%
import os
import wfdb
import numpy as np
import csv
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model
import joblib

# ============================
# CONFIG
# ============================
DATA_DIR = '/content/drive/MyDrive/mit_bih/'
PTB_ROOT = os.path.join(DATA_DIR,
        'ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500')

MODEL_PATH = os.path.join(DATA_DIR, 'my_summed_signal_model.keras')
ENCODER_PATH = os.path.join(DATA_DIR, 'label_encoder.joblib')

OUTPUT_CSV = "/content/drive/MyDrive/ptb_xl_predictions_100_all_leads.csv"

INPUT_LEN = 180


# ============================
# PREPROCESSOR (SUM ALL LEADS)
# ============================
def preprocess_all_leads(record_path):
    rec = wfdb.rdrecord(record_path, pn_dir=None)
    sig = rec.p_signal

    # Sum all leads
    summed = np.sum(sig, axis=1)

    # Standardize
    scaler = StandardScaler()
    scaled = scaler.fit_transform(summed.reshape(-1, 1)).flatten()

    if len(scaled) < INPUT_LEN:
        raise ValueError("Record smaller than 180 samples.")

    segment = scaled[:INPUT_LEN]
    return np.expand_dims(segment, axis=(0, -1))  # (1,180,1)


# ============================
# LOAD MODEL
# ============================
print("Loading model...")
model = load_model(MODEL_PATH)
encoder = joblib.load(ENCODER_PATH)
print("Model loaded. Classes:", list(encoder.classes_))


# ============================
# GET SAME 100 RECORDS
# ============================
record_paths = []

for root, dirs, files in os.walk(PTB_ROOT):
    for f in files:
        if f.endswith(".dat"):
            full = os.path.join(root, f[:-4])  # drop .dat
            record_paths.append(full)

record_paths = sorted(record_paths)[:100]  # SAME first 100

print(f"\nTotal records used: {len(record_paths)}")


# ============================
# PREDICT LOOP
# ============================
with open(OUTPUT_CSV, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["record", "predicted_class", "confidence", "softmax"])

    for rec in record_paths:
        try:
            print("\nProcessing:", rec)

            X = preprocess_all_leads(rec)
            probs = model.predict(X, verbose=0)[0]

            cls_idx = np.argmax(probs)
            label = encoder.classes_[cls_idx]
            confidence = float(probs[cls_idx])

            print(" →", label, " (confidence:", round(confidence, 4), ")")

            writer.writerow([
                rec,
                label,
                confidence,
                probs.tolist()
            ])

        except Exception as e:
            print(" ❌ Error:", e)
            writer.writerow([rec, "ERROR", "NA", str(e)])


print("\n\n===============================")
print("All-leads Prediction File Saved At:")
print(OUTPUT_CSV)
print("===============================")
# Out:
# Loading model...
# Model loaded. Classes: ['F', 'N', 'S', 'V']
#
# Total records used: 100
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00001_hr
#  → S  (confidence: 0.9677 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00002_hr
#  → V  (confidence: 0.812 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00003_hr
#  → F  (confidence: 0.9973 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00004_hr
#  → V  (confidence: 0.9991 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00005_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00006_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00007_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00008_hr
#  → F  (confidence: 0.9969 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00009_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00010_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00011_hr
#  → V  (confidence: 0.9879 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00012_hr
#  → V  (confidence: 0.9968 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00013_hr
#  → V  (confidence: 0.5093 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00014_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00015_hr
#  → V  (confidence: 0.9129 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00016_hr
#  → F  (confidence: 0.9823 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00017_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00018_hr
#  → F  (confidence: 0.9985 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00019_hr
#  → F  (confidence: 0.9947 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00020_hr
#  → V  (confidence: 0.9991 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00021_hr
#  → N  (confidence: 0.9568 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00022_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00023_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00024_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00025_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00026_hr
#  → F  (confidence: 0.7717 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00027_hr
#  → F  (confidence: 0.7231 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00028_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00029_hr
#  → F  (confidence: 0.9582 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00030_hr
#  → V  (confidence: 0.9869 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00031_hr
#  → F  (confidence: 0.9964 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00032_hr
#  → F  (confidence: 0.9932 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00033_hr
#  → V  (confidence: 0.9992 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00034_hr
#  → V  (confidence: 0.9967 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00035_hr
#  → N  (confidence: 0.726 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00036_hr
#  → N  (confidence: 0.9989 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00037_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00038_hr
#  → V  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00039_hr
#  → V  (confidence: 0.9994 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00040_hr
#  → S  (confidence: 0.8419 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00041_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00042_hr
#  → V  (confidence: 0.9839 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00043_hr
#  → S  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00044_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00045_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00046_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00047_hr
#  → S  (confidence: 0.4947 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00048_hr
#  → V  (confidence: 0.8067 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00049_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00050_hr
#  → V  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00051_hr
#  → F  (confidence: 0.8579 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00052_hr
#  → S  (confidence: 0.9343 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00053_hr
#  → V  (confidence: 0.9017 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00054_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00055_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00056_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00057_hr
#  → F  (confidence: 0.8961 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00058_hr
#  → N  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00059_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00060_hr
#  → F  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00061_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00062_hr
#  → V  (confidence: 0.9701 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00063_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00064_hr
#  → F  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00065_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00066_hr
#  → V  (confidence: 0.9571 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00067_hr
#  → S  (confidence: 0.9685 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00068_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00069_hr
#  → F  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00070_hr
#  → F  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00071_hr
#  → S  (confidence: 0.5226 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00072_hr
#  → V  (confidence: 0.9995 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00073_hr
#  → S  (confidence: 0.9859 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00074_hr
#  → N  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00075_hr
#  → F  (confidence: 0.7205 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00076_hr
#  → F  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00077_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00078_hr
#  → F  (confidence: 0.7617 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00079_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00080_hr
#  → N  (confidence: 0.6369 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00081_hr
#  → N  (confidence: 0.9946 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00082_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00083_hr
#  → N  (confidence: 0.8662 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00084_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00085_hr
#  → S  (confidence: 0.7065 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00086_hr
#  → V  (confidence: 0.9973 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00087_hr
#  → F  (confidence: 0.9696 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00088_hr
#  → V  (confidence: 0.9693 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00089_hr
#  → S  (confidence: 0.6623 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00090_hr
#  → F  (confidence: 0.9775 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00091_hr
#  → N  (confidence: 0.8805 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00092_hr
#  → N  (confidence: 0.8712 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00093_hr
#  → V  (confidence: 0.9997 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00094_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00095_hr
#  → F  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00096_hr
#  → S  (confidence: 0.8091 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00097_hr
#  → V  (confidence: 0.3176 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00098_hr
#  → N  (confidence: 0.436 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00099_hr
#  → F  (confidence: 0.6873 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00100_hr
#  → F  (confidence: 1.0 )
#
#
# ===============================
# All-leads Prediction File Saved At:
# /content/drive/MyDrive/ptb_xl_predictions_100_all_leads.csv
# ===============================

# %%
import os
import wfdb
import numpy as np
import csv
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model
import joblib

# ========================================
# CONFIG
# ========================================
DATA_DIR = '/content/drive/MyDrive/mit_bih/'
PTB_ROOT = os.path.join(DATA_DIR,
        'ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500')

MODEL_PATH = os.path.join(DATA_DIR, 'my_summed_signal_model.keras')
ENCODER_PATH = os.path.join(DATA_DIR, 'label_encoder.joblib')

OUTPUT_CSV = "/content/drive/MyDrive/ptb_xl_predictions_100_leads_II_aVR_V1toV5.csv"

INPUT_LEN = 180


# =====================================================
# PREPROCESS — SUM LEADS: II, aVR, V1, V2, V3, V4, V5
# PTB-XL lead index reference:
# 0 I
# 1 II
# 2 III
# 3 aVR
# 4 aVL
# 5 aVF
# 6 V1
# 7 V2
# 8 V3
# 9 V4
#10 V5
#11 V6
# =====================================================
def preprocess_custom_leads(record_path):
    rec = wfdb.rdrecord(record_path, pn_dir=None)
    sig = rec.p_signal

    # Required lead indices
    lead_indices = [1, 4, 6, 7, 8, 9, 10]

    # Extract and sum them
    selected = sig[:, lead_indices]
    summed = np.sum(selected, axis=1)

    # Standardize
    scaler = StandardScaler()
    scaled = scaler.fit_transform(summed.reshape(-1, 1)).flatten()

    if len(scaled) < INPUT_LEN:
        raise ValueError("Record smaller than 180 samples.")

    segment = scaled[:INPUT_LEN]
    return np.expand_dims(segment, axis=(0, -1))  # (1,180,1)


# ========================================
# LOAD MODEL
# ========================================
print("Loading model...")
model = load_model(MODEL_PATH)
encoder = joblib.load(ENCODER_PATH)
print("Model loaded. Classes:", list(encoder.classes_))


# ========================================
# GET SAME 100 RECORDS
# ========================================
record_paths = []

for root, dirs, files in os.walk(PTB_ROOT):
    for f in files:
        if f.endswith(".dat"):
            record_paths.append(os.path.join(root, f[:-4]))  # remove .dat

record_paths = sorted(record_paths)[:100]

print(f"\nTotal records used: {len(record_paths)}")


# ========================================
# PREDICTION LOOP
# ========================================
with open(OUTPUT_CSV, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["record", "predicted_class", "confidence", "softmax"])

    for rec in record_paths:
        try:
            print("\nProcessing:", rec)

            X = preprocess_custom_leads(rec)
            probs = model.predict(X, verbose=0)[0]

            cls_idx = np.argmax(probs)
            label = encoder.classes_[cls_idx]
            confidence = float(probs[cls_idx])

            print(" →", label, " (confidence:", round(confidence, 4), ")")

            writer.writerow([
                rec,
                label,
                confidence,
                probs.tolist()
            ])

        except Exception as e:
            print(" ❌ Error:", e)
            writer.writerow([rec, "ERROR", "NA", str(e)])


print("\n\n=================================")
print("Custom Lead Prediction File Saved:")
print(OUTPUT_CSV)
print("=================================")
# Out:
# Loading model...
# Model loaded. Classes: ['F', 'N', 'S', 'V']
#
# Total records used: 100
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00001_hr
#  → S  (confidence: 0.731 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00002_hr
#  → F  (confidence: 0.8007 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00003_hr
#  → F  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00004_hr
#  → V  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00005_hr
#  → V  (confidence: 0.6066 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00006_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00007_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00008_hr
#  → F  (confidence: 0.9986 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00009_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00010_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00011_hr
#  → V  (confidence: 0.9877 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00012_hr
#  → V  (confidence: 0.9991 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00013_hr
#  → F  (confidence: 0.9263 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00014_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00015_hr
#  → V  (confidence: 0.7156 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00016_hr
#  → F  (confidence: 0.9949 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00017_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00018_hr
#  → F  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00019_hr
#  → N  (confidence: 0.9482 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00020_hr
#  → V  (confidence: 0.9937 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00021_hr
#  → N  (confidence: 0.9886 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00022_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00023_hr
#  → V  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00024_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00025_hr
#  → F  (confidence: 0.9354 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00026_hr
#  → V  (confidence: 0.5462 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00027_hr
#  → V  (confidence: 0.5792 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00028_hr
#  → V  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00029_hr
#  → F  (confidence: 0.9224 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00030_hr
#  → V  (confidence: 0.9982 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00031_hr
#  → F  (confidence: 0.8759 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00032_hr
#  → F  (confidence: 0.998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00033_hr
#  → V  (confidence: 0.9258 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00034_hr
#  → V  (confidence: 0.9797 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00035_hr
#  → N  (confidence: 0.6594 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00036_hr
#  → N  (confidence: 0.9989 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00037_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00038_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00039_hr
#  → V  (confidence: 0.9984 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00040_hr
#  → S  (confidence: 0.6672 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00041_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00042_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00043_hr
#  → S  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00044_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00045_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00046_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00047_hr
#  → S  (confidence: 0.7005 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00048_hr
#  → V  (confidence: 0.9125 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00049_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00050_hr
#  → V  (confidence: 0.7176 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00051_hr
#  → V  (confidence: 0.5833 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00052_hr
#  → S  (confidence: 0.9947 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00053_hr
#  → V  (confidence: 0.9948 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00054_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00055_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00056_hr
#  → V  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00057_hr
#  → F  (confidence: 0.8008 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00058_hr
#  → N  (confidence: 0.9997 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00059_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00060_hr
#  → F  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00061_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00062_hr
#  → V  (confidence: 0.9721 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00063_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00064_hr
#  → F  (confidence: 0.9997 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00065_hr
#  → V  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00066_hr
#  → N  (confidence: 0.6738 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00067_hr
#  → S  (confidence: 0.8526 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00068_hr
#  → V  (confidence: 0.9935 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00069_hr
#  → F  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00070_hr
#  → F  (confidence: 0.9981 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00071_hr
#  → S  (confidence: 0.9187 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00072_hr
#  → V  (confidence: 0.9416 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00073_hr
#  → S  (confidence: 0.8727 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00074_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00075_hr
#  → F  (confidence: 0.916 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00076_hr
#  → F  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00077_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00078_hr
#  → S  (confidence: 0.53 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00079_hr
#  → V  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00080_hr
#  → N  (confidence: 0.7745 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00081_hr
#  → N  (confidence: 0.7152 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00082_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00083_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00084_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00085_hr
#  → S  (confidence: 0.5466 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00086_hr
#  → V  (confidence: 0.9994 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00087_hr
#  → V  (confidence: 0.9962 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00088_hr
#  → V  (confidence: 0.8644 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00089_hr
#  → N  (confidence: 0.5208 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00090_hr
#  → F  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00091_hr
#  → F  (confidence: 0.6527 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00092_hr
#  → N  (confidence: 0.9505 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00093_hr
#  → V  (confidence: 0.9985 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00094_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00095_hr
#  → F  (confidence: 0.9959 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00096_hr
#  → S  (confidence: 0.9047 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00097_hr
#  → V  (confidence: 0.7888 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00098_hr
#  → V  (confidence: 0.9886 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00099_hr
#  → F  (confidence: 0.8638 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00100_hr
#  → F  (confidence: 1.0 )
#
#
# =================================
# Custom Lead Prediction File Saved:
# /content/drive/MyDrive/ptb_xl_predictions_100_leads_II_aVR_V1toV5.csv
# =================================

# %%
import os
import wfdb
import numpy as np
import csv
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model
import joblib

# ========================================
# CONFIG
# ========================================
DATA_DIR = '/content/drive/MyDrive/mit_bih/'
PTB_ROOT = os.path.join(DATA_DIR,
        'ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500')

MODEL_PATH = os.path.join(DATA_DIR, 'my_summed_signal_model.keras')
ENCODER_PATH = os.path.join(DATA_DIR, 'label_encoder.joblib')

OUTPUT_CSV = "/content/drive/MyDrive/ptb_xl_predictions_100_leadsV1toV5.csv"

INPUT_LEN = 180


# =====================================================
# PREPROCESS — SUM LEADS: II, aVR, V1, V2, V3, V4, V5
# PTB-XL lead index reference:
# 0 I
# 1 II
# 2 III
# 3 aVR
# 4 aVL
# 5 aVF
# 6 V1
# 7 V2
# 8 V3
# 9 V4
#10 V5
#11 V6
# =====================================================
def preprocess_custom_leads(record_path):
    rec = wfdb.rdrecord(record_path, pn_dir=None)
    sig = rec.p_signal

    # Required lead indices
    lead_indices = [ 6, 7, 8, 9, 10]

    # Extract and sum them
    selected = sig[:, lead_indices]
    summed = np.sum(selected, axis=1)

    # Standardize
    scaler = StandardScaler()
    scaled = scaler.fit_transform(summed.reshape(-1, 1)).flatten()

    if len(scaled) < INPUT_LEN:
        raise ValueError("Record smaller than 180 samples.")

    segment = scaled[:INPUT_LEN]
    return np.expand_dims(segment, axis=(0, -1))  # (1,180,1)


# ========================================
# LOAD MODEL
# ========================================
print("Loading model...")
model = load_model(MODEL_PATH)
encoder = joblib.load(ENCODER_PATH)
print("Model loaded. Classes:", list(encoder.classes_))


# ========================================
# GET SAME 100 RECORDS
# ========================================
record_paths = []

for root, dirs, files in os.walk(PTB_ROOT):
    for f in files:
        if f.endswith(".dat"):
            record_paths.append(os.path.join(root, f[:-4]))  # remove .dat

record_paths = sorted(record_paths)[:100]

print(f"\nTotal records used: {len(record_paths)}")


# ========================================
# PREDICTION LOOP
# ========================================
with open(OUTPUT_CSV, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["record", "predicted_class", "confidence", "softmax"])

    for rec in record_paths:
        try:
            print("\nProcessing:", rec)

            X = preprocess_custom_leads(rec)
            probs = model.predict(X, verbose=0)[0]

            cls_idx = np.argmax(probs)
            label = encoder.classes_[cls_idx]
            confidence = float(probs[cls_idx])

            print(" →", label, " (confidence:", round(confidence, 4), ")")

            writer.writerow([
                rec,
                label,
                confidence,
                probs.tolist()
            ])

        except Exception as e:
            print(" ❌ Error:", e)
            writer.writerow([rec, "ERROR", "NA", str(e)])


print("\n\n=================================")
print("Custom Lead Prediction File Saved:")
print(OUTPUT_CSV)
print("=================================")
# Out:
# Loading model...
# Model loaded. Classes: ['F', 'N', 'S', 'V']
#
# Total records used: 100
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00001_hr
#  → V  (confidence: 0.4971 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00002_hr
#  → F  (confidence: 0.8152 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00003_hr
#  → F  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00004_hr
#  → V  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00005_hr
#  → V  (confidence: 0.5794 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00006_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00007_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00008_hr
#  → F  (confidence: 0.9924 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00009_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00010_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00011_hr
#  → V  (confidence: 0.9952 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00012_hr
#  → V  (confidence: 0.9992 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00013_hr
#  → F  (confidence: 0.9996 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00014_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00015_hr
#  → S  (confidence: 0.4804 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00016_hr
#  → F  (confidence: 0.9825 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00017_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00018_hr
#  → F  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00019_hr
#  → N  (confidence: 0.9789 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00020_hr
#  → V  (confidence: 0.9988 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00021_hr
#  → N  (confidence: 0.9963 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00022_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00023_hr
#  → V  (confidence: 0.9993 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00024_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00025_hr
#  → F  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00026_hr
#  → V  (confidence: 0.9061 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00027_hr
#  → F  (confidence: 0.5819 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00028_hr
#  → V  (confidence: 0.9991 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00029_hr
#  → F  (confidence: 0.9835 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00030_hr
#  → V  (confidence: 0.9991 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00031_hr
#  → F  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00032_hr
#  → F  (confidence: 0.9967 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00033_hr
#  → N  (confidence: 0.5897 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00034_hr
#  → V  (confidence: 0.895 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00035_hr
#  → V  (confidence: 0.3757 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00036_hr
#  → N  (confidence: 0.9742 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00037_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00038_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00039_hr
#  → V  (confidence: 0.9955 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00040_hr
#  → S  (confidence: 0.7449 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00041_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00042_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00043_hr
#  → S  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00044_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00045_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00046_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00047_hr
#  → S  (confidence: 0.5934 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00048_hr
#  → V  (confidence: 0.9988 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00049_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00050_hr
#  → F  (confidence: 0.9289 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00051_hr
#  → N  (confidence: 0.9977 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00052_hr
#  → S  (confidence: 0.9897 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00053_hr
#  → V  (confidence: 0.9857 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00054_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00055_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00056_hr
#  → V  (confidence: 0.9955 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00057_hr
#  → V  (confidence: 0.9471 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00058_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00059_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00060_hr
#  → F  (confidence: 0.9966 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00061_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00062_hr
#  → V  (confidence: 0.9764 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00063_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00064_hr
#  → F  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00065_hr
#  → V  (confidence: 0.6002 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00066_hr
#  → S  (confidence: 0.9073 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00067_hr
#  → S  (confidence: 0.6653 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00068_hr
#  → S  (confidence: 0.5394 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00069_hr
#  → F  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00070_hr
#  → F  (confidence: 0.998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00071_hr
#  → S  (confidence: 0.9757 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00072_hr
#  → V  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00073_hr
#  → S  (confidence: 0.778 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00074_hr
#  → N  (confidence: 0.9792 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00075_hr
#  → F  (confidence: 0.997 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00076_hr
#  → F  (confidence: 0.9899 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00077_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00078_hr
#  → F  (confidence: 0.9342 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00079_hr
#  → V  (confidence: 0.9983 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00080_hr
#  → N  (confidence: 0.6471 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00081_hr
#  → V  (confidence: 0.7736 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00082_hr
#  → V  (confidence: 0.988 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00083_hr
#  → N  (confidence: 0.998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00084_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00085_hr
#  → F  (confidence: 0.498 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00086_hr
#  → V  (confidence: 0.9997 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00087_hr
#  → V  (confidence: 0.9838 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00088_hr
#  → V  (confidence: 0.6475 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00089_hr
#  → N  (confidence: 0.6155 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00090_hr
#  → F  (confidence: 0.9997 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00091_hr
#  → F  (confidence: 0.9752 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00092_hr
#  → N  (confidence: 0.8422 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00093_hr
#  → V  (confidence: 0.8822 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00094_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00095_hr
#  → F  (confidence: 0.6378 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00096_hr
#  → F  (confidence: 0.5395 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00097_hr
#  → N  (confidence: 0.4284 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00098_hr
#  → V  (confidence: 0.995 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00099_hr
#  → F  (confidence: 0.939 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00100_hr
#  → F  (confidence: 1.0 )
#
#
# =================================
# Custom Lead Prediction File Saved:
# /content/drive/MyDrive/ptb_xl_predictions_100_leadsV1toV5.csv
# =================================

# %%
import pandas as pd

# ======================================
# FILE PATHS
# ======================================
file_ii_v5 = "/content/drive/MyDrive/ptb_xl_predictions_100.csv"
file_all = "/content/drive/MyDrive/ptb_xl_predictions_100_all_leads.csv"
file_custom = "/content/drive/MyDrive/ptb_xl_predictions_100_leads_II_aVR_V1toV5.csv"
file_v1_v5 = "/content/drive/MyDrive/ptb_xl_predictions_100_leadsV1toV5.csv"

output_file = "/content/drive/MyDrive/ptb_xl_predictions_comparison_ALL_4.csv"

# ======================================
# LOAD & FILTER REQUIRED COLUMNS
# ======================================
def load_and_clean(path, label_suffix):
    df = pd.read_csv(path)

    # Keep only the necessary columns
    keep_cols = [c for c in df.columns if c in ["record", "predicted_class", "confidence"]]
    df = df[keep_cols]

    # Rename for merging
    df = df.rename(columns={
        "predicted_class": f"label_{label_suffix}",
        "confidence": f"conf_{label_suffix}"
    })

    return df

df_ii_v5 = load_and_clean(file_ii_v5, "ii_v5")
df_all = load_and_clean(file_all, "all")
df_custom = load_and_clean(file_custom, "custom")
df_v1_v5 = load_and_clean(file_v1_v5, "v1_v5")

# ======================================
# MERGE ALL FOUR SAFELY
# ======================================
df = df_ii_v5.merge(df_all, on="record", how="outer")
df = df.merge(df_custom, on="record", how="outer")
df = df.merge(df_v1_v5, on="record", how="outer")

# ======================================
# SAVE FINAL COMPARISON
# ======================================
df.to_csv(output_file, index=False)

print("\n=====================================")
print("Final Comparison File Saved:")
print(output_file)
print("=====================================")
# Out:
# =====================================
# Final Comparison File Saved:
# /content/drive/MyDrive/ptb_xl_predictions_comparison_ALL_4.csv
# =====================================

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/ptb_xl_predictions_comparison_ALL_4.csv')
df.head()
df.tail()
# Out:
#                                                record label_ii_v5  conf_ii_v5  \
# 95  /content/drive/MyDrive/mit_bih/ptb_xl_download...           F    0.753582
# 96  /content/drive/MyDrive/mit_bih/ptb_xl_download...           N    0.999997
# 97  /content/drive/MyDrive/mit_bih/ptb_xl_download...           V    0.984863
# 98  /content/drive/MyDrive/mit_bih/ptb_xl_download...           F    0.934667
# 99  /content/drive/MyDrive/mit_bih/ptb_xl_download...           F    0.999985
#
#    label_all  conf_all label_custom  conf_custom label_v1_v5  conf_v1_v5
# 95         S  0.809106            S     0.904718           F    0.539492
# 96         V  0.317563            V     0.788771           N    0.428354
# 97         N  0.435971            V     0.988610           V    0.994978
# 98         F  0.687323            F     0.863801           F    0.938975
# 99         F  1.000000            F     1.000000           F    1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load comparison file
file = "/content/drive/MyDrive/ptb_xl_predictions_comparison_ALL_4.csv"
df = pd.read_csv(file)

# Prepare data for boxplot
conf_cols = ["conf_ii_v5", "conf_all", "conf_custom", "conf_v1_v5"]
labels = ["II+V5", "All Leads", "Custom", "V1–V5"]

data = [df[c] for c in conf_cols]

plt.figure(figsize=(10,6))
plt.boxplot(data, labels=labels)
plt.title("Confidence Distribution for Each Lead Combination")
plt.ylabel("Confidence Level")
plt.xlabel("Lead Combination")
plt.grid(True)

plt.show()
# Out:
# /tmp/ipython-input-2108234271.py:15: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your merged file
df = pd.read_csv('/content/drive/MyDrive/ptb_xl_predictions_comparison_ALL_4.csv')

# Which columns contain confidence values
conf_cols = ["conf_ii_v5", "conf_all", "conf_custom", "conf_v1_v5"]
titles = ["II + V5", "All Leads Summed", "Custom Leads", "V1–V5"]

plt.figure(figsize=(14, 10))

for i, col in enumerate(conf_cols):
    plt.subplot(2, 2, i+1)
    plt.hist(df[col], bins=20, edgecolor='black')
    plt.title(f"Confidence Histogram: {titles[i]}")
    plt.xlabel("Confidence")
    plt.ylabel("Frequency")
    plt.grid(True, linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/ptb_xl_predictions_comparison_ALL_4.csv')
print(df.columns)
# Out:
# Index(['record', 'label_ii_v5', 'conf_ii_v5', 'label_all', 'conf_all',
#        'label_custom', 'conf_custom', 'label_v1_v5', 'conf_v1_v5'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load file
df = pd.read_csv('/content/drive/MyDrive/ptb_xl_predictions_comparison_ALL_4.csv')

# Use your actual label column names
lead_cols = ["label_ii_v5", "label_all", "label_custom", "label_v1_v5"]
lead_names = ["II+V5", "All Leads", "Custom", "V1–V5"]


# ======================================================
# 1. BAR CHART: Class Distribution per Combination
# ======================================================
plt.figure(figsize=(14, 8))

for i, col in enumerate(lead_cols):
    plt.subplot(2, 2, i+1)
    df[col].value_counts().reindex(["N", "V", "S", "F"]).plot(
        kind="bar", edgecolor="black", color="skyblue"
    )
    plt.title(f"Class Distribution – {lead_names[i]}")
    plt.xlabel("Class")
    plt.ylabel("Count")
    plt.grid(axis="y", linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()


# ======================================================
# 2. SHOW first 10 disagreements
# ======================================================
disagree_mask = (
    (df["label_ii_v5"] != df["label_all"]) |
    (df["label_ii_v5"] != df["label_custom"]) |
    (df["label_ii_v5"] != df["label_v1_v5"])
)

disagreements = df[disagree_mask][[
    "record", "label_ii_v5", "label_all", "label_custom", "label_v1_v5"
]]

print("\n========== FIRST 10 DISAGREEMENTS ==========\n")
print(disagreements.head(10))


# ======================================================
# 3. DISAGREEMENT COUNTS (pairwise)
# ======================================================
pairs = [
    ("label_ii_v5", "label_all"),
    ("label_ii_v5", "label_custom"),
    ("label_ii_v5", "label_v1_v5"),
    ("label_all", "label_custom"),
    ("label_all", "label_v1_v5"),
    ("label_custom", "label_v1_v5"),
]

print("\n========== DISAGREEMENT COUNTS ==========\n")
for a, b in pairs:
    diff = (df[a] != df[b]).sum()
    print(f"{a} vs {b}: {diff} disagreements")


# ======================================================
# 4. HEATMAP of Disagreement Counts
# ======================================================
matrix = pd.DataFrame(index=lead_names, columns=lead_names)

# Fill matrix with disagreement counts
for i, a in enumerate(lead_cols):
    for j, b in enumerate(lead_cols):
        if a == b:
            matrix.iloc[i, j] = 0
        else:
            matrix.iloc[i, j] = (df[a] != df[b]).sum()

matrix = matrix.astype(int)

plt.figure(figsize=(7, 5))
sns.heatmap(matrix, annot=True, cmap="Reds", fmt="d")
plt.title("Disagreement Heatmap Between Lead Combinations")
plt.show()
# Out:
# ========== FIRST 10 DISAGREEMENTS ==========
#
#                                                record label_ii_v5 label_all  \
# 0   /content/drive/MyDrive/mit_bih/ptb_xl_download...           S         S
# 1   /content/drive/MyDrive/mit_bih/ptb_xl_download...           V         V
# 2   /content/drive/MyDrive/mit_bih/ptb_xl_download...           N         F
# 3   /content/drive/MyDrive/mit_bih/ptb_xl_download...           F         V
# 5   /content/drive/MyDrive/mit_bih/ptb_xl_download...           F         V
# 9   /content/drive/MyDrive/mit_bih/ptb_xl_download...           V         N
# 10  /content/drive/MyDrive/mit_bih/ptb_xl_download...           S         V
# 11  /content/drive/MyDrive/mit_bih/ptb_xl_download...           S         V
# 12  /content/drive/MyDrive/mit_bih/ptb_xl_download...           S         V
# 14  /content/drive/MyDrive/mit_bih/ptb_xl_download...           V         V
#
#    label_custom label_v1_v5
# 0             S           V
# 1             F           F
# 2             F           F
# 3             V           V
# 5             V           V
# 9             N           N
# 10            V           V
# 11            V           V
# 12            F           F
# 14            V           S
#
# ========== DISAGREEMENT COUNTS ==========
#
# label_ii_v5 vs label_all: 46 disagreements
# label_ii_v5 vs label_custom: 47 disagreements
# label_ii_v5 vs label_v1_v5: 49 disagreements
# label_all vs label_custom: 13 disagreements
# label_all vs label_v1_v5: 22 disagreements
# label_custom vs label_v1_v5: 15 disagreements

# %%
import os

base = "/content/drive/MyDrive/mit_bih/ptb_xl_download"
for root, dirs, files in os.walk(base):
    if "ptbxl_database.csv" in files:
        print("FOUND:", os.path.join(root, "ptbxl_database.csv"))
# Out:
# FOUND: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/ptbxl_database.csv

# %%
import pandas as pd

path = "/content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/ptbxl_database.csv"
df = pd.read_csv(path)

df.head(20)
# Out:
#     ecg_id  patient_id   age  sex  height  weight  nurse  site     device  \
# 0        1     15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 1        2     13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 2        3     20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 3        4     17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 4        5     17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
# 5        6     19005.0  18.0    1     NaN    58.0    2.0   0.0  CS-12   E
# 6        7     16193.0  54.0    0     NaN    83.0    2.0   0.0  CS-12   E
# 7        8     11275.0  48.0    0     NaN    95.0    2.0   0.0  CS-12   E
# 8        9     18792.0  55.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 9       10      9456.0  22.0    1     NaN    56.0    2.0   0.0  CS-12   E
# 10      11     11243.0  20.0    1     NaN    57.0    2.0   0.0  CS-12   E
# 11      12     11031.0  43.0    1     NaN    44.0    2.0   0.0  CS-12   E
# 12      13     19953.0  58.0    1     NaN    54.0    2.0   0.0  CS-12   E
# 13      14     12925.0  19.0    1     NaN    58.0    2.0   0.0  CS-12   E
# 14      15     13375.0  17.0    1     NaN    67.0    2.0   0.0  CS-12   E
# 15      16     10999.0  49.0    0     NaN    79.0    2.0   0.0  CS-12   E
# 16      17     13619.0  56.0    0     NaN     NaN    2.0   0.0  CS-12   E
# 17      18     13619.0  56.0    0     NaN     NaN    2.0   0.0  CS-12   E
# 18      19     11116.0  20.0    0     NaN    85.0    2.0   0.0  CS-12   E
# 19      20     13619.0  56.0    0     NaN     NaN    2.0   0.0  CS-12   E
#
#          recording_date  ... validated_by_human  baseline_drift static_noise  \
# 0   1984-11-09 09:17:34  ...               True             NaN    , I-V1,
# 1   1984-11-14 12:55:37  ...               True             NaN          NaN
# 2   1984-11-15 12:49:10  ...               True             NaN          NaN
# 3   1984-11-15 13:44:57  ...               True    , II,III,AVF          NaN
# 4   1984-11-17 10:43:15  ...               True   , III,AVR,AVF          NaN
# 5   1984-11-28 13:32:13  ...               True            , V1          NaN
# 6   1984-11-28 13:32:22  ...               True             NaN          NaN
# 7   1984-12-01 14:49:52  ...               True        , II,AVF   , I-AVF,
# 8   1984-12-08 09:44:43  ...               True             NaN   , I-AVR,
# 9   1984-12-12 14:12:46  ...               True             NaN          NaN
# 10  1984-12-16 14:20:39  ...               True    , II-AVL,AVF   , I-AVL,
# 11  1984-12-21 08:02:26  ...               True             NaN          NaN
# 12  1985-01-05 12:13:05  ...               True             NaN   , I-AVR,
# 13  1985-01-10 11:45:19  ...               True             NaN          NaN
# 14  1985-01-12 10:39:41  ...               True             NaN   , I-AVR,
# 15  1985-01-16 08:27:38  ...               True            , V1          NaN
# 16  1985-01-20 14:25:25  ...               True             NaN   , alles,
# 17  1985-01-20 15:17:24  ...               True             NaN   , alles,
# 18  1985-01-23 11:23:00  ...               True             NaN          NaN
# 19  1985-01-23 12:55:32  ...               True             NaN          NaN
#
#    burst_noise electrodes_problems  extra_beats  pacemaker  strat_fold  \
# 0          NaN                 NaN          NaN        NaN           3
# 1          NaN                 NaN          NaN        NaN           2
# 2          NaN                 NaN          NaN        NaN           5
# 3          NaN                 NaN          NaN        NaN           3
# 4          NaN                 NaN          NaN        NaN           4
# 5          NaN                 NaN          NaN        NaN           4
# 6          NaN                 NaN          NaN        NaN           7
# 7          NaN                 NaN          NaN        NaN           9
# 8          NaN                 NaN          NaN        NaN          10
# 9          NaN                 NaN          NaN        NaN           9
# 10         NaN                 NaN          NaN        NaN           5
# 11         NaN                 NaN          NaN        NaN           8
# 12         NaN                 NaN          NaN        NaN           2
# 13         NaN                 NaN          NaN        NaN           7
# 14         NaN                 NaN          1ES        NaN           3
# 15         NaN                 NaN          NaN        NaN           6
# 16         NaN                 NaN          NaN        NaN           9
# 17         NaN                 NaN          NaN        NaN           9
# 18         NaN                 NaN          NaN        NaN           7
# 19         NaN                 NaN          VES        NaN           9
#
#                   filename_lr                filename_hr
# 0   records100/00000/00001_lr  records500/00000/00001_hr
# 1   records100/00000/00002_lr  records500/00000/00002_hr
# 2   records100/00000/00003_lr  records500/00000/00003_hr
# 3   records100/00000/00004_lr  records500/00000/00004_hr
# 4   records100/00000/00005_lr  records500/00000/00005_hr
# 5   records100/00000/00006_lr  records500/00000/00006_hr
# 6   records100/00000/00007_lr  records500/00000/00007_hr
# 7   records100/00000/00008_lr  records500/00000/00008_hr
# 8   records100/00000/00009_lr  records500/00000/00009_hr
# 9   records100/00000/00010_lr  records500/00000/00010_hr
# 10  records100/00000/00011_lr  records500/00000/00011_hr
# 11  records100/00000/00012_lr  records500/00000/00012_hr
# 12  records100/00000/00013_lr  records500/00000/00013_hr
# 13  records100/00000/00014_lr  records500/00000/00014_hr
# 14  records100/00000/00015_lr  records500/00000/00015_hr
# 15  records100/00000/00016_lr  records500/00000/00016_hr
# 16  records100/00000/00017_lr  records500/00000/00017_hr
# 17  records100/00000/00018_lr  records500/00000/00018_hr
# 18  records100/00000/00019_lr  records500/00000/00019_hr
# 19  records100/00000/00020_lr  records500/00000/00020_hr
#
# [20 rows x 28 columns]

# %%
'''data_dir = '/content/drive/MyDrive/mit_bih/'
MODEL_ORIGINAL_PATH = os.path.join(data_dir, 'my_summed_signal_model.keras')
MODEL_HEAVY_NOISY_FT_PATH = os.path.join(data_dir, 'my_fine_tuned_noisy_model.keras')
MODEL_PURE_NOISE_PATH = os.path.join(data_dir, 'model_B_noisy.keras')
MODEL_MIXED_FT_PATH = os.path.join(data_dir, 'my_fine_tuned_v2_mixed_low_noise_model.keras')'''

# %%
# !pip install wfdb
# Out:
# Collecting wfdb
#   Downloading wfdb-4.3.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.12/dist-packages (from wfdb) (3.13.2)
# Requirement already satisfied: fsspec>=2023.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2025.3.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.12/dist-packages (from wfdb) (3.10.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2.0.2)
# Collecting pandas>=2.2.3 (from wfdb)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.12/dist-packages (from wfdb) (2.32.4)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (1.16.3)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb) (1.22.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.2.2->wfdb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->wfdb) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.8.1->wfdb) (2025.10.5)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.10.0->wfdb) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp>=3.10.11->wfdb) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.17.0)
# Downloading wfdb-4.3.0-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 7.7 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 50.2 MB/s eta 0:00:00
# Installing collected packages: pandas, wfdb
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# Successfully installed pandas-2.3.3 wfdb-4.3.0

# %%
import os
import wfdb
import numpy as np
import csv
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model
import joblib

# ============================
# CONFIG
# ============================
DATA_DIR = '/content/drive/MyDrive/mit_bih/'
PTB_ROOT = os.path.join(DATA_DIR,
        'ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500')

MODEL_PATH = os.path.join(DATA_DIR, 'my_fine_tuned_v2_mixed_low_noise_model.keras')
ENCODER_PATH = os.path.join(DATA_DIR, 'label_encoder.joblib')

OUTPUT_CSV = "/content/drive/MyDrive/5050ptb.csv"

INPUT_LEN = 180  # model input requirement


# ============================
# PREPROCESSOR (Lead II + V5)
# ============================
def preprocess(record_path):
    rec = wfdb.rdrecord(record_path, pn_dir=None)
    sig = rec.p_signal

    if sig.shape[1] < 6:
        raise ValueError("Record does not contain enough leads (needs lead II & V5).")

    lead_II = sig[:, 1]
    lead_V5 = sig[:, 5]

    summed = lead_II + lead_V5

    # Standardize
    scaler = StandardScaler()
    scaled = scaler.fit_transform(summed.reshape(-1, 1)).flatten()

    if len(scaled) < INPUT_LEN:
        raise ValueError("Record smaller than 180 samples.")

    segment = scaled[:INPUT_LEN]
    return np.expand_dims(segment, axis=(0, -1))  # (1,180,1)


# ============================
# LOAD MODEL
# ============================
print("Loading model...")
model = load_model(MODEL_PATH)
encoder = joblib.load(ENCODER_PATH)
print("Model loaded. Classes:", list(encoder.classes_))


# ============================
# GET RECORD LIST
# ============================
record_paths = []

for root, dirs, files in os.walk(PTB_ROOT):
    for f in files:
        if f.endswith(".dat"):
            full = os.path.join(root, f[:-4])  # remove .dat
            record_paths.append(full)

record_paths = sorted(record_paths)[:100]  # TAKE ONLY FIRST 100 RECORDS

print(f"\nTotal records used: {len(record_paths)}")


# ============================
# PREDICT LOOP
# ============================
with open(OUTPUT_CSV, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["record", "predicted_class", "confidence", "softmax"])

    for rec in record_paths:
        try:
            print("\nProcessing:", rec)

            X = preprocess(rec)
            probs = model.predict(X, verbose=0)[0]

            cls_idx = np.argmax(probs)
            label = encoder.classes_[cls_idx]
            confidence = float(probs[cls_idx])

            print(" →", label, " (confidence:", round(confidence, 4), ")")

            writer.writerow([
                rec,
                label,
                confidence,
                probs.tolist()
            ])

        except Exception as e:
            print(" ❌ Error:", e)
            writer.writerow([rec, "ERROR", "NA", str(e)])


print("\n\n===============================")
print("Prediction File Saved At:")
print(OUTPUT_CSV)
print("===============================")
# Out:
# Loading model...
# Model loaded. Classes: ['F', 'N', 'S', 'V']
#
# Total records used: 100
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00001_hr
#  → S  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00002_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00003_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00004_hr
#  → F  (confidence: 0.9953 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00005_hr
#  → F  (confidence: 0.4553 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00006_hr
#  → F  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00007_hr
#  → V  (confidence: 0.9947 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00008_hr
#  → F  (confidence: 0.9997 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00009_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00010_hr
#  → V  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00011_hr
#  → F  (confidence: 0.9992 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00012_hr
#  → S  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00013_hr
#  → S  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00014_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00015_hr
#  → V  (confidence: 0.5637 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00016_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00017_hr
#  → N  (confidence: 0.9856 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00018_hr
#  → N  (confidence: 0.8557 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00019_hr
#  → V  (confidence: 0.783 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00020_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00021_hr
#  → N  (confidence: 0.9478 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00022_hr
#  → V  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00023_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00024_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00025_hr
#  → V  (confidence: 0.8154 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00026_hr
#  → F  (confidence: 0.9457 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00027_hr
#  → S  (confidence: 0.9951 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00028_hr
#  → V  (confidence: 0.9976 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00029_hr
#  → V  (confidence: 0.99 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00030_hr
#  → N  (confidence: 0.6402 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00031_hr
#  → F  (confidence: 0.9966 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00032_hr
#  → V  (confidence: 0.7509 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00033_hr
#  → V  (confidence: 0.9991 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00034_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00035_hr
#  → S  (confidence: 0.5257 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00036_hr
#  → N  (confidence: 0.9297 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00037_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00038_hr
#  → N  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00039_hr
#  → V  (confidence: 0.9988 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00040_hr
#  → S  (confidence: 0.9951 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00041_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00042_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00043_hr
#  → S  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00044_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00045_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00046_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00047_hr
#  → N  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00048_hr
#  → N  (confidence: 0.5814 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00049_hr
#  → S  (confidence: 0.9784 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00050_hr
#  → V  (confidence: 0.9935 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00051_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00052_hr
#  → S  (confidence: 0.9594 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00053_hr
#  → V  (confidence: 0.9981 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00054_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00055_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00056_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00057_hr
#  → S  (confidence: 0.9266 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00058_hr
#  → V  (confidence: 0.9985 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00059_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00060_hr
#  → F  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00061_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00062_hr
#  → V  (confidence: 0.9996 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00063_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00064_hr
#  → V  (confidence: 0.8337 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00065_hr
#  → V  (confidence: 0.9665 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00066_hr
#  → V  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00067_hr
#  → S  (confidence: 0.9353 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00068_hr
#  → N  (confidence: 0.999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00069_hr
#  → S  (confidence: 0.9963 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00070_hr
#  → S  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00071_hr
#  → N  (confidence: 0.9971 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00072_hr
#  → N  (confidence: 0.7636 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00073_hr
#  → V  (confidence: 0.9997 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00074_hr
#  → N  (confidence: 0.9212 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00075_hr
#  → F  (confidence: 0.9713 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00076_hr
#  → F  (confidence: 0.9539 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00077_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00078_hr
#  → S  (confidence: 0.8358 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00079_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00080_hr
#  → V  (confidence: 0.5852 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00081_hr
#  → N  (confidence: 0.9926 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00082_hr
#  → N  (confidence: 0.9875 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00083_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00084_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00085_hr
#  → F  (confidence: 0.8385 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00086_hr
#  → F  (confidence: 0.8809 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00087_hr
#  → F  (confidence: 0.561 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00088_hr
#  → F  (confidence: 0.5678 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00089_hr
#  → V  (confidence: 0.9953 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00090_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00091_hr
#  → N  (confidence: 0.9908 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00092_hr
#  → F  (confidence: 0.5315 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00093_hr
#  → V  (confidence: 0.9915 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00094_hr
#  → V  (confidence: 0.9982 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00095_hr
#  → F  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00096_hr
#  → F  (confidence: 0.9877 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00097_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00098_hr
#  → V  (confidence: 0.9888 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00099_hr
#  → F  (confidence: 0.8192 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00100_hr
#  → F  (confidence: 0.9999 )
#
#
# ===============================
# Prediction File Saved At:
# /content/drive/MyDrive/5050ptb.csv
# ===============================

# %%
import os
import wfdb
import numpy as np
import csv
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import load_model
import joblib

# ============================
# CONFIG
# ============================
DATA_DIR = '/content/drive/MyDrive/mit_bih/'
PTB_ROOT = os.path.join(DATA_DIR,
        'ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500')

MODEL_PATH = os.path.join(DATA_DIR, 'model_B_noisy.keras')
ENCODER_PATH = os.path.join(DATA_DIR, 'label_encoder.joblib')

OUTPUT_CSV = "/content/drive/MyDrive/noisy_allptb.csv"

INPUT_LEN = 180  # model input requirement


# ============================
# PREPROCESSOR (Lead II + V5)
# ============================
def preprocess(record_path):
    rec = wfdb.rdrecord(record_path, pn_dir=None)
    sig = rec.p_signal

    if sig.shape[1] < 6:
        raise ValueError("Record does not contain enough leads (needs lead II & V5).")

    lead_II = sig[:, 1]
    lead_V5 = sig[:, 5]

    summed = lead_II + lead_V5

    # Standardize
    scaler = StandardScaler()
    scaled = scaler.fit_transform(summed.reshape(-1, 1)).flatten()

    if len(scaled) < INPUT_LEN:
        raise ValueError("Record smaller than 180 samples.")

    segment = scaled[:INPUT_LEN]
    return np.expand_dims(segment, axis=(0, -1))  # (1,180,1)


# ============================
# LOAD MODEL
# ============================
print("Loading model...")
model = load_model(MODEL_PATH)
encoder = joblib.load(ENCODER_PATH)
print("Model loaded. Classes:", list(encoder.classes_))


# ============================
# GET RECORD LIST
# ============================
record_paths = []

for root, dirs, files in os.walk(PTB_ROOT):
    for f in files:
        if f.endswith(".dat"):
            full = os.path.join(root, f[:-4])  # remove .dat
            record_paths.append(full)

record_paths = sorted(record_paths)[:100]  # TAKE ONLY FIRST 100 RECORDS

print(f"\nTotal records used: {len(record_paths)}")


# ============================
# PREDICT LOOP
# ============================
with open(OUTPUT_CSV, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["record", "predicted_class", "confidence", "softmax"])

    for rec in record_paths:
        try:
            print("\nProcessing:", rec)

            X = preprocess(rec)
            probs = model.predict(X, verbose=0)[0]

            cls_idx = np.argmax(probs)
            label = encoder.classes_[cls_idx]
            confidence = float(probs[cls_idx])

            print(" →", label, " (confidence:", round(confidence, 4), ")")

            writer.writerow([
                rec,
                label,
                confidence,
                probs.tolist()
            ])

        except Exception as e:
            print(" ❌ Error:", e)
            writer.writerow([rec, "ERROR", "NA", str(e)])


print("\n\n===============================")
print("Prediction File Saved At:")
print(OUTPUT_CSV)
print("===============================")
# Out:
# Loading model...
# Model loaded. Classes: ['F', 'N', 'S', 'V']
#
# Total records used: 100
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00001_hr
#  → S  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00002_hr
#  → V  (confidence: 0.7111 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00003_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00004_hr
#  → N  (confidence: 0.9996 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00005_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00006_hr
#  → N  (confidence: 0.9526 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00007_hr
#  → N  (confidence: 0.9786 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00008_hr
#  → V  (confidence: 0.4138 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00009_hr
#  → N  (confidence: 0.7025 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00010_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00011_hr
#  → N  (confidence: 0.9461 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00012_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00013_hr
#  → N  (confidence: 0.9993 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00014_hr
#  → V  (confidence: 0.9992 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00015_hr
#  → N  (confidence: 0.9486 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00016_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00017_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00018_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00019_hr
#  → N  (confidence: 0.767 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00020_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00021_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00022_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00023_hr
#  → N  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00024_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00025_hr
#  → V  (confidence: 0.9493 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00026_hr
#  → N  (confidence: 0.9968 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00027_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00028_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00029_hr
#  → N  (confidence: 0.996 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00030_hr
#  → N  (confidence: 0.7279 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00031_hr
#  → N  (confidence: 0.9986 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00032_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00033_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00034_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00035_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00036_hr
#  → N  (confidence: 0.5451 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00037_hr
#  → N  (confidence: 0.9887 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00038_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00039_hr
#  → V  (confidence: 0.972 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00040_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00041_hr
#  → V  (confidence: 0.9978 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00042_hr
#  → N  (confidence: 0.9955 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00043_hr
#  → N  (confidence: 0.9081 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00044_hr
#  → V  (confidence: 0.9996 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00045_hr
#  → N  (confidence: 0.93 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00046_hr
#  → N  (confidence: 0.9905 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00047_hr
#  → S  (confidence: 0.998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00048_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00049_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00050_hr
#  → V  (confidence: 0.9991 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00051_hr
#  → N  (confidence: 0.9934 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00052_hr
#  → S  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00053_hr
#  → V  (confidence: 0.9566 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00054_hr
#  → N  (confidence: 0.9838 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00055_hr
#  → V  (confidence: 0.9985 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00056_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00057_hr
#  → S  (confidence: 0.9831 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00058_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00059_hr
#  → V  (confidence: 0.9487 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00060_hr
#  → N  (confidence: 0.992 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00061_hr
#  → V  (confidence: 0.9998 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00062_hr
#  → N  (confidence: 0.9706 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00063_hr
#  → V  (confidence: 0.9987 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00064_hr
#  → N  (confidence: 0.9999 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00065_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00066_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00067_hr
#  → N  (confidence: 0.8271 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00068_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00069_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00070_hr
#  → S  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00071_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00072_hr
#  → N  (confidence: 0.9853 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00073_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00074_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00075_hr
#  → S  (confidence: 0.6268 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00076_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00077_hr
#  → V  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00078_hr
#  → V  (confidence: 0.6687 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00079_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00080_hr
#  → V  (confidence: 0.9563 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00081_hr
#  → N  (confidence: 0.8054 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00082_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00083_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00084_hr
#  → V  (confidence: 0.9945 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00085_hr
#  → N  (confidence: 0.9041 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00086_hr
#  → V  (confidence: 0.985 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00087_hr
#  → N  (confidence: 0.9996 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00088_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00089_hr
#  → N  (confidence: 0.9785 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00090_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00091_hr
#  → N  (confidence: 0.8226 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00092_hr
#  → N  (confidence: 0.9912 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00093_hr
#  → N  (confidence: 0.9992 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00094_hr
#  → V  (confidence: 0.9668 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00095_hr
#  → V  (confidence: 0.8626 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00096_hr
#  → V  (confidence: 0.5308 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00097_hr
#  → N  (confidence: 0.9987 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00098_hr
#  → N  (confidence: 1.0 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00099_hr
#  → N  (confidence: 0.8846 )
#
# Processing: /content/drive/MyDrive/mit_bih/ptb_xl_download/physionet.org/files/ptb-xl/1.0.1/records500/00000/00100_hr
#  → N  (confidence: 1.0 )
#
#
# ===============================
# Prediction File Saved At:
# /content/drive/MyDrive/noisy_allptb.csv
# ===============================

# %%
import pandas as pd

# ======================================
# FILE PATHS
# ======================================
file_ii_v5050 = "/content/drive/MyDrive/5050ptb.csv"
file_ii_vnoisy="/content/drive/MyDrive/noisy_allptb.csv"

output_file = "/content/drive/MyDrive/ptb_xl_5050_noisy.csv"

# ======================================
# LOAD & FILTER REQUIRED COLUMNS
# ======================================
def load_and_clean(path, label_suffix):
    df = pd.read_csv(path)

    # Keep only the necessary columns
    keep_cols = [c for c in df.columns if c in ["record", "predicted_class", "confidence"]]
    df = df[keep_cols]

    # Rename for merging
    df = df.rename(columns={
        "predicted_class": f"label_{label_suffix}",
        "confidence": f"conf_{label_suffix}"
    })

    return df

df_ii_v5050 = load_and_clean(file_ii_v5050, "ii_v5_5050")
df_ii_vnoisy = load_and_clean(file_ii_vnoisy, "ii_v5_noisy")



# ======================================
# MERGE ALL FOUR SAFELY
# ======================================
df = df_ii_v5050.merge(df_ii_vnoisy, on="record", how="outer")


# ======================================
# SAVE FINAL COMPARISON
# ======================================
df.to_csv(output_file, index=False)

print("\n=====================================")
print("Final Comparison File Saved:")
print(output_file)
print("=====================================")
# Out:
# =====================================
# Final Comparison File Saved:
# /content/drive/MyDrive/ptb_xl_5050_noisy.csv
# =====================================

# %%
df["same_label"] = df["label_ii_v5_5050"] == df["label_ii_v5_noisy"]

# %%
print(df["same_label"].value_counts())
# Out:
# same_label
# False    61
# True     39
# Name: count, dtype: int64

# %%
df_diff = df[df["same_label"] == False]
print(df_diff.head())
# Out:
#                                               record label_ii_v5_5050  \
# 3  /content/drive/MyDrive/mit_bih/ptb_xl_download...                F
# 4  /content/drive/MyDrive/mit_bih/ptb_xl_download...                F
# 5  /content/drive/MyDrive/mit_bih/ptb_xl_download...                F
# 6  /content/drive/MyDrive/mit_bih/ptb_xl_download...                V
# 7  /content/drive/MyDrive/mit_bih/ptb_xl_download...                F
#
#    conf_ii_v5_5050 label_ii_v5_noisy  conf_ii_v5_noisy  same_label
# 3         0.995284                 N          0.999591       False
# 4         0.455251                 V          0.999985       False
# 5         0.999876                 N          0.952558       False
# 6         0.994738                 N          0.978603       False
# 7         0.999698                 V          0.413774       False

# %%
df["conf_diff"] = df["conf_ii_v5_5050"] - df["conf_ii_v5_noisy"]

# %%
df_big_conf_diff = df.sort_values("conf_diff", key=abs, ascending=False)
df_big_conf_diff.head()
# Out:
#                                                record label_ii_v5_5050  \
# 7   /content/drive/MyDrive/mit_bih/ptb_xl_download...                F
# 4   /content/drive/MyDrive/mit_bih/ptb_xl_download...                F
# 34  /content/drive/MyDrive/mit_bih/ptb_xl_download...                S
# 91  /content/drive/MyDrive/mit_bih/ptb_xl_download...                F
# 95  /content/drive/MyDrive/mit_bih/ptb_xl_download...                F
#
#     conf_ii_v5_5050 label_ii_v5_noisy  conf_ii_v5_noisy  same_label  conf_diff
# 7          0.999698                 V          0.413774       False   0.585925
# 4          0.455251                 V          0.999985       False  -0.544734
# 34         0.525739                 N          0.999995       False  -0.474257
# 91         0.531541                 N          0.991156       False  -0.459614
# 95         0.987734                 V          0.530761       False   0.456972

# %%
pd.crosstab(df["label_ii_v5_5050"], df["label_ii_v5_noisy"])
# Out:
# label_ii_v5_noisy   N  S   V
# label_ii_v5_5050
# F                  13  1   5
# N                  18  1   1
# S                   9  4   1
# V                  30  0  17

# %%
summary = {
    "total_records": len(df),
    "same_predictions": df["same_label"].sum(),
    "different_predictions": (~df["same_label"]).sum(),
    "agreement_rate": df["same_label"].mean()
}

print(summary)
# Out:
# {'total_records': 100, 'same_predictions': np.int64(39), 'different_predictions': np.int64(61), 'agreement_rate': np.float64(0.39)}

# %%
import pandas as pd

# ======================================
# FILE PATHS (ALL 6 MODELS)
# ======================================
file_ii_v5_5050 = "/content/drive/MyDrive/5050ptb.csv"
file_ii_v5_noisy = "/content/drive/MyDrive/noisy_allptb.csv"

file_ii_v5 = "/content/drive/MyDrive/ptb_xl_predictions_100.csv"
file_all = "/content/drive/MyDrive/ptb_xl_predictions_100_all_leads.csv"
file_custom = "/content/drive/MyDrive/ptb_xl_predictions_100_leads_II_aVR_V1toV5.csv"
file_v1_v5 = "/content/drive/MyDrive/ptb_xl_predictions_100_leadsV1toV5.csv"

output_file = "/content/drive/MyDrive/ptb_xl_predictions_comparison_ALL_6.csv"

# ======================================
# LOAD FUNCTION
# ======================================
def load_and_clean(path, label_suffix):
    df = pd.read_csv(path)
    keep_cols = [c for c in df.columns if c in ["record", "predicted_class", "confidence"]]
    df = df[keep_cols]

    df = df.rename(columns={
        "predicted_class": f"label_{label_suffix}",
        "confidence": f"conf_{label_suffix}"
    })
    return df

# ======================================
# LOAD ALL 6 FILES
# ======================================
df_ii_v5_5050 = load_and_clean(file_ii_v5_5050, "ii_v5_5050")
df_ii_v5_noisy = load_and_clean(file_ii_v5_noisy, "ii_v5_noisy")

df_ii_v5 = load_and_clean(file_ii_v5, "ii_v5")
df_all = load_and_clean(file_all, "all")
df_custom = load_and_clean(file_custom, "custom")
df_v1_v5 = load_and_clean(file_v1_v5, "v1_v5")

# ======================================
# MERGE EVERYTHING ON "record"
# ======================================
df = df_ii_v5_5050.merge(df_ii_v5_noisy, on="record", how="outer")
df = df.merge(df_ii_v5, on="record", how="outer")
df = df.merge(df_all, on="record", how="outer")
df = df.merge(df_custom, on="record", how="outer")
df = df.merge(df_v1_v5, on="record", how="outer")

# ======================================
# SAVE MASTER COMPARISON FILE
# ======================================
df.to_csv(output_file, index=False)

print("\n=====================================")
print("Master Comparison File Saved:")
print(output_file)
print("=====================================")
# Out:
# =====================================
# Master Comparison File Saved:
# /content/drive/MyDrive/ptb_xl_predictions_comparison_ALL_6.csv
# =====================================

# %%
label_cols = [c for c in df.columns if c.startswith("label_")]
df["num_unique_predictions"] = df[label_cols].nunique(axis=1)

# %%
df_disagree = df[df["num_unique_predictions"] > 1]

# %%
(df["label_ii_v5"] == df["label_all"]).mean()
# Out:
# np.float64(0.54)

# %%
pd.crosstab(df["label_custom"], df["label_v1_v5"])
# Out:
# label_v1_v5    F   N  S   V
# label_custom
# F             21   0  0   1
# N              0  10  1   2
# S              3   0  7   1
# V              2   3  2  47
